# %%
from importlib import reload
from md_Helpers import master_csv

reload(master_csv)

excitation_runs = master_csv.build_excitation_evolved_master_csv()
excitation_runs
# Out:
# Wrote 141 excitation evolution rows:
# /exp/e961/data/MDsims-data/pnichols/Master_CSVs_v3/excitation_evolved_master.csv
# /home/pnichols/MDsims/excitation_evolved_master.csv
#      n_fcc_cells  temp  density  radius  energy_deposition  \
# 0           10.0   0.8     0.72     3.0              600.0
# 1           10.0   0.8     0.72     3.0              700.0
# 2           10.0   0.8     0.72     3.0              800.0
# 3           10.0   0.8     0.72     3.0              900.0
# 4           10.0   0.8     0.72     3.0             1000.0
# ..           ...   ...      ...     ...                ...
# 136          NaN   NaN      NaN     NaN                NaN
# 137          NaN   NaN      NaN     NaN                NaN
# 138          NaN   NaN      NaN     NaN                NaN
# 139          NaN   NaN      NaN     NaN                NaN
# 140          NaN   NaN      NaN     NaN                NaN
#
#              voxel_phase  actual_energy_deposition     excitation_method  \
# 0    not_phase_separated                     600.0  velocity_rescale_com
# 1    not_phase_separated                     700.0  velocity_rescale_com
# 2    not_phase_separated                     800.0  velocity_rescale_com
# 3    not_phase_separated                     900.0  velocity_rescale_com
# 4    not_phase_separated                    1000.0  velocity_rescale_com
# ..                   ...                       ...                   ...
# 136       not_classified                       NaN
# 137       not_classified                       NaN
# 138       not_classified                       NaN
# 139                  NaN                       NaN                   NaN
# 140                  NaN                       NaN                   NaN
#
#       evolution_format ensemble  ...  source_seed  evolve_seed  \
# 0    two_segment_dt_v1      NVE  ...          1.0          1.0
# 1    two_segment_dt_v1      NVE  ...          1.0          1.0
# 2    two_segment_dt_v1      NVE  ...          1.0          1.0
# 3    two_segment_dt_v1      NVE  ...          1.0          1.0
# 4    two_segment_dt_v1      NVE  ...          1.0          1.0
# ..                 ...      ...  ...          ...          ...
# 136  two_segment_dt_v1      NVE  ...          NaN          1.0
# 137  two_segment_dt_v1      NVE  ...          NaN          1.0
# 138   legacy_single_dt      NVE  ...          NaN          NaN
# 139  two_segment_dt_v1      NaN  ...          NaN          NaN
# 140  two_segment_dt_v1      NaN  ...          NaN          NaN
#
#      voxel_low_density_fraction          status  files_complete  \
# 0                           0.0        complete            True
# 1                           0.0        complete            True
# 2                           0.0        complete            True
# 3                           0.0        complete            True
# 4                           0.0        complete            True
# ..                          ...             ...             ...
# 136                         NaN         running           False
# 137                         NaN         running           False
# 138                         NaN      incomplete           False
# 139                         NaN  summary_failed           False
# 140                         NaN  summary_failed           False
#
#                    last_updated  \
# 0    2026-08-05T21:00:03.274759
# 1    2026-08-05T21:01:29.476579
# 2    2026-08-05T21:02:58.576393
# 3    2026-08-05T21:04:26.656209
# 4    2026-08-05T21:05:53.705027
# ..                          ...
# 136  2026-08-07T14:47:26.162186
# 137  2026-08-04T17:07:32.233188
# 138  2026-07-28T17:30:02.440778
# 139  2026-08-05T18:43:11.116666
# 140  2026-08-07T12:25:38.289318
#
#                                               run_path  checked  notes  \
# 0    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 1    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 2    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 3    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 4    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# ..                                                 ...      ...    ...
# 136  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 137  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 138  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 139  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 140  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
#
#                                          summary_error
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139  OSError('Unable to synchronously open file (ba...
# 140  BlockingIOError(11, "Unable to synchronously o...
#
# [141 rows x 28 columns]
