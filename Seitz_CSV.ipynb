# %%
from md_Helpers import master_csv, paths

seitz_master = master_csv.build_seitz_master_csv(
    output_name="seitz_master.csv",
    eos_table=paths.MASTER_CSVS_V3_ROOT / "thermalization_master_ncells_30.csv",
    seitz_kwargs={"plot": False},
)

seitz_master
# Out:
#      n_cells  N_source  rho_source  source_kT  source_nsteps  source_seed  \
# 0       10.0    4000.0       0.710        0.8      1000000.0          1.0
# 1       10.0    4000.0       0.710        0.8      1000000.0          1.0
# 2       10.0    4000.0       0.710        0.8      1000000.0          1.0
# 3       10.0    4000.0       0.750        0.7      1000000.0          1.0
# 4       10.0    4000.0       0.755        0.8      1000000.0          1.0
# ..       ...       ...         ...        ...            ...          ...
# 175     30.0  108000.0       0.775        0.8      1000000.0          1.0
# 176     30.0  108000.0       0.775        0.8      1000000.0          1.0
# 177     30.0  108000.0       0.800        0.8      1000000.0          1.0
# 178     30.0  108000.0       0.800        0.8      1000000.0          1.0
# 179      NaN       NaN         NaN        NaN            NaN          NaN
#
#      source_radius  bubble_seed  evolve_nsteps  evolve_seed  ...  \
# 0         3.000000          1.0       100000.0          1.0  ...
# 1         4.000000          1.0       100000.0          1.0  ...
# 2         5.000000          1.0       100000.0          1.0  ...
# 3         5.000000          1.0       100000.0          1.0  ...
# 4         2.500000          1.0       100000.0          1.0  ...
# ..             ...          ...            ...          ...  ...
# 175       4.000000          1.0       100000.0          1.0  ...
# 176       5.000000          1.0       100000.0          1.0  ...
# 177       2.564964          1.0      1000000.0          1.0  ...
# 178       3.847446          1.0       100000.0          1.0  ...
# 179            NaN          NaN            NaN          NaN  ...
#
#                                                 reason   N_cav       u_c  \
# 0    ValueError('target_rho=0.695269 is outside the...     NaN       NaN
# 1                                                       3797.0 -4.545729
# 2                                                       3613.0 -4.507610
# 3                                                       3603.0 -4.924326
# 4        final voxel classifier did not phase separate     NaN       NaN
# ..                                                 ...     ...       ...
# 175      final voxel classifier did not phase separate     NaN       NaN
# 176      final voxel classifier did not phase separate     NaN       NaN
# 177      final voxel classifier did not phase separate     NaN       NaN
# 178      final voxel classifier did not phase separate     NaN       NaN
# 179  FileNotFoundError('Could not find state for lo...     NaN       NaN
#
#     rho_liquid   rho_cav     P_EOS     u_EOS           Q  \
# 0          NaN       NaN       NaN       NaN         NaN
# 1     0.715206  0.673967 -0.255311 -4.618213  192.286157
# 2     0.719485  0.641307 -0.235069 -4.644734  351.529387
# 3     0.776600  0.675563 -0.318806 -5.092608  385.109470
# 4          NaN       NaN       NaN       NaN         NaN
# ..         ...       ...       ...       ...         ...
# 175        NaN       NaN       NaN       NaN         NaN
# 176        NaN       NaN       NaN       NaN         NaN
# 177        NaN       NaN       NaN       NaN         NaN
# 178        NaN       NaN       NaN       NaN         NaN
# 179        NaN       NaN       NaN       NaN         NaN
#
#                                    cavitation_log_path  \
# 0    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 1    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 2    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 3    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 4    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# ..                                                 ...
# 175  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 176  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 177  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 178  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 179  /exp/e961/data/MDsims-data/pnichols/Cavitation...
#
#                                        trajectory_path
# 0    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 1    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 2    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 3    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 4    /exp/e961/data/MDsims-data/pnichols/Cavitation...
# ..                                                 ...
# 175  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 176  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 177  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 178  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 179
#
# [180 rows x 23 columns]
