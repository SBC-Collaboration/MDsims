# %%
from importlib import reload
from md_Helpers import master_csv

reload(master_csv)

excitation_runs = master_csv.build_excitation_evolved_master_csv()
excitation_runs
# Out:
# Wrote 88 excitation evolution rows:
# /exp/e961/data/MDsims-data/pnichols/Master_CSVs_v3/excitation_evolved_master.csv
# /home/pnichols/MDsims/excitation_evolved_master.csv
#     n_fcc_cells  temp  density  radius  energy_deposition  \
# 0          30.0   0.8     0.71     3.0             4000.0
# 1          30.0   0.8     0.71     3.0             4000.0
# 2          30.0   0.8     0.71     3.0             6000.0
# 3          30.0   0.8     0.71     3.0             6000.0
# 4          30.0   0.8     0.71     3.0             6000.0
# ..          ...   ...      ...     ...                ...
# 83         80.0   0.8     0.72     3.0              750.0
# 84         80.0   0.8     0.72     3.0              800.0
# 85         80.0   0.8     0.72     3.0              850.0
# 86          NaN   NaN      NaN     NaN                NaN
# 87          NaN   NaN      NaN     NaN                NaN
#
#             voxel_phase  actual_energy_deposition     excitation_method  \
# 0   not_phase_separated                    4000.0  velocity_rescale_com
# 1   not_phase_separated                    4000.0  velocity_rescale_com
# 2   not_phase_separated                    6000.0  velocity_rescale_com
# 3   not_phase_separated                    6000.0  velocity_rescale_com
# 4   not_phase_separated                    6000.0  velocity_rescale_com
# ..                  ...                       ...                   ...
# 83      phase_separated                     750.0  velocity_rescale_com
# 84  not_phase_separated                     800.0  velocity_rescale_com
# 85      phase_separated                     850.0  velocity_rescale_com
# 86       not_classified                       NaN
# 87       not_classified                       NaN
#
#      evolution_format ensemble  ...  source_nsteps  source_seed  evolve_seed  \
# 0    legacy_single_dt      NVE  ...      1000000.0          1.0          1.0
# 1    legacy_single_dt      NVE  ...      1000000.0          1.0          1.0
# 2    legacy_single_dt      NVE  ...      1000000.0          1.0          1.0
# 3    legacy_single_dt      NVE  ...      1000000.0          1.0          1.0
# 4    legacy_single_dt      NVE  ...      1000000.0          1.0          1.0
# ..                ...      ...  ...            ...          ...          ...
# 83  two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 84  two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 85  two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 86  two_segment_dt_v1      NVE  ...            NaN          NaN          1.0
# 87   legacy_single_dt      NVE  ...            NaN          NaN          NaN
#
#     voxel_low_density_fraction      status  files_complete  \
# 0                     0.006366  incomplete           False
# 1                     0.007523  incomplete           False
# 2                     0.004630  incomplete           False
# 3                     0.003472  incomplete           False
# 4                     0.000000  incomplete           False
# ..                         ...         ...             ...
# 83                    0.015953    complete            True
# 84                    0.000000    complete            True
# 85                    0.015546    complete            True
# 86                         NaN     running           False
# 87                         NaN  incomplete           False
#
#                   last_updated  \
# 0   2026-07-21T19:12:27.116592
# 1   2026-07-21T19:12:27.289593
# 2   2026-07-21T19:12:28.251592
# 3   2026-07-21T19:12:28.646592
# 4   2026-07-21T19:12:28.911592
# ..                         ...
# 83  2026-08-04T04:44:49.468184
# 84  2026-08-04T17:20:44.774777
# 85  2026-08-04T17:17:38.453644
# 86  2026-08-04T17:07:32.233188
# 87  2026-07-28T17:30:02.440778
#
#                                              run_path  checked  notes
# 0   /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 1   /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 2   /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 3   /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 4   /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# ..                                                ...      ...    ...
# 83  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 84  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 85  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 86  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 87  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
#
# [88 rows x 26 columns]
