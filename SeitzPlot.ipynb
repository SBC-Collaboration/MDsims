# %%
import matplotlib.pyplot as plt

from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
    plot_cavitation_seitz,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)

# Select the completed cavitation runs to plot.
matches = display_cavitation_table(
    database,
    # limit=20,
    N_Cells=25,
    Nsteps=[250_000],
    # Mask_Radius=(2.0, 5.0),
    Phase_Separation_Status="Separated",
    # Source_Run_ID="THERMALIZATION_RUN_ID",
    # Random_Location=0,
)

# Calculate the V3-style Seitz threshold and make the plot.
figure, axis, seitz_results = plot_cavitation_seitz(
    matches,
    database,
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
        # "LJ_Mode": "xplor",
        # "LJ_r_cut": 3.0,
        # "LJ_r_on": 2.0,
    },
)

plt.show()

# Display the calculated values and uncertainty components.
display(seitz_results)
# Out:
# <style type="text/css">
# #T_1fff7 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_1fff7_row0_col0, #T_1fff7_row0_col1, #T_1fff7_row0_col2, #T_1fff7_row0_col17, #T_1fff7_row0_col22, #T_1fff7_row0_col23, #T_1fff7_row0_col24, #T_1fff7_row0_col25, #T_1fff7_row0_col34, #T_1fff7_row0_col35, #T_1fff7_row0_col36, #T_1fff7_row1_col0, #T_1fff7_row1_col1, #T_1fff7_row1_col2, #T_1fff7_row1_col17, #T_1fff7_row1_col22, #T_1fff7_row1_col23, #T_1fff7_row1_col24, #T_1fff7_row1_col25, #T_1fff7_row1_col34, #T_1fff7_row1_col35, #T_1fff7_row1_col36, #T_1fff7_row2_col0, #T_1fff7_row2_col1, #T_1fff7_row2_col2, #T_1fff7_row2_col17, #T_1fff7_row2_col22, #T_1fff7_row2_col23, #T_1fff7_row2_col24, #T_1fff7_row2_col25, #T_1fff7_row2_col34, #T_1fff7_row2_col35, #T_1fff7_row2_col36, #T_1fff7_row3_col0, #T_1fff7_row3_col1, #T_1fff7_row3_col2, #T_1fff7_row3_col17, #T_1fff7_row3_col22, #T_1fff7_row3_col23, #T_1fff7_row3_col24, #T_1fff7_row3_col25, #T_1fff7_row3_col34, #T_1fff7_row3_col35, #T_1fff7_row3_col36, #T_1fff7_row4_col0, #T_1fff7_row4_col1, #T_1fff7_row4_col2, #T_1fff7_row4_col17, #T_1fff7_row4_col22, #T_1fff7_row4_col23, #T_1fff7_row4_col24, #T_1fff7_row4_col25, #T_1fff7_row4_col34, #T_1fff7_row4_col35, #T_1fff7_row4_col36 {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_1fff7_row0_col3, #T_1fff7_row0_col4, #T_1fff7_row0_col5, #T_1fff7_row0_col6, #T_1fff7_row0_col7, #T_1fff7_row0_col8, #T_1fff7_row0_col9, #T_1fff7_row0_col10, #T_1fff7_row0_col11, #T_1fff7_row0_col12, #T_1fff7_row0_col13, #T_1fff7_row0_col14, #T_1fff7_row0_col15, #T_1fff7_row0_col16, #T_1fff7_row0_col18, #T_1fff7_row0_col19, #T_1fff7_row0_col
7_row3_col19, #T_1fff7_row3_col20, #T_1fff7_row3_col21, #T_1fff7_row3_col26, #T_1fff7_row3_col27, #T_1fff7_row3_col28, #T_1fff7_row3_col29, #T_1fff7_row3_col30, #T_1fff7_row3_col31, #T_1fff7_row3_col32, #T_1fff7_row3_col33, #T_1fff7_row3_col37, #T_1fff7_row3_col38, #T_1fff7_row3_col39, #T_1fff7_row3_col40, #T_1fff7_row3_col41, #T_1fff7_row3_col42, #T_1fff7_row3_col43, #T_1fff7_row3_col44, #T_1fff7_row3_col45, #T_1fff7_row3_col46, #T_1fff7_row4_col3, #T_1fff7_row4_col4, #T_1fff7_row4_col5, #T_1fff7_row4_col6, #T_1fff7_row4_col7, #T_1fff7_row4_col8, #T_1fff7_row4_col9, #T_1fff7_row4_col10, #T_1fff7_row4_col11, #T_1fff7_row4_col12, #T_1fff7_row4_col13, #T_1fff7_row4_col14, #T_1fff7_row4_col15, #T_1fff7_row4_col16, #T_1fff7_row4_col18, #T_1fff7_row4_col19, #T_1fff7_row4_col20, #T_1fff7_row4_col21, #T_1fff7_row4_col26, #T_1fff7_row4_col27, #T_1fff7_row4_col28, #T_1fff7_row4_col29, #T_1fff7_row4_col30, #T_1fff7_row4_col31, #T_1fff7_row4_col32, #T_1fff7_row4_col33, #T_1fff7_row4_col37, #T_1fff7_row4_col38, #T_1fff7_row4_col39, #T_1fff7_row4_col40, #T_1fff7_row4_col41, #T_1fff7_row4_col42, #T_1fff7_row4_col43, #T_1fff7_row4_col44, #T_1fff7_row4_col45, #T_1fff7_row4_col46 {
#   text-align: right;
#   white-space: nowrap;
# }
# </style>
# <table id="T_1fff7">
#   <thead>
#     <tr>
#       <th id="T_1fff7_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_1fff7_level0_col1" class="col_heading level0 col1" >File_Location</th>
#       <th id="T_1fff7_level0_col2" class="col_heading level0 col2" >Source_Run_ID</th>
#       <th id="T_1fff7_level0_col3" class="col_heading level0 col3" >Source_Frame_ID</th>
#       <th id="T_1fff7_level0_col4" class="col_heading level0 col4" >N_Cells</th>
#       <th id="T_1fff7_level0_col5" class="col_heading level0 col5" >Therm_kT</th>
#       <th id="T_1fff7_level0_col6" class="col_heading level0 col6" >Therm_Seed</th>
#       <th id="T_1fff7_level0_col7" class="col_heading level0 col7" >Source_Density</th>
#       <th id="T_1fff7_level0_col8" class="col_heading level0 col8" >Initial_Density</th>
#       <th id="T_1fff7_level0_col9" class="col_heading level0 col9" >BoxLength</th>
#       <th id="T_1fff7_level0_col10" class="col_heading level0 col10" >Mask_Radius</th>
#       <th id="T_1fff7_level0_col11" class="col_heading level0 col11" >Random_Location</th>
#       <th id="T_1fff7_level0_col12" class="col_heading level0 col12" >Location_Seed</th>
#       <th id="T_1fff7_level0_col13" class="col_heading level0 col13" >dt</th>
#       <th id="T_1fff7_level0_col14" class="col_heading level0 col14" >Nsteps</th>
#       <th id="T_1fff7_level0_col15" class="col_heading level0 col15" >This_LJ_Time</th>
#       <th id="T_1fff7_level0_col16" class="col_heading level0 col16" >Cumulative_LJ_Time</th>
#       <th id="T_1fff7_level0_col17" class="col_heading level0 col17" >Ensemble</th>
#       <th id="T_1fff7_level0_col18" class="col_heading level0 col18" >T_Set</th>
#       <th id="T_1fff7_level0_col19" class="col_heading level0 col19" >P_Set</th>
#       <th id="T_1fff7_level0_col20" class="col_heading level0 col20" >LJ_r_cut</th>
#       <th id="T_1fff7_level0_col21" class="col_heading level0 col21" >LJ_r_on</th>
#       <th id="T_1fff7_level0_col22" class="col_heading level0 col22" >LJ_Mode</th>
#       <th id="T_1fff7_level0_col23" class="col_heading level0 col23" >Phase_Separation_Status</th>
#       <th id="T_1fff7_level0_col24" class="col_heading level0 col24" >Phase_Separation_Method</th>
#       <th id="T_1fff7_level0_col25" class="col_heading level0 col25" >Phase_Separation_Method_Version</th>
#       <th id="T_1fff7_level0_col26" class="col_heading level0 col26" >rho_liquid</th>
#       <th id="T_1fff7_level0_col27" class="col_heading level0 col27" >rho_liquid_unc</th>
#       <th id="T_1fff7_level0_col28" class="col_heading level0 col28" >rho_gas</th>
#       <th id="T_1fff7_level0_col29" class="col_heading level0 col29" >rho_gas_unc</th>
#       <th id="T_1fff7_level0_col30" class="col_heading level0 col30" >V_liquid</th>
#       <th id="T_1fff7_level0_col31" class="col_heading level0 col31" >V_liquid_unc</th>
#       <th id="T_1fff7_level0_col32" class="col_heading level0 col32" >V_gas</th>
#       <th id="T_1fff7_level0_co
#            Run_ID  N_Cells  Therm_kT  Nsteps     Nc              V     rho_c  \
# 0  20260918183312       25       1.0  250000  61209  107758.608330  0.568020
# 1  20260918182835       25       1.0  250000  61232  104166.655576  0.587827
# 2  20260918183535       25       1.0  250000  61223  105042.014229  0.582843
# 3  20260918183754       25       1.0  250000  61270  106837.612251  0.573487
# 4  20260918183053       25       1.0  250000  61234  105932.203941  0.578049
#
#          uc  uc_uncertainty  rho_liquid  ...  P_EOS_uncertainty  \
# 0 -3.751707        0.000887    0.607235  ...           0.001317
# 1 -3.797267        0.000469    0.608994  ...           0.001220
# 2 -3.792704        0.000607    0.610401  ...           0.001529
# 3 -3.786896        0.000727    0.612418  ...           0.001592
# 4 -3.794461        0.000819    0.612904  ...           0.001587
#
#    P_EOS_mean_uncertainty  P_EOS_density_uncertainty  P_EOS_density_slope  \
# 0                0.000462                   0.001233             1.505352
# 1                0.000460                   0.001130             1.505352
# 2                0.000464                   0.001457             1.948282
# 3                0.000496                   0.001513             1.948282
# 4                0.000503                   0.001505             1.948282
#
#              Q  Q_uncertainty  Q_uncertainty_uc_component  \
# 0  4581.227400     289.074991                   54.303267
# 1  2396.128938     261.721840                   28.700304
# 2  3184.609708     267.549428                   37.174573
# 3  4304.281139     278.953149                   44.542576
# 4  4005.737749     278.303461                   50.138082
#
#    Q_uncertainty_u_EOS_component  Q_uncertainty_P_EOS_component  \
# 0                     283.779969                       9.165377
# 1                     260.104322                       4.415746
# 2                     264.852258                       7.251782
# 3                     275.156203                      10.810358
# 4                     273.576721                       9.558610
#
#    Q_uncertainty_rho_liquid_component
# 0                            0.656049
# 1                            0.925955
# 2                            1.200319
# 3                            1.737420
# 4                            1.843878
#
# [5 rows x 27 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
    fit_argon_lj_scale,
    plot_cavitation_seitz,
    query_argon_scaling_states,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)


# ============================================================
# 1. Select phase-separated states for the Argon scale fit
#
# These defaults reproduce the selection in Argon_Like.ipynb:
#   N_Cells = 40
#   Cumulative_LJ_Time = 200
#   Phase separated
#   rho_gas_unc <= 0.002
#   Therm_kT >= 0.85
#   Fixed-density runs only
# ============================================================

argon_states = query_argon_scaling_states(database)


# ============================================================
# 2. Fit epsilon/kB and sigma
#
# The Argon atomic mass, 39.948 u, is assigned automatically.
# ============================================================

argon_fit = fit_argon_lj_scale(argon_states)
argon_scale = argon_fit.scale

print("Argon-like LJ unit conversion:")
display(pd.Series(argon_scale.summary(), name="Value").to_frame())

print(
    "Temperature-ratio reduced chi-square:",
    argon_fit.temperature_reduced_chi2,
)

print(
    "Absolute-density reduced chi-square:",
    argon_fit.density_reduced_chi2,
)


# ============================================================
# 3. Select cavitation runs
# ============================================================

matches = display_cavitation_table(
    database,
    Nsteps=[250_000,500_000],
    Phase_Separation_Status="Separated",
    # N_Cells=45,
    # Mask_Radius=(2.0, 5.0),
    # Random_Location=0,
)


# ============================================================
# 4. Calculate Seitz Q and plot in physical Argon-like units
# ============================================================

figure, axis, seitz_results = plot_cavitation_seitz(
    matches,
    database,

    # Homogeneous states defining the EOS:
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
        # "LJ_Mode": "xplor",
    },

    # Apply fitted Argon conversion:
    physical_scale=argon_scale,
    energy_unit="eV",       # Change to "keV", "J", or "kJ/mol"
    density_unit="mol/L",   # Change to "kg/m^3" or "1/nm^3"
)

plt.show()


# ============================================================
# 5. Inspect the physical Seitz values
# ============================================================

display(
    seitz_results[
        [
            "Run_ID",
            "Therm_kT",
            "rho_liquid",
            "rho_liquid_mol/L",
            "Q",
            "Q_uncertainty",
            "Q_eV",
            "Q_uncertainty_eV",
        ]
    ]
)
# Out:
# Argon-like LJ unit conversion:
#                                       Value
# epsilon_over_kB_K              1.285996e+02
# epsilon_over_kB_uncertainty_K  4.210981e-02
# epsilon_J                      1.775508e-21
# epsilon_eV                     1.108185e-02
# sigma_nm                       3.358547e-01
# sigma_uncertainty_nm           9.749997e-06
# mass_u                         3.994800e+01
# mass_kg                        6.633521e-26
# time_ps                        2.052873e+00
# pressure_bar                   4.686714e+02
# density_mol_L                  4.383235e+01
# velocity_m_s                   1.636023e+02
# force_N                        5.286537e-12
# Temperature-ratio reduced chi-square: 7.4093708866611285
# Absolute-density reduced chi-square: 173.3929896388853
# <style type="text/css">
# #T_2cb53 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_2cb53_row0_col0, #T_2cb53_row0_col1, #T_2cb53_row0_col2, #T_2cb53_row0_col17, #T_2cb53_row0_col22, #T_2cb53_row0_col23, #T_2cb53_row0_col24, #T_2cb53_row0_col25, #T_2cb53_row0_col34, #T_2cb53_row0_col35, #T_2cb53_row0_col36, #T_2cb53_row1_col0, #T_2cb53_row1_col1, #T_2cb53_row1_col2, #T_2cb53_row1_col17, #T_2cb53_row1_col22, #T_2cb53_row1_col23, #T_2cb53_row1_col24, #T_2cb53_row1_col25, #T_2cb53_row1_col34, #T_2cb53_row1_col35, #T_2cb53_row1_col36, #T_2cb53_row2_col0, #T_2cb53_row2_col1, #T_2cb53_row2_col2, #T_2cb53_row2_col17, #T_2cb53_row2_col22, #T_2cb53_row2_col23, #T_2cb53_row2_col24, #T_2cb53_row2_col25, #T_2cb53_row2_col34, #T_2cb53_row2_col35, #T_2cb53_row2_col36, #T_2cb53_row3_col0, #T_2cb53_row3_col1, #T_2cb53_row3_col2, #T_2cb53_row3_col17, #T_2cb53_row3_col22, #T_2cb53_row3_col23, #T_2cb53_row3_col24, #T_2cb53_row3_col25, #T_2cb53_row3_col34, #T_2cb53_row3_col35, #T_2cb53_row3_col36, #T_2cb53_row4_col0, #T_2cb53_row4_col1, #T_2cb53_row4_col2, #T_2cb53_row4_col17, #T_2cb53_row4_col22, #T_2cb53_row4_col23, #T_2cb53_row4_col24, #T_2cb53_row4_col25, #T_2cb53_row4_col34, #T_2cb53_row4_col35, #T_2cb53_row4_col36, #T_2cb53_row5_col0, #T_2cb53_row5_col1, #T_2cb53_row5_col2, #T_2cb53_row5_col17, #T_2cb53_row5_col22, #T_2cb53_row5_col23, #T_2cb53_row5_col24, #T_2cb53_row5_col25, #T_2cb53_row5_col34, #T_2cb53_row5_col35, #T_2cb53_row5_col36, #T_2cb53_row6_col0, #T_2cb53_row6_col1, #T_2cb53_row6_col2, #T_2cb53_row6_col17, #T_2cb53_row6_col22, #T_2cb53_row6_col23, #T_2cb53_row6_col24, #T_2cb53_row6_col25, #T_2cb53_row6_col34, #T_2cb53_row6_col35, #T_2cb53_row6_col36, #T_2cb53_row7_col0, #T_2cb53_row7_col1, #T_2cb53_row7_col2, #T_2cb53_row7_col17, #T_2cb53_row7_col22, #T_2cb53_row7_col23, #T_2cb53_row7_col24, #T_2cb53_row7_col25, #T_2cb53_row7_col34, #T_2cb53_row7_col35, #T_2cb53_row7_col36, #T_2cb53_row8_col0, #T_2cb53_row8_col1, #T_2cb53_row8_col2, #T_2cb53_row8_col17, #T_2cb53_row8_col22, #T_2cb53_row8_col23, #T_2cb53_row8_col24, #T_2cb53_row8_col25, #T_2cb53_row8_col34, #T_2cb53_row8_col35, #T_2cb53_row8_col36, #T_2cb53_row9_col0, #T_2c