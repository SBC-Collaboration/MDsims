# %%
from pprint import pprint
from md_Helpers import delete_run

RUN_ID = "20260910203913"  # Replace with the specific 14-digit Run_ID
DRY_RUN = True             # Change to False only when ready to delete permanently

result = delete_run(
    RUN_ID,
    dry_run=DRY_RUN,
    force=True,
    confirm_run_id=RUN_ID if not DRY_RUN else None,
)

pprint(result)
# Out:
# {'directory_deleted': True,
#  'directory_exists': True,
#  'dry_run': False,
#  'hdf5_exists': True,
#  'master_rows': 1,
#  'master_rows_deleted': 1,
#  'run_directory': '/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260910203913',
#  'run_hdf5': '/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260910203913/run.hdf5',
#  'run_id': '20260910203913',
#  'sim_type': 'Thermalization',
#  'status': 'Cancelled',
#  'thermalization_rows': 0,
#  'thermalization_rows_deleted': 0,
#  'trajectory_exists': True,
#  'trajectory_gsd': '/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260910203913/trajectory.gsd'}
