# %%
from md_Helpers import (
    CavitationConfig,
    ProjectPaths,
    SQLiteRunDatabase,
    run_cavitation,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)
database.initialize()

# Only select known homogeneous thermalization states.
thermalizations = database.query_thermalizations(
    Phase_Separation_Status="Not_Separated",
    Pressure_Mean=(0, .2),
    This_LJ_Time=(400, None),
    Clone_Run_ID=None,
    Therm_kT = 0.95,
    Nsteps = 200_000,
    N_Cells = (None,20)
)

source_run_ids = [row["Run_ID"] for row in thermalizations]

print(len(source_run_ids))
source_run_ids
# Out:
# 18
# ['20260917191751',
#  '20260917191828',
#  '20260917191906',
#  '20260917191943',
#  '20260917192020',
#  '20260917194637',
#  '20260917194745',
#  '20260917194852',
#  '20260917195004',
#  '20260917195112',
#  '20260917212644',
#  '20260917213105',
#  '20260917213143',
#  '20260917213221',
#  '20260917214914',
#  '20260917215602',
#  '20260917215712',
#  '20260917215823']

# %%
results = []

for source_run_id in source_run_ids:
    config = CavitationConfig(
        source_run_id=source_run_id,
        mask_radius=10.0,
        nsteps=500_000,
        ensemble="NVT",
        random_location=False,
    )

    try:
        result = run_cavitation(
            config,
            project_paths=paths,
            database=database,
        )
    except Exception as error:
        result = {
            "source_run_id": source_run_id,
            "status": "Failed",
            "error": f"{type(error).__name__}: {error}",
        }

    results.append(result)
    print(source_run_id, result.get("status"), result.get("run_id"))
# Out:
# 20260917191751 Complete 20260923175255
# 20260917191828 Complete 20260923175421
# 20260917191906 Complete 20260923175544
# 20260917191943 Complete 20260923175704
# 20260917192020 Complete 20260923175826
# 20260917194637 Complete 20260923175950
# 20260917194745 Complete 20260923180228
# 20260917194852 Complete 20260923180507
# 20260917195004 Complete 20260923180743
# 20260917195112 Complete 20260923181018
# 20260917212644 Complete 20260923181251
# 20260917213105 Complete 20260923181414
# 20260917213143 Complete 20260923181538
# 20260917213221 Complete 20260923181701
# 20260917214914 Complete 20260923181824
# 20260917215602 Complete 20260923182102
# 20260917215712 Complete 20260923182344
# 20260917215823 Complete 20260923182620
