# %%
from md_Helpers import run_clone_rescale_thermalization

result = run_clone_rescale_thermalization(
    source_run_id="20260904203704",
    final_density=0.60,
    nsteps=20_000,
    notes=None,  # Optional additional note
)

result
# Out:
# {'skipped': False,
#  'created_new': True,
#  'run_id': '20260904204428',
#  'run_signature': '986095627c35eb97d247b320b02bfe93abe106a738f39ba83a9a3f21c1974fd0',
#  'status': 'Complete',
#  'directory': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260904204428'),
#  'trajectory_path': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260904204428/trajectory.gsd'),
#  'hdf5_path': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260904204428/run.hdf5'),
#  'phase_separation': {'phase_separated': False,
#   'status': 'Not_Separated',
#   'method': 'voxel_histogram',
#   'method_version': 'voxel_low_density_fraction_v1'},
#  'phase_fit': {'status': 'Skipped_Homogeneous',
#   'method': None,
#   'method_version': None,
#   'message': 'Voxel classification did not identify phase separation.',
#   'rho_liquid': None,
#   'rho_liquid_unc': None,
#   'rho_gas': None,
#   'rho_gas_unc': None,
#   'V_liquid': None,
# ...

# %%
# Thermostat-free box resizing (NVE particle dynamics)
from md_Helpers import run_clone_rescale_ensemble

nve_result = run_clone_rescale_ensemble(
    source_run_id="20260904203704",
    final_density=0.60,  # Above source rho = compression; below = expansion
    nsteps=20_000,
    ensemble="NVE",
    notes=None,
)

nve_result
