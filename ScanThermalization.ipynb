# %%
from md_Helpers import display_thermalization_table

thermalizations = display_thermalization_table()
# Out:
# <style type="text/css">
# #T_a4a7f th {
#   text-align: left;
#   white-space: nowrap;
# }
# ...

# %%
from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_thermalization_table,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)

matches = display_thermalization_table(
    database,

    # None returns every matching row; otherwise provide a positive integer.
    limit=None,

    # Tuples specify inclusive ranges.
    Therm_kT=(0.85, 0.95),
    Density_End=(0.55, 0.65),

    # Lists specify any acceptable value.
    Nsteps=[10_000, 100_000, 500_000, 1_000_000],
    Phase_Separation_Status=[
        "Separated",
        #"Not_Separated",
    ],

    # Scalars require an exact match.
    Ensemble="NVT",
)

matches
# Out:
# <style type="text/css">
# #T_57142 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_57142_row0_col0, #T_57142_row0_col1, #T_57142_row0_col2, #T_57142_row0_col14, #T_57142_row0_col19, #T_57142_row0_col20, #T_57142_row0_col21, #T_57142_row0_col22, #T_57142_row0_col31, #T_57142_row0_col32, #T_57142_row0_col33 {
#   text-align: left;
#   white-space: nowrap;
# }
# ...
