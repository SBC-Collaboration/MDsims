# %%
from md_Helpers import display_master_table

master_table = display_master_table(show_run_signature=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from md_Helpers import display_master_table
#       2
# ----> 3 master_table = display_master_table(show_run_signature=False)
#
# TypeError: display_master_table() got an unexpected keyword argument 'show_run_signature'
