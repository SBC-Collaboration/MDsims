# %%
from md_Helpers import display_master_table

master_table = display_master_table(
    show_run_signature=False,
    show_clock_times=False,
)
# Out:
# <style type="text/css">
# #T_9e9b3 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_9e9b3_row0_col0, #T_9e9b3_row0_col5, #T_9e9b3_row0_col6, #T_9e9b3_row0_col7, #T_9e9b3_row0_col8, #T_9e9b3_row0_col9 {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_9e9b3_row0_col1, #T_9e9b3_row0_col2, #T_9e9b3_row0_col3, #T_9e9b3_row0_col4 {
#   text-align: right;
#   white-space: nowrap;
# }
# </style>
# <table id="T_9e9b3">
#   <thead>
#     <tr>
#       <th id="T_9e9b3_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_9e9b3_level0_col1" class="col_heading level0 col1" >N_Cells</th>
#       <th id="T_9e9b3_level0_col2" class="col_heading level0 col2" >Nsteps</th>
#       <th id="T_9e9b3_level0_col3" class="col_heading level0 col3" >Current_Nstep</th>
#       <th id="T_9e9b3_level0_col4" class="col_heading level0 col4" >ElapsedTime</th>
#       <th id="T_9e9b3_level0_col5" class="col_heading level0 col5" >Sim_Type</th>
#       <th id="T_9e9b3_level0_col6" class="col_heading level0 col6" >Status</th>
#       <th id="T_9e9b3_level0_col7" class="col_heading level0 col7" >Stop_Reason</th>
#       <th id="T_9e9b3_level0_col8" class="col_heading level0 col8" >Status_Message</th>
#       <th id="T_9e9b3_level0_col9" class="col_heading level0 col9" >Notes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e9b3_row0_col0" class="data row0 col0" >20260904190346</td>
#       <td id="T_9e9b3_row0_col1" class="data row0 col1" >40</td>
#       <td id="T_9e9b3_row0_col2" class="data row0 col2" >500,000</td>
#       <td id="T_9e9b3_row0_col3" class="data row0 col3" >500,000</td>
#       <td id="T_9e9b3_row0_col4" class="data row0 col4" >554.717</td>
#       <td id="T_9e9b3_row0_col5" class="data row0 col5" >Thermalization</td>
#       <td id="T_9e9b3_row0_col6" class="data row0 col6" >Complete</td>
#       <td id="T_9e9b3_row0_col7" class="data row0 col7" >NULL</td>
#       <td id="T_9e9b3_row0_col8" class="data row0 col8" >NULL</td>
#       <td id="T_9e9b3_row0_col9" class="data row0 col9" >NULL</td>
#     </tr>
#   </tbody>
# </table>

# %%
from md_Helpers import display_thermalization_table

thermalizations = display_thermalization_table()
# Out:
# <style type="text/css">
# #T_0dd0e th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_0dd0e_row0_col0, #T_0dd0e_row0_col1, #T_0dd0e_row0_col2, #T_0dd0e_row0_col14, #T_0dd0e_row0_col19, #T_0dd0e_row0_col20, #T_0dd0e_row0_col21, #T_0dd0e_row0_col22, #T_0dd0e_row0_col31, #T_0dd0e_row0_col32, #T_0dd0e_row0_col33 {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_0dd0e_row0_col3, #T_0dd0e_row0_col4, #T_0dd0e_row0_col5, #T_0dd0e_row0_col6, #T_0dd0e_row0_col7, #T_0dd0e_row0_col8, #T_0dd0e_row0_col9, #T_0dd0e_row0_col10, #T_0dd0e_row0_col11, #T_0dd0e_row0_col12, #T_0dd0e_row0_col13, #T_0dd0e_row0_col15, #T_0dd0e_row0_col16, #T_0dd0e_row0_col17, #T_0dd0e_row0_col18, #T_0dd0e_row0_col23, #T_0dd0e_row0_col24, #T_0dd0e_row0_col25, #T_0dd0e_row0_col26, #T_0dd0e_row0_col27, #T_0dd0e_row0_col28, #T_0dd0e_row0_col29, #T_0dd0e_row0_col30, #T_0dd0e_row0_col34, #T_0dd0e_row0_col35, #T_0dd0e_row0_col36, #T_0dd0e_row0_col37, #T_0dd0e_row0_col38, #T_0dd0e_row0_col39, #T_0dd0e_row0_col40, #T_0dd0e_row0_col41, #T_0dd0e_row0_col42, #T_0dd0e_row0_col43 {
#   text-align: right;
#   white-space: nowrap;
# }
# </style>
# <table id="T_0dd0e">
#   <thead>
#     <tr>
#       <th id="T_0dd0e_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_0dd0e_level0_col1" class="col_heading level0 col1" >File_Location</th>
#       <th id="T_0dd0e_level0_col2" class="col_heading level0 col2" >Clone_Run_ID</th>
#       <th id="T_0dd0e_level0_col3" class="col_heading level0 col3" >Clone_Frame_ID</th>
#       <th id="T_0dd0e_level0_col4" class="col_heading level0 col4" >Therm_kT</th>
#       <th id="T_0dd0e_level0_col5" class="col_heading level0 col5" >Therm_Seed</th>
#       <th id="T_0dd0e_level0_col6" class="col_heading level0 col6" >Density_Start</th>
#       <th id="T_0dd0e_level0_col7" class="col_heading level0 col7" >Density_End</th>
#       <th id="T_0dd0e_level0_col8" class="col_heading level0 col8" >BoxLength_Start</th>
#       <th id="T_0dd0e_level0_col9" class="col_heading level0 col9" >BoxLength_End</th>
#       <th id="T_0dd0e_level0_col10" class="col_heading level0 col10" >dt</th>
#       <th id="T_0dd0e_level0_col11" class="col_heading level0 col11" >Nsteps</th>
#       <th id="T_0dd0e_level0_col12" class="col_heading level0 col12" >This_LJ_Time</th>
#       <th id="T_0dd0e_level0_col13" class="col_heading level0 col13" >Cumulative_LJ_Time</th>
#       <th id="T_0dd0e_level0_col14" class="col_heading level0 col14" >Ensemble</th>
#       <th id="T_0dd0e_level0_col15" class="col_heading level0 col15" >T_Set</th>
#       <th id="T_0dd0e_level0_col16" class="col_heading level0 col16" >P_Set</th>
#       <th id="T_0dd0e_level0_col17" class="col_heading level0 col17" >LJ_r_cut</th>
#       <th id="T_0dd0e_level0_col18" class="col_heading level0 col18" >LJ_r_on</th>
#       <th id="T_0dd0e_level0_col19" class="col_heading level0 col19" >LJ_Mode</th>
#       <th id="T_0dd0e_level0_col20" class="col_heading level0 col20" >Phase_Separation_Status</th>
#       <th id="T_0dd0e_level0_col21" class="col_heading level0 col21" >Phase_Separation_Method</th>
#       <th id="T_0dd0e_level0_col22" class="col_heading level0 col22" >Phase_Separation_Method_Version</th>
#       <th id="T_0dd0e_level0_col23" class="col_heading level0 col23" >rho_liquid</th>
#       <th id="T_0dd0e_level0_col24" class="col_heading level0 col24" >rho_liquid_unc</th>
#       <th id="T_0dd0e_level0_col25" class="col_heading level0 col25" >rho_gas</th>
#       <th id="T_0dd0e_level0_col26" class="col_heading level0 col26" >rho_gas_unc</th>
#       <th id="T_0dd0e_level0_col27" class="col_heading level0 col27" >V_liquid</th>
#       <th id="T_0dd0e_level0_col28" class="col_heading level0 col28" >V_liquid_unc</th>
#       <th id="T_0dd0e_level0_col29" class="col_heading level0 col29" >V_gas</th>
#       <th id="T_0dd0e_level0_col30" class="col_heading level0 col30" >V_gas_unc</th>
#       <th id="T_0dd0e_level0_col31" class="col_heading level0 col31" >Phase_Fit_Status</th>
#       <th id="T_0dd0e_level0_col32" class="col_heading level0 col32" >Phase_Fit_Method</th>
#       <th id="T_0dd0e_level0_col33" class="col_heading level0 col33" >Phase_Fit_Method_Version</th>
#       <th id="T_0dd0e_level0_col34" class="col_heading level0 col34" >Summary_Start_Step</th>
#       <th id="T_0dd0e_level0_col35" class="col_heading level0 col35" >Summary_End_Step</th>
#       <th id="T_0dd0e_level0_col36" class="col_heading level0 col36" >Summary_Num_Samples</th>
#       <th id="T_0dd0e_level0_col37" class="col_heading level0 col37" >Pressure_Mean</th>
#       <th id="T_0dd0e_level0_col38" class="col_heading level0 col38" >Pressure_Std</th>
#       <th id="T_0dd0e_level0_col39" class="col_heading level0 col39" >Pressure_SEM</th>
#       <th id="T_0dd0e_level0_col40" class="col_heading level0 col40" >PE_Per_Particle_Mean</th>
#       <th id="T_0dd0e_level0_col41" class="col_heading level0 col41" >PE_Per_Particle_Std</th>
#       <th id="T_0dd0e_level0_col42" class="col_heading level0 col42" >PE_Per_Particle_SEM</th>
#       <th id="T_0dd0e_level0_col43" class="col_heading level0 col43" >Num_Frames</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0dd0e_row0_col0" class="data row0 col0" >20260904190346</td>
#       <td id="T_0dd0e_row0_col1" class="data row0 col1" >Thermalization/20260904190346</td>
#       <td id="T_0dd0e_row0_col2" class="data row0 col2" >NULL</td>
#       <td id="T_0dd0e_row0_col3" class="data row0 col3" >NULL</td>
#       <td id="T_0dd0e_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_0dd0e_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_0dd0e_row0_col6" class="data row0 col6" >0.7</td>
#       <td id="T_0dd0e_row0_col7" class="data row0 col7" >0.7</td>
#       <td id="T_0dd0e_row0_col8" class="data row0 col8" >71.5123</td>
#       <td id="T_0dd0e_row0_col9" class="data row0 col9" >71.5123</td>
#       <td id="T_0dd0e_row0_col10" class="data row0 col10" >0.002</td>
#       <td id="T_0dd0e_row0_col11" class="data row0 col11" >500,000</td>
#       <td id="T_0dd0e_row0_col12" class="data row0 col12" >1,000</td>
#       <td id="T_0dd0e_row0_col13" class="data row0 col13" >1,000</td>
#       <td id="T_0dd0e_row0_col14" class="data row0 col14" >NVT</td>
#       <td id="T_0dd0e_row0_col15" class="data row0 col15" >1</td>
#       <td id="T_0dd0e_row0_col16" class="data row0 col16" >NULL</td>
#       <td id="T_0dd0e_row0_col17" class="data row0 col17" >2.5</td>
#       <td id="T_0dd0e_row0_col18" class="data row0 col18" >2</td>
#       <td id="T_0dd0e_row0_col19" class="data row0 col19" >xplor</td>
#       <td id="T_0dd0e_row0_col20" class="data row0 col20" >Not_Separated</td>
#       <td id="T_0dd0e_row0_col21" class="data row0 col21" >voxel_histogram</td>
#       <td id="T_0dd0e_row0_col22" class="data row0 col22" >voxel_low_density_fraction_v1</td>
#       <td id="T_0dd0e_row0_col23" class="data row0 col23" >NULL</td>
#       <td id="T_0dd0e_row0_col24" class="data row0 col24" >NULL</td>
#       <td id="T_0dd0e_row0_col25" class="data row0 col25" >NULL</td>
#       <td id="T_0dd0e_row0_col26" class="data row0 col26" >NULL</td>
#       <td id="T_0dd0e_row0_col27" class="data row0 col27" >NULL</td>
#       <td id="T_0dd0e_row0_col28" class="data row0 col28" >NULL</td>
#       <td id="T_0dd0e_row0_col29" class="data row0 col29" >NULL</td>
#       <td id="T_0dd0e_row0_col30" class="data row0 col30" >NULL</td>
#       <td id="T_0dd0e_row0_col31" class="data row0 col31" >Skipped_Homogeneous</td>
#       <td id="T_0dd0e_row0_col32" class="data row0 col32" >NULL</td>
#       <td id="T_0dd0e_row0_col33" class="data row0 col33" >NULL</td>
#       <td id="T_0dd0e_row0_col34" class="data row0 col34" >401,000</td>
#       <td id="T_0dd0e_row0_col35" class="data row0 col35" >500,000</td>
#       <td id="T_0dd0e_row0_col36" class="data row0 col36" >100</td>
#       <td id="T_0dd0e_row0_col37" class="data row0 col37" >0.358659</td>
#       <td id="T_0dd0e_row0_col38" class="data row0 col38" >0.00783597</td>
#       <td id="T_0dd0e_row0_col39" class="data row0 col39" >0.000783597</td>
#       <td id="T_0dd0e_row0_col40" class="data row0 col40" >-4.37843</td>
#       <td
