# %%
from pprint import pprint
from md_Helpers import delete_run

RUN_ID = "20260914171620"  # Replace with the specific 14-digit Run_ID
DRY_RUN = True             # Change to False only when ready to delete permanently

result = delete_run(
    RUN_ID,
    dry_run=DRY_RUN,
    force=True,
    confirm_run_id=RUN_ID if not DRY_RUN else None,
)

pprint(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 RUN_ID = "20260914171620"  # Replace with the specific 14-digit Run_ID
#       5 DRY_RUN = True             # Change to False only when ready to delete permanently
#       6
# ----> 7 result = delete_run(
#       8     RUN_ID,
#       9     dry_run=DRY_RUN,
#      10     force=True,
#
# File ~/MDsims/md_Helpers/run_management.py:88, in delete_run(run_id, dry_run, confirm_run_id, force, project_paths, database)
#      86 master = database.get_run(run_id)
#      87 if master is None:
# ---> 88     raise KeyError(f"Run_ID was not found: {run_id}")
#      89 thermalization = database.get_thermalization(run_id)
#      90 run_directory = _validated_run_directory(
#      91     run_id,
#      92     master,
#      93     thermalization,
#      94     project_paths,
#      95 )
#
# ...
