# %% [markdown]
# # V4 Thermalization Starter
# This notebook uses the local SQLite backend and the output root configured in `md_Helpers/paths.py`.

# %%
from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    ThermalizationConfig,
    display_thermalization_table,
    run_thermalization,
)

paths = ProjectPaths()
print("Output root:", paths.top_directory)
print("Local database:", paths.database)
# Out:
# Output root: /exp/e961/data/MDsims-data/pnichols/SQL
# Local database: /exp/e961/data/MDsims-data/pnichols/SQL/mdsims.sqlite3

# %%
config = ThermalizationConfig(
    n_fcc_cells=60,
    target_rho=0.65,
    kT=1.0,
    nsteps=100_000,
    dt=0.002,
    log_period = 10,
)

print("Run signature:", config.run_signature)
# Out:
# Run signature: fab9944c36aa7fc46b4a306566ee6615cbeb87e69080cbced846ad13c2bdac02

# %%
result = run_thermalization(config, project_paths=paths)
result
# Out:
# {'skipped': False,
#  'created_new': True,
#  'run_id': '20260911174634',
#  'run_signature': 'fab9944c36aa7fc46b4a306566ee6615cbeb87e69080cbced846ad13c2bdac02',
#  'status': 'Complete',
#  'directory': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260911174634'),
#  'trajectory_path': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260911174634/trajectory.gsd'),
#  'hdf5_path': PosixPath('/exp/e961/data/MDsims-data/pnichols/SQL/Thermalization/20260911174634/run.hdf5'),
#  'phase_separation': {'phase_separated': False,
#   'status': 'Not_Separated',
#   'method': 'voxel_histogram',
#   'method_version': 'voxel_low_density_fraction_v1'},
#  'phase_fit': {'status': 'Skipped_Homogeneous',
#   'method': None,
#   'method_version': None,
#   'message': 'Voxel classification did not identify phase separation.',
#   'rho_liquid': None,
#   'rho_liquid_unc': None,
#   'rho_gas': None,
#   'rho_gas_unc': None,
#   'V_liquid': None,
#   'V_liquid_unc': None,
#   'V_gas': None,
#   'V_gas_unc': None},
#  'thermodynamic_summary': {'Summary_Start_Step': 99010,
#   'Summary_End_Step': 100000,
#   'Summary_Num_Samples': 100,
#   'Pressure_Mean': 0.1121651511416549,
#   'Pressure_Std': 0.002693175433115302,
#   'Pressure_SEM': 0.00026931754331153024,
#   'PE_Per_Particle_Mean': -4.076274442230098,
#   'PE_Per_Particle_Std': 0.0006901914507181159,
#   'PE_Per_Particle_SEM': 6.901914507181159e-05}}

# %%
database = SQLiteRunDatabase(paths.database)
database.query_runs(Sim_Type="Thermalization")
# Out:
# [{'Run_ID': '20260904190346',
#   'Run_Signature': 'd5269e14a5916e1349bad80d26645b8a6827101cba20db3e6f9231b93392391f',
#   'N_Cells': 40,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 554.7166000751313,
#   'StartTime': '2026-09-04 19:03:48.131624',
#   'EndTime': '2026-09-04 19:13:35.082758',
#   'Last_Update_Time': '2026-09-04 19:13:35.082758',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260904193711',
#   'Run_Signature': '21fdc7807ac47d45ef3dacf1a97b1817dff770952152dc50ee94e3e7ca798a8d',
#   'N_Cells': 40,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 709.646795484703,
#   'StartTime': '2026-09-04 19:37:12.134084',
#   'EndTime': '2026-09-04 19:49:46.345106',
#   'Last_Update_Time': '2026-09-04 19:49:46.345106',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260904195323',
#   'Run_Signature': 'f20b5469c6603096c88b57487a86c665bd358353daeac36c958e642dc2d992e5',
#   'N_Cells': 40,
#   'Nsteps': 250000,
#   'Current_Nstep': 250000,
#   'ElapsedTime': 277.36575843859464,
#   'StartTime': '2026-09-04 19:53:25.345757',
#   'EndTime': '2026-09-04 19:58:23.874973',
#   'Last_Update_Time': '2026-09-04 19:58:23.874973',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904190346; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 250000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904195937',
#   'Run_Signature': 'c9060da70c75dff12b83d0477a127df6de7e059f26176c8a904f3d926947f918',
#   'N_Cells': 40,
#   'Nsteps': 250000,
#   'Current_Nstep': 250000,
#   'ElapsedTime': 275.94594850437716,
#   'StartTime': '2026-09-04 19:59:38.420726',
#   'EndTime': '2026-09-04 20:04:34.950363',
#   'Last_Update_Time': '2026-09-04 20:04:34.950363',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 250000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904201701',
#   'Run_Signature': '2c112b44c536d3296ab0aaaf34b2fe824409272402b4a54c1ed903359e1ffb79',
#   'N_Cells': 40,
#   'Nsteps': 150000,
#   'Current_Nstep': 150000,
#   'ElapsedTime': 166.81244106241502,
#   'StartTime': '2026-09-04 20:17:02.028846',
#   'EndTime': '2026-09-04 20:20:01.335670',
#   'Last_Update_Time': '2026-09-04 20:20:01.335670',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 150000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904202205',
#   'Run_Signature': 'bd272a68174c9c5e435eff85ba2f7307fa2e90d6a457b0c2d682af7d15d07e95',
#   'N_Cells': 40,
#   'Nsteps': 150000,
#   'Current_Nstep': 150000,
#   'ElapsedTime': 167.08318156353198,
#   'StartTime': '2026-09-04 20:22:05.877553',
#   'EndTime': '2026-09-04 20:25:07.039872',
#   'Last_Update_Time': '2026-09-04 20:25:07.039872',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904190346; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 150000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904202604',
#   'Run_Signature': '4a221cee8de78cf9c69c2e5a6f5e43d3e58e9cdab703de71a0cb7b42017051f9',
#   'N_Cells': 40,
#   'Nsteps': 50000,
#   'Current_Nstep': 50000,
#   'ElapsedTime': 56.58388259797357,
#   'StartTime': '2026-09-04 20:26:05.462177',
#   'EndTime': '2026-09-04 20:27:09.554661',
#   'Last_Update_Time': '2026-09-04 20:27:09.554661',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904190346; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 50000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904202726',
#   'Run_Signature': '6534bfb6a65f092f3d09edf876aca0e19ae2e3154de48db92e896e0ba4b20f50',
#   'N_Cells': 40,
#   'Nsteps': 50000,
#   'Current_Nstep': 50000,
#   'ElapsedTime': 56.39465878647752,
#   'StartTime': '2026-09-04 20:27:27.251439',
#   'EndTime': '2026-09-04 20:28:31.203528',
#   'Last_Update_Time': '2026-09-04 20:28:31.203528',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 50000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904203105',
#   'Run_Signature': '07ac0acb4158639b6e66e7a817c0b1c32eb6a61bfd7c41098093ee02e98616ff',
#   'N_Cells': 40,
#   'Nsteps': 25000,
#   'Current_Nstep': 0,
#   'ElapsedTime': 0.0,
#   'StartTime': None,
#   'EndTime': '2026-09-04 20:31:06.591273',
#   'Last_Update_Time': '2026-09-04 20:31:06.591305',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Failed',
#   'Stop_Reason': 'exception',
#   'Status_Message': 'ValueError: Thermalization requires at least 41 evolved log points to save five phase-analysis frames spaced by 10 logs. Reduce log_period or increase Nsteps.',
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 25000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904203234',
#   'Run_Signature': '5ebcafbdd251afd2e27243c0a76c24f739afec8dbcf220b3dbf060f985dec0ff',
#   'N_Cells': 40,
#   'Nsteps': 100000,
#   'Current_Nstep': 100000,
#   'ElapsedTime': 102.99582306854427,
#   'StartTime': '2026-09-04 20:32:35.582500',
#   'EndTime': '2026-09-04 20:35:17.855084',
#   'Last_Update_Time': '2026-09-04 20:35:17.855084',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260904203704',
#   'Run_Signature': 'ab2f1fc3f9fce3ebe2fd98d068beaca027cd17c7517222d21250520ec9064093',
#   'N_Cells': 40,
#   'Nsteps': 100000,
#   'Current_Nstep': 100000,
#   'ElapsedTime': 118.35762597853318,
#   'StartTime': '2026-09-04 20:37:05.972305',
#   'EndTime': '2026-09-04 20:39:59.107454',
#   'Last_Update_Time': '2026-09-04 20:39:59.107454',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260904203723',
#   'Run_Signature': '8e9d13e8927cae90cd49e94b017752bf77878bb2cd2b4f4335aa749071c1705c',
#   'N_Cells': 40,
#   'Nsteps': 5000,
#   'Current_Nstep': 5000,
#   'ElapsedTime': 13.304528539767489,
#   'StartTime': '2026-09-04 20:37:23.383088',
#   'EndTime': '2026-09-04 20:37:42.480792',
#   'Last_Update_Time': '2026-09-04 20:37:42.480792',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203234; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 5000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904204048',
#   'Run_Signature': '293e2bf2a3a85364fdc41047bdd98c2359df1db51c7cfcf6ca9730fac7032dce',
#   'N_Cells': 40,
#   'Nsteps': 5000,
#   'Current_Nstep': 5000,
#   'ElapsedTime': 6.4191918866708875,
#   'StartTime': '2026-09-04 20:40:49.502949',
#   'EndTime': '2026-09-04 20:41:02.336460',
#   'Last_Update_Time': '2026-09-04 20:41:02.336460',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203704; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 5000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904204228',
#   'Run_Signature': '4777d3da123447a6dd52c9685a8c2cbb406ea3c12cae8e10a22e453a63e5f689',
#   'N_Cells': 40,
#   'Nsteps': 10000,
#   'Current_Nstep': 10000,
#   'ElapsedTime': 12.266974692232907,
#   'StartTime': '2026-09-04 20:42:29.479749',
#   'EndTime': '2026-09-04 20:42:51.236083',
#   'Last_Update_Time': '2026-09-04 20:42:51.236083',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203704; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 10000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904204253',
#   'Run_Signature': 'c8a48a944b19526305468af00841d0e2d27df1a7dd421b5ba4814f72bcbbe7fc',
#   'N_Cells': 40,
#   'Nsteps': 10000,
#   'Current_Nstep': 10000,
#   'ElapsedTime': 12.367070098407567,
#   'StartTime': '2026-09-04 20:42:55.039085',
#   'EndTime': '2026-09-04 20:43:16.983917',
#   'Last_Update_Time': '2026-09-04 20:43:16.983917',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203234; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 10000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904204344',
#   'Run_Signature': '4fa191cfa0b8655ea38ff1b156b613e0b59d9c78aafc6ede5d363be8e34a6909',
#   'N_Cells': 40,
#   'Nsteps': 20000,
#   'Current_Nstep': 20000,
#   'ElapsedTime': 23.352336371084675,
#   'StartTime': '2026-09-04 20:43:46.216471',
#   'EndTime': '2026-09-04 20:44:24.576669',
#   'Last_Update_Time': '2026-09-04 20:44:24.576669',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203234; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 20000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260904204428',
#   'Run_Signature': '986095627c35eb97d247b320b02bfe93abe106a738f39ba83a9a3f21c1974fd0',
#   'N_Cells': 40,
#   'Nsteps': 20000,
#   'Current_Nstep': 20000,
#   'ElapsedTime': 23.40326902968809,
#   'StartTime': '2026-09-04 20:44:29.124899',
#   'EndTime': '2026-09-04 20:45:06.559413',
#   'Last_Update_Time': '2026-09-04 20:45:06.559413',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904203704; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 20000 steps. All other simulation settings inherited from the source run.'},
#  {'Run_ID': '20260908155424',
#   'Run_Signature': 'ef4a89c9bd0d05e08727ef0b1373bc41ec36ff889f4dc0cceb6c7fa2be9b4786',
#   'N_Cells': 40,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 397.08054069359787,
#   'StartTime': '2026-09-08 15:54:28.479932',
#   'EndTime': '2026-09-08 16:01:24.852961',
#   'Last_Update_Time': '2026-09-08 16:01:24.852961',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904190346; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 200000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: decreasing-density branch'},
#  {'Run_ID': '20260908160137',
#   'Run_Signature': '220501746dc2ef9deb8bc2b6ff00450fcac01f8b298ca5408291a1ab318d5c75',
#   'N_Cells': 40,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 394.8767991354689,
#   'StartTime': '2026-09-08 16:01:38.076532',
#   'EndTime': '2026-09-08 16:08:26.138555',
#   'Last_Update_Time': '2026-09-08 16:08:26.138555',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 200000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: increasing-density branch'},
#  {'Run_ID': '20260908163606',
#   'Run_Signature': '07bc9e3c06685e82a8db5bd56be5cb516df8496f21da16607f7693a72e1c091c',
#   'N_Cells': 40,
#   'Nsteps': 400000,
#   'Current_Nstep': 400000,
#   'ElapsedTime': 792.9260940456297,
#   'StartTime': '2026-09-08 16:36:07.576742',
#   'EndTime': '2026-09-08 16:49:46.812517',
#   'Last_Update_Time': '2026-09-08 16:49:46.812517',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904190346; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 400000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: decreasing-density branch'},
#  {'Run_ID': '20260908164947',
#   'Run_Signature': '2f1a9ba9f7e6c2dc80321d7579adec56e035ca83742a1e5d376b9a21d65d7d20',
#   'N_Cells': 40,
#   'Nsteps': 400000,
#   'Current_Nstep': 400000,
#   'ElapsedTime': 787.166709515499,
#   'StartTime': '2026-09-08 16:49:47.380867',
#   'EndTime': '2026-09-08 17:03:21.604210',
#   'Last_Update_Time': '2026-09-08 17:03:21.604210',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260904193711; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 400000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: increasing-density branch'},
#  {'Run_ID': '20260908174524',
#   'Run_Signature': '8fb3c7a8907eb4bd3fd3955cd68ca89a507c22d9b818eb7e4ed5b7f98bd869f1',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 184.68471735995263,
#   'StartTime': '2026-09-08 17:45:25.725658',
#   'EndTime': '2026-09-08 17:48:37.258703',
#   'Last_Update_Time': '2026-09-08 17:48:37.258703',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260908174722',
#   'Run_Signature': 'ef2c18a622b1b93d2a66b65cbe791c9eb0c3387606de92e330c4525c46c1f04e',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 168.90339095517993,
#   'StartTime': '2026-09-08 17:47:23.239014',
#   'EndTime': '2026-09-08 17:50:20.799180',
#   'Last_Update_Time': '2026-09-08 17:50:20.799180',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260908175244',
#   'Run_Signature': '4ef496e5b5dc05e7523a8a2142286cacfc7254b93a90c6366e64a69e8471cba7',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 419.939941942459,
#   'StartTime': '2026-09-08 17:52:45.540201',
#   'EndTime': '2026-09-08 18:00:08.360928',
#   'Last_Update_Time': '2026-09-08 18:00:08.360928',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260908174524; box rescaled isotropically with density changing linearly from 0.700000 to 0.600000 over 500000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: decreasing-density branch'},
#  {'Run_ID': '20260908175304',
#   'Run_Signature': '132eaa93dea8a44bb1d6d28b3b9e36e8904554baa1958ce6ea490ea2ef85d577',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 416.47231792402454,
#   'StartTime': '2026-09-08 17:53:05.082611',
#   'EndTime': '2026-09-08 18:00:19.964377',
#   'Last_Update_Time': '2026-09-08 18:00:19.964377',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260908174722; box rescaled isotropically with density changing linearly from 0.600000 to 0.700000 over 500000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: increasing-density branch'},
#  {'Run_ID': '20260908204234',
#   'Run_Signature': '5c206441bb11f942e9b61d3d9669f1039a9c3103dd02f142a64545346669604a',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 172.64636486559175,
#   'StartTime': '2026-09-08 20:42:36.735604',
#   'EndTime': '2026-09-08 20:45:36.081166',
#   'Last_Update_Time': '2026-09-08 20:45:36.081166',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260908205723',
#   'Run_Signature': 'e6a8a622ef465905515eb50f0ccbf2208f0ff133e507a7b037b1426ec43325d6',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 423.4750594475772,
#   'StartTime': '2026-09-08 20:57:24.658391',
#   'EndTime': '2026-09-08 21:04:48.699402',
#   'Last_Update_Time': '2026-09-08 21:04:48.699402',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260908174524; box rescaled isotropically with density changing linearly from 0.700000 to 0.640000 over 500000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: decreasing-density branch'},
#  {'Run_ID': '20260908205851',
#   'Run_Signature': 'e5f1e3f44be6e6a082d034595029ae9244b889338c9fffd0ccac81d4363b4794',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 847.5604445773643,
#   'StartTime': '2026-09-08 20:58:54.163525',
#   'EndTime': '2026-09-08 21:13:22.501746',
#   'Last_Update_Time': '2026-09-08 21:13:22.501746',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': 'Cloned final frame 5 from Run_ID 20260908204234; box rescaled isotropically with density changing linearly from 0.640000 to 0.700000 over 500000 steps. Clone evolved in NVE; all other simulation settings inherited from the source run. User note: increasing-density branch'}]

# %%
# No filters displays the entire Thermalization table.
display_thermalization_table(database);
# Out:
# <style type="text/css">
# #T_c04ad th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_c04ad_row0_col0, #T_c04ad_row0_col1, #T_c04ad_row0_col2, #T_c04ad_row0_col15, #T_c04ad_row0_col20, #T_c04ad_row0_col21, #T_c04ad_row0_col22, #T_c04ad_row0_col23, #T_c04ad_row0_col32, #T_c04ad_row0_col33, #T_c04ad_row0_col34, #T_c04ad_row1_col0, #T_c04ad_row1_col1, #T_c04ad_row1_col2, #T_c04ad_row1_col15, #T_c04ad_row1_col20, #T_c04ad_row1_col21, #T_c04ad_row1_col22, #T_c04ad_row1_col23, #T_c04ad_row1_col32, #T_c04ad_row1_col33, #T_c04ad_row1_col34, #T_c04ad_row2_col0, #T_c04ad_row2_col1, #T_c04ad_row2_col2, #T_c04ad_row2_col15, #T_c04ad_row2_col20, #T_c04ad_row2_col21, #T_c04ad_row2_col22, #T_c04ad_row2_col23, #T_c04ad_row2_col32, #T_c04ad_row2_col33, #T_c04ad_row2_col34, #T_c04ad_row3_col0, #T_c04ad_row3_col1, #T_c04ad_row3_col2, #T_c04ad_row3_col15, #T_c04ad_row3_col20, #T_c04ad_row3_col21, #T_c04ad_row3_col22, #T_c04ad_row3_col23, #T_c04ad_row3_col32, #T_c04ad_row3_col33, #T_c04ad_row3_col34, #T_c04ad_row4_col0, #T_c04ad_row4_col1, #T_c04ad_row4_col2, #T_c04ad_row4_col15, #T_c04ad_row4_col20, #T_c04ad_row4_col21, #T_c04ad_row4_col22, #T_c04ad_row4_col23, #T_c04ad_row4_col32, #T_c04ad_row4_col33, #T_c04ad_row4_col34, #T_c04ad_row5_col0, #T_c04ad_row5_col1, #T_c04ad_row5_col2, #T_c04ad_row5_col15, #T_c04ad_row5_col20, #T_c04ad_row5_col21, #T_c04ad_row5_col22, #T_c04ad_row5_col23, #T_c04ad_row5_col32, #T_c04ad_row5_col33, #T_c04ad_row5_col34, #T_c04ad_row6_col0, #T_c04ad_row6_col1, #T_c04ad_row6_col2, #T_c04ad_row6_col15, #T_c04ad_row6_col20, #T_c04ad_row6_col21, #T_c04ad_row6_col22, #T_c04ad_row6_col23, #T_c04ad_row6_col32, #T_c04ad_row6_col33, #T_c04ad_row6_col34, #T_c04ad_row7_col0, #T_c04ad_row7_col1, #T_c04ad_row7_col2, #T_c04ad_row7_col15, #T_c04ad_row7_col20, #T_c04ad_row7_col21, #T_c04ad_row7_col22, #T_c04ad_row7_col23, #T_c04ad_row7_col32, #T_c04ad_row7_col33, #T_c04ad_row7_col34, #T_c04ad_row8_col0, #T_c04ad_row8_col1, #T_c04ad_row8_col2, #T_c04ad_row8_col15, #T_c04ad_row8_col20, #T_c04ad_row8_col21, #T_c04ad_row8_col22, #T_c04ad_row8_col23, #T_c04ad_row8_col32, #T_c04ad_row8_col33, #T_c04ad_row8_col34, #T_c04ad_row9_col0, #T_c04ad_row9_col1, #T_c04ad_row9_col2, #T_c04ad_row9_col15, #T_c04ad_row9_col20, #T_c04ad_row9_col21, #T_c04ad_row9_col22, #T_c04ad_row9_col23, #T_c04ad_row9_col32, #T_c04ad_row9_col33, #T_c04ad_row9_col34, #T_c04ad_row10_col0, #T_c04ad_row10_col1, #T_c04ad_row10_col2, #T_c04ad_row10_col15, #T_c04ad_row10_col20, #T_c04ad_row10_col21, #T_c04ad_row10_col22, #T_c04ad_row10_col23, #T_c04ad_row10_col32, #T_c04ad_row10_col33, #T_c04ad_row10_col34, #T_c04ad_row11_col0, #T_c04ad_row11_col1, #T_c04ad_row11_col2, #T_c04ad_row11_col15, #T_c04ad_row11_col20, #T_c04ad_row11_col21, #T_c04ad_row11_col22, #T_c04ad_row11_col23, #T_c04ad_row11_col32, #T_c04ad_row11_col33, #T_c04ad_row11_col34, #T_c04ad_row12_col0, #T_c04ad_row12_col1, #T_c04ad_row12_col2, #T_c04ad_row12_col15, #T_c04ad_row12_col20, #T_c04ad_row12_col21, #T_c04ad_row12_col22, #T_c04ad_row12_col23, #T_c04ad_row12_col32, #T_c04ad_row12_col33, #T_c04ad_row12_col34, #T_c04ad_row13_col0, #T_c04ad_row13_col1, #T_c04ad_row13_col2, #T_c04ad_row13_col15, #T_c04ad_row13_col20, #T_c04ad_row13_col21, #T_c04ad_row13_col22, #T_c04ad_row13_col23, #T_c04ad_row13_col32, #T_c04ad_row13_col33, #T_c04ad_row13_col34, #T_c04ad_row14_col0, #T_c04ad_row14_col1, #T_c04ad_row14_col2, #T_c04ad_row14_col15, #T_c04ad_row14_col20, #T_c04ad_row14_col21, #T_c04ad_row14_col22, #T_c04ad_row14_col23, #T_c04ad_row14_col32, #T_c04ad_row14_col33, #T_c04ad_row14_col34, #T_c04ad_row15_col0, #T_c04ad_row15_col1, #T_c04ad_row15_col2, #T_c04ad_row15_col15, #T_c04ad_row15_col20, #T_c04ad_row15_col21, #T_c04ad_row15_col22, #T_c04ad_row15_col23, #T_c04ad_row15_col32, #T_c04ad_row15_col33, #T_c04ad_row15_col34, #T_c04ad_row16_col0, #T_c04ad_row16_col1, #T_c04ad_row16_col2, #T_c04ad_row16_col15, #T_c04ad_row16_col20, #T_c04ad_row16_col21, #T_c04ad_row16_col22, #T_c04ad_row16_col23, #T_c04ad_row16_col32, #T_c04ad_row16_col33, #T_c04ad_row16_col34, #T_c04ad_row17_col0, #T_c04ad_row17_col1, #T_c0 ...
#   text-align: left;
#   white-space: nowrap;
# }
# #T_c04ad_row0_col3, #T_c04ad_row0_col4, #T_c04ad_row0_col5, #T_c04ad_row0_col6, #T_c04ad_row0_col7, #T_c04ad_row0_col8, #T_c04ad_row0_col9, #T_c04ad_row0_col10, #T_c04ad_row0_col11, #T_c04ad_row0_col12, #T_c04ad_row0_col13, #T_c04ad_row0_col14, #T_c04ad_row0_col16, #T_c04ad_row0_col17, #T_c04ad_row0_col18, #T_c04ad_row0_col19, #T_c04ad_row0_col24, #T_c04ad_row0_col25, #T_c04ad_row0_col26, #T_c04ad_row0_col27, #T_c04ad_row0_col28, #T_c04ad_row0_col29, #T_c04ad_row0_col30, #T_c04ad_row0_col31, #T_c04ad_row0_col35, #T_c04ad_row0_col36, #T_c04ad_row0_col37, #T_c04ad_row0_col38, #T_c04ad_row0_col39, #T_c04ad_row0_col40, #T_c04ad_row0_col41, #T_c04ad_row0_col42, #T_c04ad_row0_col43, #T_c04ad_row0_col44, #T_c04ad_row1_col3, #T_c04ad_row1_col4, #T_c04ad_row1_col5, #T_c04ad_row1_col6, #T_c04ad_row1_col7, #T_c04ad_row1_col8, #T_c04ad_row1_col9, #T_c04ad_row1_col10, #T_c04ad_row1_col11, #T_c04ad_row1_col12, #T_c04ad_row1_col13, #T_c04ad_row1_col14, #T_c04ad_row1_col16, #T_c04ad_row1_col17, #T_c04ad_row1_col18, #T_c04ad_row1_col19, #T_c04ad_row1_col24, #T_c04ad_row1_col25, #T_c04ad_row1_col26, #T_c04ad_row1_col27, #T_c04ad_row1_col28, #T_c04ad_row1_col29, #T_c04ad_row1_col30, #T_c04ad_row1_col31, #T_c04ad_row1_col35, #T_c04ad_row1_col36, #T_c04ad_row1_col37, #T_c04ad_row1_col38, #T_c04ad_row1_col39, #T_c04ad_row1_col40, #T_c04ad_row1_col41, #T_c04ad_row1_col42, #T_c04ad_row1_col43, #T_c04ad_row1_col44, #T_c04ad_row2_col3, #T_c04ad_row2_col4, #T_c04ad_row2_col5, #T_c04ad_row2_col6, #T_c04ad_row2_col7, #T_c04ad_row2_

# %%
# Scalars are exact matches, tuples are inclusive ranges, and lists
# contain any acceptable value. Set limit=None to return every match.
matches = display_thermalization_table(
    database,
    limit=100,
    N_Cells=30,
    #Nsteps=[500_000],
    #Phase_Separation_Status="Not_Separated",
)
# Out:
# <style type="text/css">
# #T_c00c0 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_c00c0_row0_col0, #T_c00c0_row0_col1, #T_c00c0_row0_col2, #T_c00c0_row0_col15, #T_c00c0_row0_col20, #T_c00c0_row0_col21, #T_c00c0_row0_col22, #T_c00c0_row0_col23, #T_c00c0_row0_col32, #T_c00c0_row0_col33, #T_c00c0_row0_col34, #T_c00c0_row1_col0, #T_c00c0_row1_col1, #T_c00c0_row1_col2, #T_c00c0_row1_col15, #T_c00c0_row1_col20, #T_c00c0_row1_col21, #T_c00c0_row1_col22, #T_c00c0_row1_col23, #T_c00c0_row1_col32, #T_c00c0_row1_col33, #T_c00c0_row1_col34, #T_c00c0_row2_col0, #T_c00c0_row2_col1, #T_c00c0_row2_col2, #T_c00c0_row2_col15, #T_c00c0_row2_col20, #T_c00c0_row2_col21, #T_c00c0_row2_col22, #T_c00c0_row2_col23, #T_c00c0_row2_col32, #T_c00c0_row2_col33, #T_c00c0_row2_col34, #T_c00c0_row3_col0, #T_c00c0_row3_col1, #T_c00c0_row3_col2, #T_c00c0_row3_col15, #T_c00c0_row3_col20, #T_c00c0_row3_col21, #T_c00c0_row3_col22, #T_c00c0_row3_col23, #T_c00c0_row3_col32, #T_c00c0_row3_col33, #T_c00c0_row3_col34, #T_c00c0_row4_col0, #T_c00c0_row4_col1, #T_c00c0_row4_col2, #T_c00c0_row4_col15, #T_c00c0_row4_col20, #T_c00c0_row4_col21, #T_c00c0_row4_col22, #T_c00c0_row4_col23, #T_c00c0_row4_col32, #T_c00c0_row4_col33, #T_c00c0_row4_col34, #T_c00c0_row5_col0, #T_c00c0_row5_col1, #T_c00c0_row5_col2, #T_c00c0_row5_col15, #T_c00c0_row5_col20, #T_c00c0_row5_col21, #T_c00c0_row5_col22, #T_c00c0_row5_col23, #T_c00c0_row5_col32, #T_c00c0_row5_col33, #T_c00c0_row5_col34, #T_c00c0_row6_col0, #T_c00c0_row6_col1, #T_c00c0_row6_col2, #T_c00c0_row6_col15, #T_c00c0_row6_col20, #T_c00c0_row6_col21, #T_c00c0_row6_col22, #T_c00c0_row6_col23, #T_c00c0_row6_col32, #T_c00c0_row6_col33, #T_c00c0_row6_col34 {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_c00c0_row0_col3, #T_c00c0_row0_col4, #T_c00c0_row0_col5, #T_c00c0_row0_col6, #T_c00c0_row0_col7, #T_c00c0_row0_col8, #T_c00c0_row0_col9, #T_c00c0_row0_col10, #T_c00c0_row0_col11, #T_c00c0_row0_col12, #T_c00c0_row0_col13, #T_c00c0_row0_col14, #T_c00c0_row0_col16, #T_c00c0_row0_col17, #T_c00c0_row0_col18, #T_c00c0_row0_col19, #T_c00c0_row0_col24, #T_c00c0_row0_col25, #T_c00c0_row0_col26, #T_c00c0_row0_col27, #T_c00c0_row0_col28, #T_c00c0_row0_col29, #T_c00c0_row0_col30, #T_c00c0_row0_col31, #T_c00c0_row0_col35, #T_c00c0_row0_col36, #T_c00c0_row0_col37, #T_c00c0_row0_col38, #T_c00c0_row0_col39, #T_c00c0_row0_col40, #T_c00c0_row0_col41, #T_c00c0_row0_col42, #T_c00c0_row0_col43, #T_c00c0_row0_col44, #T_c00c0_row1_col3, #T_c00c0_row1_col4, #T_c00c0_row1_col5, #T_c00c0_row1_col6, #T_c00c0_row1_col7, #T_c00c0_row1_col8, #T_c00c0_row1_col9, #T_c00c0_row1_col10, #T_c00c0_row1_col11, #T_c00c0_row1_col12, #T_c00c0_row1_col13, #T_c00c0_row1_col14, #T_c00c0_row1_col16, #T_c00c0_row1_col17, #T_c00c0_row1_col18, #T_c00c0_row1_col19, #T_c00c0_row1_col24, #T_c00c0_row1_col25, #T_c00c0_row1_col26, #T_c00c0_row1_col27, #T_c00c0_row1_col28, #T_c00c0_row1_col29, #T_c00c0_row1_col30, #T_c00c0_row1_col31, #T_c00c0_row1_col35, #T_c00c0_row1_col36, #T_c00c0_row1_col37, #T_c00c0_row1_col38, #T_c00c0_row1_col39, #T_c00c0_row1_col40, #T_c00c0_row1_col41, #T_c00c0_row1_col42, #T_c00c0_row1_col43, #T_c00c0_row1_col44, #T_c00c0_row2_col3, #T_c00c0_row2_col4, #T_c00c0_row2_col5, #T_c00c0_row2_col6, #T_c00c0_row2_col7, #T_c00c0_row2_col8, #T_c00c0_row2_col9, #T_c00c0_row2_col10, #T_c00c0_row2_col11, #T_c00c0_row2_col12, #T_c00c0_row2_col13, #T_c00c0_row2_col14, #T_c00c0_row2_col16, #T_c00c0_row2_col17, #T_c00c0_row2_col18, #T_c00c0_row2_col19, #T_c00c0_row2_col24, #T_c00c0_row2_col25, #T_c00c0_row2_col26, #T_c00c0_row2_col27, #T_c00c0_row2_col28, #T_c00c0_row2_col29, #T_c00c0_row2_col30, #T_c00c0_row2_col31, #T_c00c0_row2_col35, #T_c00c0_row2_col36, #T_c00c0_row2_col37, #T_c00c0_row2_col38, #T_c00c0_row2_col39, #T_c00c0_row2_col40, #T_c00c0_row2_col41, #T_c00c0_row2_col42, #T_c00c0_row2_col43, #T_c00c0_row2_col44, #T_c00c0_row3_col3, #T_c00c0_row3_col4, #T_c00c0_row3_col5, #T_c00c0_row3_col6, #T_c00c0_row3_col7, #T_c00c0_row3_col8, #T_c00c0_row3_col9, #T_c00c0_row3_col10, #T_c00c0_row3_col11, #T_c00c0_row3_col12, #T_c00c0_row3_col13, #T_c00c0_row3_col14, #T_c00c0_row3_col16, #T_c00c0_row3_col17, #T_c00c0_row3_col18, #T_c00c0_row3_col19, #T_c00c0_row3_col24, #T_c00c0_row3_col25, #T_c00c0_row3_col26, #T_c00c0_row3_col27, #T_c00c0_row3_col28, #T_c00c0_row3_col29, #T_c00c0_row3_col30, #T_c00c0_row3_col31, #T_c00c0_row3_col35, #T_c00c0_row3_col36, #T_c00c0_row3_col37, #T_c00c0_row3_col38, #T_c00c0_row3_col39, #T_c00c0_row3_col40, #T_c00c0_row3_col41, #T_c00c0_row3_col42, #T_c00c0_row3_col43, #T_c00c0_row3_col44, #T_c00c0_row4_col3, #T_c00c0_row4_col4, #T_c00c0_row4_col5, #T_c00c0_row4_col6, #T_c00c0_row4_col7, #T_c00c0_row4_col8, #T_c00c0_row4_col9, #T_c00c0_row4_col10, #T_c00c0_row4_col11, #T_c00c0_row4_col12, #T_c00c0_row4_col13, #T_c00c0_row4_col14, #T_c00c0_row4_col16, #T_c00c0_row4_col17, #T_c00c0_row4_col18, #T_c00c0_row4_col19, #T_c00c0_row4_col24, #T_c00c0_row4_col25, #T_c00c0_row4_col26, #T_c00c0_row4_col27, #T_c00c0_row4_col28, #T_c00c0_row4_col29, #T_c00c0_row4_col30, #T_c00c0_row4_col31, #T_c00c0_row4_col35, #T_c00c0_row4_col36, #T_c00c0_row4_col37, #T_c00c0_row4_col38, #T_c00c0_row4_col39, #T_c00c0_row4_col40, #T_c00c0_row4_col41, #T_c00c0_row4_col42, #T_c00c0_row4_col43, #T_c00c0_row4_col44, #T_c00c0_row5_col3, #T_c00c0_row5_col4, #T_c00c0_row5_col5, #T_c00c0_row5_col6, #T_c00c0_row5_col7, #T_c00c0_row5_col8, #T_c00c0_row5_col9, #T_c00c0_row5_col10, #T_c00c0_row5_col11, #T_c00c0_row5_col12, #T_c00c0_row5_col13, #T_c00c0_row5_col14, #T_c00c0_row5_col16, #T_c00c0_row5_col17, #T_c00c0_row5_col18, #T_c00c0_row5_col19, #T_c00c0_row5_col24, #T_c00c0_row5_col25, #T_c00c0_row5_col26, #T_c00c0_row5_col27, #T_c00c0_row5_col28, #T_c00c0_row5_col29, #T_c00c0_r ...
#   text-align: right;
#   white-space: nowrap;
# }
# </style>
# <table id="T_c00c0">
#   <thead>
#     <tr>
#       <th id="T_c00c0_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_c00c0_level0_col1" class="col_heading level0 col1" >File_Location</th>
#       <th id="T_c00c0_level0_col2" class="col_heading level0 col2" >Clone_Run_ID</th>
#       <th id="T_c00c0_level0_col3" class="col_heading level0 col3" >Clone_Frame_ID</th>
#       <th id="T_c00c0_level0_col4" class="col_heading level0 col4" >N_Cells</th>
#       <th id="T_c00c0_level0_col5" class="col_heading level0 col5" >Therm_kT</th>
#       <th id="T_c00c0_level0_col6" class="col_heading level0 col6" >Therm_Seed</th>
#       <th id="T_c00c0_level0_col7" class="col_heading level0 col7" >Density_Start</th>
#       <th id="T_c00c0_level0_col8" class="col_heading level0 col8" >Density_End</th>
#       <th id="T_c00c0_level0_col9" class="col_heading level0 col9" >BoxLength_Start</th>
#       <th id="T_c00c0_level0_col10" class="col_heading level0 col10" >BoxLength_End</th>
#       <th id="T_c00c0_level0_col11" class="col_heading level0 col11" >dt</th>
#       <th id="T_c00c0_level0_col12" class="col_heading level0 col12" >Nsteps</th>
#       <th id="T_c00c0_level0_col13" class="col_heading level0 col13" >This_LJ_Time</th>
#       <th id="T_c00c0_level0_col14" class="c
