# %%
from md_Helpers import master_csv, paths

seitz_master = master_csv.build_seitz_master_csv(
    output_name="seitz_master.csv",
    eos_table=paths.MASTER_CSVS_V3_ROOT / "thermalization_master_ncells_30.csv",
    seitz_kwargs={"plot": False},
)

seitz_master
# Out:
#     n_cells  N_source  rho_source  source_kT  source_nsteps  source_seed  \
# 0      20.0   32000.0        0.71        0.8      1000000.0          1.0
# 1      20.0   32000.0        0.71        0.8      1000000.0          1.0
# 2      20.0   32000.0        0.71        0.8      1000000.0          1.0
# 3      20.0   32000.0        0.71        0.8      1000000.0          1.0
# 4      20.0   32000.0        0.76        0.7      1000000.0          1.0
# 5      20.0   32000.0        0.76        0.7      1000000.0          1.0
# 6      20.0   32000.0        0.76        0.7      1000000.0          1.0
# 7      20.0   32000.0        0.76        0.7      1000000.0          1.0
# 8      20.0   32000.0        0.80        0.8       100000.0          1.0
# 9      20.0   32000.0        0.80        0.8      1000000.0          1.0
# 10     20.0   32000.0        0.80        0.8      1000000.0          1.0
# 11     22.0   42592.0        0.71        0.8      1000000.0          1.0
# 12     22.0   42592.0        0.76        0.7      1000000.0          1.0
# 13     22.0   42592.0        0.76        0.7      1000000.0          1.0
# 14     22.0   42592.0        0.76        0.7      1000000.0          1.0
# 15     22.0   42592.0        0.76        0.7      1000000.0          1.0
# 16     24.0   55296.0        0.71        0.8      1000000.0          1.0
# 17     24.0   55296.0        0.76        0.7      1000000.0          1.0
# 18     24.0   55296.0        0.76        0.7      1000000.0          1.0
# 19     24.0   55296.0        0.76        0.7      1000000.0          1.0
# 20     24.0   55296.0        0.76        0.7      1000000.0          1.0
# 21     26.0   70304.0        0.71        0.8      1000000.0          1.0
# 22     26.0   70304.0        0.76        0.7      1000000.0          1.0
# 23     26.0   70304.0        0.76        0.7      1000000.0          1.0
# 24     26.0   70304.0        0.76        0.7      1000000.0          1.0
# 25     26.0   70304.0        0.76        0.7      1000000.0          1.0
# 26     28.0   87808.0        0.71        0.8      1000000.0          1.0
# 27     28.0   87808.0        0.76        0.7      1000000.0          1.0
# 28     28.0   87808.0        0.76        0.7      1000000.0          1.0
# 29     28.0   87808.0        0.76        0.7      1000000.0          1.0
# 30     28.0   87808.0        0.76        0.7      1000000.0          1.0
# 31     30.0  108000.0        0.60        1.0      1000000.0          1.0
# 32     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 33     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 34     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 35     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 36     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 37     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 38     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 39     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 40     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 41     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 42     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 43     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 44     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 45     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 46     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 47     30.0  108000.0        0.71        0.8      1000000.0          1.0
# 48     30.0  108000.0        0.72        0.8      1000000.0          1.0
# 49     30.0  108000.0        0.72        0.8      1000000.0          1.0
# 50     30.0  108000.0        0.76        0.7      1000000.0          1.0
# 51     30.0  108000.0        0.76        0.7      1000000.0          1.0
# 52     30.0  108000.0        0.76        0.7      1000000.0          1.0
# 53     30.0  108000.0        0.76        0.7      1000000.0          1.0
# 54     30.0  108000.0        0.80        0.8      1000000.0          1.0
# 55     30.0  108000.0        0.80        0.8      1000000.0          1.0
# 56      NaN       NaN         NaN        NaN            NaN          NaN
#
#     source_radius  bubble_seed  evolve_nsteps  evolve_seed  ...  \
# 0        1.779374          1.0       100000.0          1.0  ...
# 1        2.669061          1.0       100000.0          1.0  ...
# 2        3.558748          1.0       100000.0          1.0  ...
# 3        5.000000          1.0       100000.0          1.0  ...
# 4        2.609196          1.0       100000.0          1.0  ...
# 5        3.000000          1.0       100000.0          1.0  ...
# 6        4.000000          1.0       100000.0          1.0  ...
# 7        5.000000          1.0       100000.0          1.0  ...
# 8        1.709976          1.0       100000.0          1.0  ...
# 9        1.709976          1.0       100000.0          1.0  ...
# 10       2.564964          1.0       100000.0          1.0  ...
# 11       2.935967          1.0       100000.0          1.0  ...
# 12       2.870116          1.0       100000.0          1.0  ...
# 13       3.000000          1.0       100000.0          1.0  ...
# 14       4.000000          1.0       100000.0          1.0  ...
# 15       5.000000          1.0       100000.0          1.0  ...
# 16       3.202873          1.0       100000.0          1.0  ...
# 17       3.000000          1.0       100000.0          1.0  ...
# 18       3.131035          1.0       100000.0          1.0  ...
# 19       4.000000          1.0       100000.0          1.0  ...
# 20       5.000000          1.0       100000.0          1.0  ...
# 21       3.469779          1.0       100000.0          1.0  ...
# 22       3.000000          1.0       100000.0          1.0  ...
# 23       3.391955          1.0       100000.0          1.0  ...
# 24       4.000000          1.0       100000.0          1.0  ...
# 25       5.000000          1.0       100000.0          1.0  ...
# 26       3.736685          1.0       100000.0          1.0  ...
# 27       3.000000          1.0       100000.0          1.0  ...
# 28       3.652875          1.0       100000.0          1.0  ...
# 29       4.000000          1.0       100000.0          1.0  ...
# 30       5.000000          1.0       100000.0          1.0  ...
# 31       7.000000          1.0       100000.0          1.0  ...
# 32       1.334530          1.0       100000.0          1.0  ...
# 33       2.669061          1.0       100000.0          1.0  ...
# 34       3.000000          1.0       100000.0          1.0  ...
# 35       3.469779          1.0       100000.0          1.0  ...
# 36       3.500000          1.0       100000.0          1.0  ...
# 37       4.000000          1.0       100000.0          1.0  ...
# 38       4.003591          1.0       100000.0          1.0  ...
# 39       4.500000          1.0       100000.0          1.0  ...
# 40       5.000000          1.0       100000.0          1.0  ...
# 41       5.000000          1.0      1000000.0          1.0  ...
# 42       5.338122          1.0       100000.0          1.0  ...
# 43       5.500000          1.0       100000.0          1.0  ...
# 44       6.000000          1.0       100000.0          1.0  ...
# 45       6.500000          1.0       100000.0          1.0  ...
# 46       7.000000          1.0       100000.0          1.0  ...
# 47      13.345304          1.0       100000.0          1.0  ...
# 48       3.984970          1.0       100000.0          1.0  ...
# 49      13.283232          1.0       100000.0          1.0  ...
# 50       3.000000          1.0       100000.0          1.0  ...
# 51       3.913794          1.0       100000.0          1.0  ...
# 52       4.000000          1.0       100000.0          1.0  ...
# 53       5.000000          1.0       100000.0          1.0  ...
# 54       2.564964          1.0      1000000.0          1.0  ...
# 55       3.847446          1.0       100000.0          1.0  ...
# 56            NaN          NaN            NaN          NaN  ...
#
#                                                reason     N_cav       u_c  \
# 0       final voxel classifier did not phase separate       NaN       NaN
# 1       final voxel classifier did not phase separate       NaN       NaN
# 2                                                       31859.0 -4.707667
# 3                                                       31621.0 -4.721159
# 4       final voxel classifier did not phase separate       NaN       NaN
# 5       final voxel classifier did not phase separate       NaN       NaN
# 6                                                       31803.0 -5.142283
# 7                                                       31603.0 -5.146045
# 8       final voxel classifier did not phase separate       NaN       NaN
# 9       final voxel classifier did not phase separate       NaN       NaN
# 10      final voxel classifier did not phase separate       NaN       NaN
# 11      final voxel classifier did not phase separate       NaN       NaN
# 12      final voxel classifier did not phase separate       NaN       NaN
# 13                                                      42503.0 -5.150220
# 14                                                      42388.0 -5.156210
# 15                                                      42191.0 -5.157774
# 16      final voxel classifier did not phase separate       NaN       NaN
# 17      final voxel classifier did not phase separate       NaN       NaN
# 18                                                      55195.0 -5.161243
# 19                                                      55086.0 -5.166618
# 20                                                      54890.0 -5.170241
# 21      final voxel classifier did not phase separate       NaN       NaN
# 22                                                      70215.0 -5.159077
# 23                                                      70174.0 -5.172075
# 24                                                      70091.0 -5.175646
# 25                                                      69897.0 -5.178636
# 26                                                      87652.0 -4.755691
# 27      final voxel classifier did not phase separate       NaN       NaN
# 28                                                      87640.0 -5.178829
# 29                                                      87606.0 -5.184142
# 30                                                      87393.0 -5.185044
# 31      final voxel classifier did not phase separate       NaN       NaN
# 32      final voxel classifier did not phase separate       NaN       NaN
# 33      final voxel classifier did not phase separate       NaN       NaN
# 34      final voxel classifier did not phase separate       NaN       NaN
# 35                                                     107891.0 -4.752134
# 36                                                     107888.0 -4.760764
# 37                                                     107824.0 -4.763139
# 38                                                     107823.0 -4.760593
# 39                                                     107748.0 -4.766405
# 40                                                     107636.0 -4.766889
# 41                                                     107636.0 -4.780703
# 42                                                     107561.0 -4.768307
# 43                                                     107520.0 -4.770242
# 44                                                     107363.0 -4.771849
# 45                                                     107179.0 -4.771376
# 46                                                     106974.0 -4.771992
# 47                                                     100853.0 -4.759815
# 48      final voxel classifier did not phase separate       NaN       NaN
# 49                                                     100915.0 -4.764637
# 50                                                     107910.0 -5.180712
# 51                                                     107806.0 -5.188174
# 52                                                     107796.0 -5.189346
# 53                                                     107603.0 -5.190623
# 54      final voxel classifier did not phase separate       NaN       NaN
# 55      final voxel classifier did not phase separate       NaN       NaN
# 56  FileNotFoundError('Could not find state for lo...       NaN       NaN
#
#    rho_liquid   rho_cav     P_EOS     u_EOS            Q  \
# 0         NaN       NaN       NaN       NaN          NaN
# 1         NaN       NaN       NaN       NaN          NaN
# 2    0.736645  0.706872 -0.141345 -4.752146  1159.565263
# 3    0.740122  0.701591 -0.122377 -4.773989  1383.363829
# 4         NaN       NaN       NaN       NaN          NaN
# 5         NaN       NaN       NaN       NaN          NaN
# 6    0.792536  0.755321 -0.180064 -5.192976  1256.173415
# 7    0.792597  0.750571 -0.179501 -5.193362  1094.611238
# 8         NaN       NaN       NaN       NaN          NaN
# 9         NaN       NaN       NaN       NaN          NaN
# 10        NaN       NaN       NaN       NaN          NaN
# 11        NaN       NaN       NaN       NaN          NaN
# 12        NaN       NaN       NaN       NaN          NaN
# 13   0.793131  0.758412 -0.174617 -5.196708  1547.492587
# 14   0.794804  0.756360 -0.159303 -5.207200  1729.552517
# 15   0.794300  0.752845 -0.163916 -5.204040  1472.538800
# 16        NaN       NaN       NaN       NaN          NaN
# 17        NaN       NaN       NaN       NaN          NaN
# 18   0.795316  0.758612 -0.154614 -5.210412  2194.725549
# 19   0.794694  0.757114 -0.160307 -5.206512  1646.038114
# 20   0.795247  0.754420 -0.155250 -5.209976  1601.187888
# 21        NaN       NaN       NaN       NaN          NaN
# 22   0.796538  0.759038 -0.143430 -5.218075  3517.893801
# 23   0.796774  0.758595 -0.141265 -5.219558  2705.887740
# 24   0.796032  0.757697 -0.148060 -5.214902  2091.929218
# 25   0.796886  0.755600 -0.140244 -5.220257  2237.068169
# 26   0.745556  0.708739 -0.086416 -4.808257  4079.689305
# 27        NaN       NaN       NaN       NaN          NaN
# 28   0.797206  0.758546 -0.137311 -5.222267  3037.599976
# 29   0.798534  0.758252 -0.125156 -5.230595  3340.109012
# 30   0.797684  0.756408 -0.132935 -5.225266  2720.315473
# 31        NaN       NaN       NaN       NaN          NaN
# 32        NaN       NaN       NaN       NaN          NaN
# 33        NaN       NaN       NaN       NaN          NaN
# 34        NaN       NaN       NaN       NaN          NaN
# 35   0.746815  0.709283 -0.078086 -4.816195  6314.695469
# 36   0.746172  0.709264 -0.082343 -4.812138  4923.141106
# 37   0.746381  0.708843 -0.080961 -4.813455  4805.930582
# 38   0.746393  0.708836 -0.080881 -4.813531  5088.941615
# 39   0.746800  0.708343 -0.078187 -4.816099  4741.948894
# 40   0.745912  0.707607 -0.084060 -4.810502  4037.627045
# 41   0.746275  0.707607 -0.081662 -4.812788  2809.855399
# 42   0.746567  0.707114 -0.079726 -4.814632  4341.873720
# 43   0.746519  0.706844 -0.080044 -4.814329  4093.221932
# 44   0.746776  0.705812 -0.078345 -4.815948  4080.931119
# 45   0.746631  0.704603 -0.079308 -4.815031  3999.771850
# 46   0.746371  0.703255 -0.081023 -4.813396  3717.180562
# 47   0.748143  0.663015 -0.069298 -4.824569  5331.170167
# 48        NaN       NaN       NaN       NaN          NaN
# 49   0.748128  0.672767 -0.069400 -4.824472  4989.562990
# 50   0.798712  0.759367 -0.123534 -5.231707  4638.039256
# 51   0.798838  0.758635 -0.122375 -5.232500  3903.431955
# 52   0.799035  0.758564 -0.120577 -5.233732  3916.762427
# 53   0.798807  0.757206 -0.122656 -5.232308  3577.733472
# 54        NaN       NaN       NaN       NaN          NaN
# 55        NaN       NaN       NaN       NaN          NaN
# 56        NaN       NaN       NaN       NaN          NaN
#
#                                   cavitation_log_path  \
# 0   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 1   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 2   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 3   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 4   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 5   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 6   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 7   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 8   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 9   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 10  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 11  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 12  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 13  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 14  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 15  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 16  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 17  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 18  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 19  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 20  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 21  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 22  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 23  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 24  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 25  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 26  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 27  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 28  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 29  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 30  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 31  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 32  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 33  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 34  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 35  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 36  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 37  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 38  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 39  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 40  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 41  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 42  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 43  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 44  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 45  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 46  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 47  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 48  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 49  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 50  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 51  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 52  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 53  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 54  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 55  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 56  /exp/e961/data/MDsims-data/pnichols/Cavitation...
#
#                                       trajectory_path
# 0   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 1   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 2   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 3   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 4   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 5   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 6   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 7   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 8   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 9   /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 10  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 11  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 12  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 13  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 14  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 15  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 16  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 17  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 18  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 19  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 20  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 21  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 22  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 23  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 24  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 25  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 26  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 27  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 28  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 29  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 30  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 31  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 32  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 33  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 34  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 35  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 36  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 37  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 38  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 39  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 40  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 41  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 42  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 43  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 44  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 45  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 46  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 47  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 48  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 49  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 50  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 51  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 52  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 53  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 54  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 55  /exp/e961/data/MDsims-data/pnichols/Cavitation...
# 56
#
# [57 rows x 23 columns]
