# %%
import numpy
import itertools
import math
import gsd.hoomd
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display


#Grabbing helper scripts
import md_Helpers.Create_Lattices as cl
import md_Helpers.Simulation_Helpers as sh
import md_Helpers.Logging_Helpers as lh
import md_Helpers.viz_helpers as vh
from md_Helpers.Project_Paths import THERMALIZED_STATES_ROOT


import importlib
importlib.reload(cl)
importlib.reload(sh)
importlib.reload(lh)
importlib.reload(vh)
# Out:
# <module 'md_Helpers.viz_helpers' from '/home/pnichols/MDsims/md_Helpers/viz_helpers.py'>

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    BoxLength=50.0,
    target_rho=0.39,
    kT=0.40,
    nsteps=1_000_000,
    log_period=2_000,
    overwrite=True,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing lattice:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices/FCC/BoxLength_50.0/rho_0.39/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7fb86199c6e0>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_1000000_log.hdf5
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Saved final state
# GSD file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_1000000.gsd
#
# ================================================================================
# Simulation timing
# ================================================================================
# Total time: 302.15 seconds
# Total time: 5.04 minutes
# Total time: 0.08 hours
# Speed: 3,309.7 steps/second

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    BoxLength=50.0,
    target_rho=0.39,
    kT=0.40,
    nsteps=2_000_000,
    log_period=2_000,
    overwrite=True,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing lattice:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices/FCC/BoxLength_50.0/rho_0.39/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7fb86196a5d0>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_2000000_log.hdf5
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Saved final state
# GSD file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_2000000.gsd
#
# ================================================================================
# Simulation timing
# ================================================================================
# Total time: 606.91 seconds
# Total time: 10.12 minutes
# Total time: 0.17 hours
# Speed: 1,647.7 steps/second

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    BoxLength=50.0,
    target_rho=0.39,
    kT=0.40,
    nsteps=5_000_000,
    log_period=2_000,
    overwrite=True,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing lattice:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices/FCC/BoxLength_50.0/rho_0.39/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7fb863f66e90>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_5000000_log.hdf5
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Saved final state
# GSD file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States/BoxLength_50.0/rho_0.39/kT_0.40/randomization_nsteps_5000000.gsd
#
# ================================================================================
# Simulation timing
# ================================================================================
# Total time: 1520.26 seconds
# Total time: 25.34 minutes
# Total time: 0.42 hours
# Speed: 657.8 steps/second
