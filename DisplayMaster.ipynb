# %%
from md_Helpers import display_master_table

master_table = display_master_table(
    limit=20,
    show_run_signature=False,
    show_clock_times=False,
)
# Out:
# <style type="text/css">
# #T_7da02 th {
#   text-align: left;
#   white-space: nowrap;
# }
# ...

# %%
from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    ThermalizationConfig,
    display_thermalization_table,
    run_thermalization,
)
paths = ProjectPaths()


matches = display_thermalization_table(
    SQLiteRunDatabase(paths.database),
    limit=20,
    N_Cells=40,
    Nsteps=[100_000],
    This_LJ_Time=200,
    Cumulative_LJ_Time=200,
    Phase_Separation_Status="Separated",
    Clone_Run_ID=None,
)
# Out:
# <style type="text/css">
# #T_162d3 th {
#   text-align: left;
#   white-space: nowrap;
# }
# ...

# %%
from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
)

paths = ProjectPaths()

# Scalars are exact matches, lists accept any listed value, and tuples
# are inclusive (minimum, maximum) ranges. Leave filters commented out
# to display every completed cavitation state.
matches = display_cavitation_table(
    SQLiteRunDatabase(paths.database),
    #limit=20,
    N_Cells=(31,None),
    Nsteps=[500_000],
    Therm_kT= [.95],
    # This_LJ_Time=200,
    # Cumulative_LJ_Time=(200, 400),
    # Mask_Radius=(2.0, 5.0),
    Phase_Separation_Status="Separated",
    # Source_Run_ID="THERMALIZATION_RUN_ID",
    # Random_Location=0,
)
# Out:
# <style type="text/css">
# #T_beeaa th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_beeaa_row0_col0, #T_beeaa_row0_col1, #T_beeaa_row0_col2, #T_beeaa_row0_col17, #T_beeaa_row0_col22, #T_beeaa_row0_col23, #T_beeaa_row0_col24, #T_beeaa_row0_col25, #T_beeaa_row0_col34, #T_beeaa_row0_col35, #T_beeaa_row0_col36, #T_beeaa_row1_col0, #T_beeaa_row1_col1, #T_beeaa_row1_col2, #T_beeaa_row1_col17, #T_beeaa_row1_col22, #T_beeaa_row1_col23, #T_beeaa_row1_col24, #T_beeaa_row1_col25, #T_beeaa_row1_col34, #T_beeaa_row1_col35, #T_beeaa_row1_col36, #T_beeaa_row2_col0, #T_beeaa_row2_col1, #T_beeaa_row2_col2, #T_beeaa_row2_col17, #T_beeaa_row2_col22, #T_beeaa_row2_col23, #T_beeaa_row2_col24, #T_beeaa_row2_col25, #T_beeaa_row2_col34, #T_beeaa_row2_col35, #T_beeaa_row2_col36 {
#   text-align: left;
#   white-space: nowrap;
# }
# ...
