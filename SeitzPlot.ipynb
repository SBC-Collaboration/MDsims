# %%
import matplotlib.pyplot as plt

from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
    plot_cavitation_seitz,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)

# Select the completed cavitation runs to plot.
matches = display_cavitation_table(
    database,
    # limit=20,
    N_Cells=(31,None),
    Nsteps=[500_000],
    # Mask_Radius=(2.0, 5.0),
    Phase_Separation_Status="Separated",
    # Source_Run_ID="THERMALIZATION_RUN_ID",
    # Random_Location=0,
)

# Calculate the V3-style Seitz threshold and make the plot.
figure, axis, seitz_results = plot_cavitation_seitz(
    matches,
    database,
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
        # "LJ_Mode": "xplor",
        # "LJ_r_cut": 3.0,
        # "LJ_r_on": 2.0,
    },
)

plt.show()

# Display the calculated values and uncertainty components.
display(seitz_results)
# Out:
# <style type="text/css">
# #T_168b2 th {
#   text-align: left;
#   white-space: nowrap;
# }
# </style>
# <table id="T_168b2">
#   <thead>
#     <tr>
#       <th id="T_168b2_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_168b2_level0_col1" class="col_heading level0 col1" >File_Location</th>
#       <th id="T_168b2_level0_col2" class="col_heading level0 col2" >Source_Run_ID</th>
#       <th id="T_168b2_level0_col3" class="col_heading level0 col3" >Source_Frame_ID</th>
#       <th id="T_168b2_level0_col4" class="col_heading level0 col4" >N_Cells</th>
#       <th id="T_168b2_level0_col5" class="col_heading level0 col5" >Therm_kT</th>
#       <th id="T_168b2_level0_col6" class="col_heading level0 col6" >Therm_Seed</th>
#       <th id="T_168b2_level0_col7" class="col_heading level0 col7" >Source_Density</th>
#       <th id="T_168b2_level0_col8" class="col_heading level0 col8" >Initial_Density</th>
#       <th id="T_168b2_level0_col9" class="col_heading level0 col9" >BoxLength</th>
#       <th id="T_168b2_level0_col10" class="col_heading level0 col10" >Mask_Radius</th>
#       <th id="T_168b2_level0_col11" class="col_heading level0 col11" >Random_Location</th>
#       <th id="T_168b2_level0_col12" class="col_heading level0 col12" >Location_Seed</th>
#       <th id="T_168b2_level0_col13" class="col_heading level0 col13" >dt</th>
#       <th id="T_168b2_level0_col14" class="col_heading level0 col14" >Nsteps</th>
#       <th id="T_168b2_level0_col15" class="col_heading level0 col15" >This_LJ_Time</th>
#       <th id="T_168b2_level0_col16" class="col_heading level0 col16" >Cumulative_LJ_Time</th>
#       <th id="T_168b2_level0_col17" class="col_heading level0 col17" >Ensemble</th>
#       <th id="T_168b2_level0_col18" class="col_heading level0 col18" >T_Set</th>
#       <th id="T_168b2_level0_col19" class="col_heading level0 col19" >P_Set</th>
#       <th id="T_168b2_level0_col20" class="col_heading level0 col20" >LJ_r_cut</th>
#       <th id="T_168b2_level0_col21" class="col_heading level0 col21" >LJ_r_on</th>
#       <th id="T_168b2_level0_col22" class="col_heading level0 col22" >LJ_Mode</th>
#       <th id="T_168b2_level0_col23" class="col_heading level0 col23" >Phase_Separation_Status</th>
#       <th id="T_168b2_level0_col24" class="col_heading level0 col24" >Phase_Separation_Method</th>
#       <th id="T_168b2_level0_col25" class="col_heading level0 col25" >Phase_Separation_Method_Version</th>
#       <th id="T_168b2_level0_col26" class="col_heading level0 col26" >rho_liquid</th>
#       <th id="T_168b2_level0_col27" class="col_heading level0 col27" >rho_liquid_unc</th>
#       <th id="T_168b2_level0_col28" class="col_heading level0 col28" >rho_gas</th>
#       <th id="T_168b2_level0_col29" class="col_heading level0 col29" >rho_gas_unc</th>
#       <th id="T_168b2_level0_col30" class="col_heading level0 col30" >V_liquid</th>
#       <th id="T_168b2_level0_col31" class="col_heading level0 col31" >V_liquid_unc</th>
#       <th id="T_168b2_level0_col32" class="col_heading level0 col32" >V_gas</th>
#       <th id="T_168b2_level0_col33" class="col_heading level0 col33" >V_gas_unc</th>
#       <th id="T_168b2_level0_col34" class="col_heading level0 col34" >Phase_Fit_Status</th>
#       <th id="T_168b2_level0_col35" class="col_heading level0 col35" >Phase_Fit_Method</th>
#       <th id="T_168b2_level0_col36" class="col_heading level0 col36" >Phase_Fit_Method_Version</th>
#       <th id="T_168b2_level0_col37" class="col_heading level0 col37" >Summary_Start_Step</th>
#       <th id="T_168b2_level0_col38" class="col_heading level0 col38" >Summary_End_Step</th>
#       <th id="T_168b2_level0_col39" class="col_heading level0 col39" >Summary_Num_Samples</th>
#       <th id="T_168b2_level0_col40" class="col_heading level0 col40" >Pressure_Mean</th>
#       <th id="T_168b2_level0_col41" class="col_heading level0 col41" >Pressure_Std</th>
#       <th id="T_168b2_level0_col42" class="col_heading level0 col42" >Pressure_SEM</th>
#       <th id="T_168b2_level0_col43" class="col_heading level0 col43" >PE_Per_Particle_Mean</th>
#       <th id="T_168b2_level0_col44" class="col_heading level0 col44" >PE_Per_Particle_Std</th>
#       <th id="T_168b2_level0_col45" class="col_heading level0 col45" >PE_Per_Particle_SEM</th>
#       <th id="T_168b2_level0_col46" class="col_heading level0 col46" >Num_Frames</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 26
#      22     # Random_Location=0,
#      23 )
#      24
#      25 # Calculate the V3-style Seitz threshold and make the plot.
# ---> 26 figure, axis, seitz_results = plot_cavitation_seitz(
#      27     matches,
#      28     database,
#      29     eos_n_cells=45,
#
# File ~/MDsims/md_Helpers/seitz.py:427, in plot_cavitation_seitz(cavitations, database, eos_states, eos_n_cells, eos_filters, eos_columns, eos_method, temperature_atol, figure_size, dpi, title, physical_scale, energy_unit, density_unit)
#     419 results = calculate_cavitation_seitz(
#     420     cavitations,
#     421     eos_states,
#    (...)    424     temperature_atol=temperature_atol,
#     425 )
#     426 if results.empty:
# --> 427     raise ValueError("No cavitation rows were provided")
#     429 x_column = "rho_liquid"
#     430 x_uncertainty_column = "rho_liquid_uncertainty"
#
# ValueError: No cavitation rows were provided

# %%
import pandas as pd
import matplotlib.pyplot as plt

from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
    fit_argon_lj_scale,
    plot_cavitation_seitz,
    query_argon_scaling_states,
)

paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)


# ============================================================
# 1. Select phase-separated states for the Argon scale fit
#
# These defaults reproduce the selection in Argon_Like.ipynb:
#   N_Cells = 40
#   Cumulative_LJ_Time = 200
#   Phase separated
#   rho_gas_unc <= 0.002
#   Therm_kT >= 0.85
#   Fixed-density runs only
# ============================================================

argon_states = query_argon_scaling_states(database)


# ============================================================
# 2. Fit epsilon/kB and sigma
#
# The Argon atomic mass, 39.948 u, is assigned automatically.
# ============================================================

argon_fit = fit_argon_lj_scale(argon_states)
argon_scale = argon_fit.scale

print("Argon-like LJ unit conversion:")
display(pd.Series(argon_scale.summary(), name="Value").to_frame())

print(
    "Temperature-ratio reduced chi-square:",
    argon_fit.temperature_reduced_chi2,
)

print(
    "Absolute-density reduced chi-square:",
    argon_fit.density_reduced_chi2,
)


# ============================================================
# 3. Select cavitation runs
# ============================================================

matches = display_cavitation_table(
    database,
    Nsteps=[500_000],
    Phase_Separation_Status="Separated",
    # N_Cells=45,
    # Mask_Radius=(2.0, 5.0),
    # Random_Location=0,
)


# ============================================================
# 4. Calculate Seitz Q and plot in physical Argon-like units
# ============================================================

figure, axis, seitz_results = plot_cavitation_seitz(
    matches,
    database,

    # Homogeneous states defining the EOS:
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
        # "LJ_Mode": "xplor",
    },

    # Apply fitted Argon conversion:
    physical_scale=argon_scale,
    energy_unit="eV",       # Change to "keV", "J", or "kJ/mol"
    density_unit="mol/L",   # Change to "kg/m^3" or "1/nm^3"
)

plt.show()


# ============================================================
# 5. Inspect the physical Seitz values
# ============================================================

display(
    seitz_results[
        [
            "Run_ID",
            "Therm_kT",
            "rho_liquid",
            "rho_liquid_mol/L",
            "Q",
            "Q_uncertainty",
            "Q_eV",
            "Q_uncertainty_eV",
        ]
    ]
)
# Out:
# Argon-like LJ unit conversion:
#                                       Value
# epsilon_over_kB_K              1.285996e+02
# epsilon_over_kB_uncertainty_K  4.210981e-02
# epsilon_J                      1.775508e-21
# epsilon_eV                     1.108185e-02
# sigma_nm                       3.358547e-01
# sigma_uncertainty_nm           9.749997e-06
# mass_u                         3.994800e+01
# mass_kg                        6.633521e-26
# time_ps                        2.052873e+00
# pressure_bar                   4.686714e+02
# density_mol_L                  4.383235e+01
# velocity_m_s                   1.636023e+02
# force_N                        5.286537e-12
# Temperature-ratio reduced chi-square: 7.4093708866611285
# Absolute-density reduced chi-square: 173.3929896388853
# <style type="text/css">
# #T_b1963 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T
# 22  20260921225400       1.0    0.611941         26.822814  2776.177107
# 23  20260922001719       1.0    0.607742         26.638771  2048.701696
# 24  20260922002205       1.0    0.609297         26.706906  2982.267704
# 25  20260921233737       1.0    0.609527         26.716995  2601.502047
# 26  20260918193606       1.0    0.610226         26.747632  2560.496690
# 27  20260918195515       1.0    0.610595         26.763815  3439.574425
# 28  20260918195040       1.0    0.610687         26.767843  2479.260405
# 29  20260918194043       1.0    0.611451         26.801332  3677.723768
# 30  20260922005924       1.0    0.612396         26.842773  4120.259032
# 31  20260921223127       1.0    0.612608         26.852032  3937.101908
# 32  20260918190731       1.0    0.614951         26.954746  5599.897110
# 33  20260918191538       1.0    0.615146         26.963282  6613.466495
# 34  20260918200708       1.0    0.616457         27.020776  6039.557470
#
#     Q_uncertainty       Q_eV  Q_uncertainty_eV
# 0      131.310755  14.216173          1.455174
# 1      132.338258  17.071533          1.466564
# 2      144.924727  23.589766          1.606053
# 3      135.688881  21.382952          1.503700
# 4      147.160980  23.867153          1.630835
# 5      137.424084  20.075383          1.522928
# 6      144.167417  23.052462          1.597660
# 7      144.501996  25.395322          1.601371
# 8      136.634502  21.206483          1.514179
# 9      133.690404  20.296071          1.481552
# 10     138.400359  25.927501          1.533756
# 11     161.400856  30.199343          1.788648
# 12     153.509346  31.611914          1.701199
# 13     186.320885   8.728824          2.064782
# 14     187.138618  13.537814          2.073847
# 15     192.245112  20.998949          2.130443
# 16     195.144888  26.055409          2.162584
# 17     197.686284  20.792576          2.190741
# 18     189.536459  22.668503          2.100428
# 19     195.682034  31.513538          2.168544
# 20     198.994813  29.758028          2.205253
# 21     204.382008  31.254889          2.264954
# 22     199.601449  30.765183          2.211977
# 23     268.281024  22.703409          2.973060
# 24     261.755173  33.049049          2.900752
# 25     270.407945  28.829460          2.996636
# 26     271.906558  28.375045          3.013243
# 27     277.929456  38.116854          3.079998
# 28     279.077091  27.474797          3.092704
# 29     281.970389  40.755990          3.124783
# 30     348.121574  45.660100          3.857861
# 31     349.072307  43.630380          3.868394
# 32     356.203859  62.057230          3.947451
# 33     363.430134  73.289456          4.027550
# 34     359.068252  66.929481          3.979202

# %%
# Read-only nbins sensitivity study for the 30-cell runs.
# The stored values and files are never changed.
import matplotlib.pyplot as plt

from md_Helpers import (
    plot_nbins_phase_fits,
    plot_nbins_seitz,
    refit_cavitation_nbins,
    ProjectPaths,
    SQLiteRunDatabase,
    display_cavitation_table,
    fit_argon_lj_scale,
    plot_cavitation_seitz,
    query_argon_scaling_states,
)



paths = ProjectPaths()
database = SQLiteRunDatabase(paths.database)


matches_n30 = display_cavitation_table(
    database,
    N_Cells=(20, None),
    Nsteps=[500_000],
    Phase_Separation_Status="Separated",
)

# The existing rule gives 12 for N_Cells=30. Tune this range freely.
nbins_values = range(8, 21, 3)
trial_fits = refit_cavitation_nbins(
    matches_n30,
    nbins_values,
    project_paths=paths,
)

# Change the index to inspect the fits for another selected run.
fit_figure, fit_axes = plot_nbins_phase_fits(
    trial_fits,
    run_id=matches_n30.iloc[0]["Run_ID"],
)
plt.show()

seitz_figure, seitz_axis, seitz_trials = plot_nbins_seitz(
    matches_n30,
    trial_fits,
    database,
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
    },
)
plt.show()

display(
    seitz_trials[[
        "Run_ID", "voxel_nbins", "Therm_kT",
        "rho_liquid", "rho_liquid_uncertainty",
        "Q", "Q_uncertainty",
    ]]
)
# Out:
# <style type="text/css">
# #T_3ff0e th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_3ff0e_row0_col0, #T_3ff0e_row0_col1, #T_3ff0e_row0_col2, #T_3ff0e_row0_col17, #T_3ff0e_row0_col22, #T_3ff0e_row0_col23, #T_3ff0e_row0_col24, #T_3ff0e_row0_col25, #T_3ff0e_row0_col34, #T_3ff0e_row0_col35, #T_3ff0e_row0_col36, #T_3ff0e_row1_col0, #T_3ff0e_row1_col1, #T_3ff0e_row1_col2, #T_3ff0e_row1_col17, #T_3ff0e_row1_col22, #T_3ff0e_row1_col23, #T_3ff0e_row1_col24, #T_3ff0e_row1_col25, #T_3ff0e_row1_col34, #T_3ff0e_row1_col35, #T_3ff0e_row1_col36, #T_3ff0e_row2_col0, #T_3ff0e_row2_col1, #T_3ff0e_row2_col2, #T_3ff0e_row2_col17, #T_3ff0e_row2_col22, #T_3ff0e_row2_col23, #T_3ff0e_row2_col24, #T_3ff0e_row2_col25, #T_3ff0e_row2_col34, #T_3ff0e_row2_col35, #T_3ff0e_row2_col36, #T_3ff0e_row3_col0, #T_3ff0e_row3_col1, #T_3ff0e_row3_col2, #T_3ff0e_row3_col17, #T_3ff0e_row3_col22, #T_3ff0e_row3_col23, #T_3ff0e_row3_col24, #T_3ff0e_row3_col25, #T_3ff0e_row3_col34, #T_3ff0e_row3_col35, #T_3ff0e_row3_col36, #T_3ff0e_row4_col0, #T_3ff0e_row4_col1, #T_3ff0e_row4_col2, #T_3ff0e_row4_col17, #T_3ff0e_row4_col22, #T_3ff0e_row4_col23, #T_3ff0e_row4_col24, #T_3ff0e_row4_col25, #T_3ff0e_row4_col34, #T_3ff0e_row4_col35, #T_3ff0e_row4_col36, #T_3ff0e_row5_col0, #T_3ff0e_row5_col1, #T_3ff0e_row5_col2, #T_3ff0e_row5_col17, #T_3ff0e_row5_col22, #T_3ff0e_row5_col23, #T_3ff0e_row5_col24, #T_3ff0e_row5_col25, #T_3ff0e_row5_col34, #T_3ff0e_row5_col35, #T_3ff0e_row5_col36, #T_3ff0e_row6_col0, #T_3ff0e_row6_col1, #T_3ff0e_row6_col2, #T_3ff0e_row6_col17, #T_3ff0e_row6_col22, #T_3ff0e_row6_col23, #T_3ff0e_row6_col24, #T_3ff0e_row6_col25, #T_3ff0e_row6_col34, #T_3ff0e_row6_col35, #T_3ff0e_row6_col36, #T_3ff0e_row7_col0, #T_3ff0e_row7_col1, #T_3ff0e_row7_col2, #T_3ff0e_row7_col17, #T_3ff0e_row7_col22, #T_3ff0e_row7_col23, #T_3ff0e_row7_col24, #T_3ff0e_row7_col25, #T_3ff0e_row7_col34, #T_3ff0e_row7_col35, #T_3ff0e_row7_col36, #T_3ff0e_row8_col0, #T_3ff0e_row8_col1, #T_3ff0e_row8_col2, #T_3ff0e_row8_col17, #T_3ff0e_row8_col22, #T_3ff0e_row8_col23, #T_3ff0e_row8_col24, #T_3ff0e_row8_col25, #T_3ff0e_row8_col34, #T_3ff0e_row8_col35, #T_3ff0e_row8_col36, #T_3ff0e_row9_col0, #T_3ff0e_row9_col1, #T_3ff0e_row9_col2, #T_3ff0e_row9_col17, #T_3ff0e_row9_col22, #T_3ff0e_row9_col23, #T_3ff0e_row9_col24, #T_3ff0e_row9_col25, #T_3ff0e_row9_col34, #T_3ff0e_row9_col35, #T_3ff0e_row9_col36, #T_3ff0e_row10_col0, #T_3ff0e_row10_col1, #T_3ff0e_row10_col2, #T_3ff0e_row10_col17, #T_3ff0e_row10_col22, #T_3ff0e_row10_col23, #T_3ff0e_row10_col24, #T_3ff0e_row10_col25, #T_3ff0e_row10_col34, #T_3ff0e_row10_col35, #T_3ff0e_row10_col36, #T_3ff0e_row11_col0, #T_3ff0e_row11_col1, #T_3ff0e_row11_col2, #T_3ff0e_row11_col17, #T_3ff0e_row11_col22, #T_3ff0e_row11_col23, #T_3ff0e_row11_col24, #T_3ff0e_row11_col25, #T_3ff0e_row11_col34, #T_3ff0e_row11_col35, #T_3ff0e_row11_col36, #T_3ff0e_row12_col0, #T_3ff0e_row12_col1, #T_3ff0e_row12_col2, #T_3ff0e_row12_col17, #T_3ff0e_row12_col22, #T_3ff0e_row12_col23, #T_3ff0e_row12_col24, #T_3ff0e_row12_col25, #T_3ff0e_row12_col34, #T_3ff0e_row12_col35, #T_3ff0e_row12_col36, #T_3ff0e_row13_col0, #T_3ff0e_row13_col1, #T_3ff0e_row13_col2, #T_3ff0e_row13_col17, #T_3ff0e_row13_col22, #T_3ff0e_row13_col23, #T_3ff0e_row13_col24, #T_3ff0e_row13_col25, #T_3ff0e_row13_col34, #T_3ff0e_row13_col35, #T_3ff0e_row13_col36, #T_3ff0e_row14_col0, #T_3ff0e_row14_col1, #T_3ff0e_row14_col2, #T_3ff0e_row14_col17, #T_3ff0e_row14_col22, #T_3ff0e_row14_col23, #T_3ff0e_row14_col24, #T_3ff0e_row14_col25, #T_3ff0e_row14_col34, #T_3ff0e_row14_col35, #T_3ff0e_row14_col36, #T_3ff0e_row15_col0, #T_3ff0e_row15_col1, #T_3ff0e_row15_col2, #T_3ff0e_row15_col17, #T_3ff0e_row15_col22, #T_3ff0e_row15_col23, #T_3ff0e_row15_col24, #T_3ff0e_row15_col25, #T_3ff0e_row15_col34, #T_3ff0e_row15_col35, #T_3ff0e_row15_col36, #T_3ff0e_row16_col0, #T_3ff0e_row16_col1, #T_3ff0e_row16_col2, #T_3ff0e_row16_col17, #T_3ff0e_row16_col22, #T_3ff0e_row16_col23, #T_3ff0e_row16_col24, #T_3ff0e_row16_col25, #T_3ff0e_row16_col34, #T_3ff0e_row16_col35, #T_3ff0e_row16_col36, #T_3ff0e_row17_col0, #T_3ff0e_row17_col1, #T_3f ...
#   text-align: left;
#   white-space: nowrap;
# }
# #T_3ff0e_row0_col3, #T_3ff0e_row0_col4, #T_3ff0e_row0_col5, #T_3ff0e_row0_col6, #T_3ff0e_row0_col7, #T_3ff0e_row0_col8, #T_3ff0e_row0_col9, #T_3ff0e_row0_col10, #T_3ff0e_row0_col11, #T_3ff0e_row0_col12, #T_3ff0e_row0_col13, #T_3ff0e_row0_col14, #T_3ff0e_row0_col15, #T_3ff0e_row0_col16, #T_3ff0e_row0_col18, #T_3ff0e_row0_col19, #T_3ff0e_row0_col20, #T_3ff0e_row0_col21, #T_3ff0e_row0_col26, #T_3ff0e_row0_col27, #T_3ff0e_row0_col28, #T_3ff0e_row0_col29, #T_3ff0e_row0_col30, #T_3ff0e_row0_col31, #T_3ff0e_row0_col32, #T_3ff0e_row0_col33, #T_3ff0e_row0_col37, #T_3ff0e_row0_col38, #T_3ff0e_row0_col39, #T_3ff0e_row0_col40, #T_3ff0e_row0_col41, #T_3ff0e_row0_col42, #T_3ff0e_row0_col43, #T_3ff0e_row0_col44, #T_3ff0e_row0_col45, #T_3ff0e_row0_col46, #T_3ff0e_row1_col3, #T_3ff0e_row1_col4, #T_3ff0e_row1_col5, #T_3ff0e_row1_col6, #T_3ff0e_row1_col7, #T_3ff0e_row1_col8, #T_3ff0e_row1_col9, #T_3ff0e_row1_col10, #T_3ff0e_row1_col11, #T_3ff0e_row1_col12, #T_3ff0e_row1_col13, #T_3ff0e_row1_col14, #T_3ff0e_row1_col15, #T_3ff0e_row1_col16, #T_3ff0e_row1_col18, #T_3ff0e_row1_col19, #T_3ff0e_row1_col20, #T_3ff0e_row1_col21, #T_3ff0e_row1_col26, #T_3ff0e_row1_col27, #T_3ff0e_row1_col28, #T_3ff0e_row1_col29, #T_3ff0e_row1_col30, #T_3ff0e_row1_col31, #T_3ff0e_row1_col32, #T_3ff0e_row1_col33, #T_3ff0e_row1_col37, #T_3ff0e_row1_col38, #T_3ff0e_row1_col39, #T_3ff0e_row1_col40, #T_3ff0e_row1_col41, #T_3ff0e_row1_col42, #T_3ff0e_row1_col43, #T_3ff0e_row1_col44, #T_3ff0e_row1_col45, #T_3ff0e_row1_col46, #T_3ff0e_row2_col3, #T_3ff0e_row2_col4, #T_3ff0e_row2_col5, #T_3ff0e_row2_col6, #T_3ff0e_row2_col7, #T_3ff0e_row2_col8, #T_3ff0e_row2_col9, #T_3ff0e_row2_col10, #T_3ff0e_row2_col11, #T_3ff0e_row2_col12, #T_3ff0e_row2_col13, #T_3ff0e_row2_col14, #T_3ff0e_row2_col15, #T_3ff0e_row2_col16, #T_3ff0e_row2_col18, #T_3ff0e_row2_col19, #T_3ff0e_row2_col20, #T_3ff0e_row2_col21, #T_3ff0e_row2_col26, #T_3ff0e_row2_col27, #T_3ff0e_row2_col28, #T_3ff0e_row2_col29, #T_3ff0e_row2_col30, #T_3ff0e_row2_col31, #T_3ff0e_row2_col32, #T_3ff0e_row2_col33, #T_3ff0e_row2_col37, #T_3ff0e_row2_col38, #T_3ff0e_row2_col39, #T_3ff0e_row2_col40, #T_3ff0e_row2_col41, #T_3ff0e_row2_col42, #T_3ff0e_row2_col43, #T_3ff0e_row2_col44, #T_3ff0e_row2_col45, #T_3ff0e_row2_col46, #T_3ff0e_row3_col3, #T_3ff0e_row3_col4, #T_3ff0e_row3_col5, #T_3ff0e_row3_col6, #T_3ff0e_row3_col7, #T_3ff0e_row3_col8, #T_3ff0e_row3_col9, #T_3ff0e_row3_col10, #T_3ff0e_row3_col11, #T_3ff0e_row3_col12, #T_3ff0e_row3_col13, #T_3ff0e_row3_col14, #T_3ff0e_row3_col15, #T_3ff0e_row3_col16, #T_3ff0e_row3_col18, #T_3ff0e_row3_col19, #T_3ff0e_row3_col20, #T_3ff0e_row3_col21, #T_3ff0e_row3_col26, #T_3ff0e_row3_col27, #T_3ff0e_row3_col28, #T_3ff0e_row3_col29, #T_3ff0e_row3_col30,
#              Run_ID  voxel_nbins  Therm_kT  rho_liquid  \
# 0    20260921235908            8       1.0    0.598887
# 1    20260921225122            8       1.0    0.602476
# 2    20260918194755            8       1.0    0.606008
# 3    20260921235345            8       1.0    0.607536
# 4    20260918192601            8       1.0    0.607588
# ..              ...          ...       ...         ...
# 105  20260921223127           20       1.0    0.613489
# 106  20260922005924           20       1.0    0.613656
# 107  20260918190731           20       1.0    0.616171
# 108  20260918191538           20       1.0    0.616565
# 109  20260918200708           20       1.0    0.618380
#
#      rho_liquid_uncertainty            Q  Q_uncertainty
# 0                  0.001149   594.257866     190.642579
# 1                  0.001152  1225.079671     189.967282
# 2                  0.001105  1892.969974     199.285929
# 3                  0.001119  2481.033890     189.714221
# 4                  0.001118  1969.121717     201.991610
# ..                      ...          ...            ...
# 105                0.000570  4486.969039     353.427904
# 106                0.000583  4909.209761     359.472265
# 107                0.000572  6385.853868     366.958181
# 108                0.000582  7537.646290     365.120769
# 109                0.000582  7289.194650     370.902494
#
# [110 rows x 7 columns]

# %%
fit_figure, fit_axes = plot_nbins_phase_fits(
    trial_fits,
    run_id=matches_n30.iloc[0]["Run_ID"],
)
plt.show()

# %%
seitz_figure, seitz_axis, seitz_trials = plot_nbins_seitz(
    matches_n30,
    trial_fits,
    database,
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
    },
)
plt.ylim(0,None)
plt.show()

# %%
selected_fits = trial_fits[
    trial_fits["voxel_nbins"].isin([8, 14])
]

seitz_figure, seitz_axis, seitz_trials_selected = plot_nbins_seitz(
    matches_n30,
    selected_fits,
    database,
    eos_n_cells=45,
    eos_filters={
        "Nsteps": 200_000,
        "dt": 0.002,
        "Ensemble": "NVT",
    },
)

seitz_axis.set_ylim(0, None)
plt.show()
