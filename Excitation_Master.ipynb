# %%
from importlib import reload
from md_Helpers import master_csv

reload(master_csv)

excitation_runs = master_csv.build_excitation_evolved_master_csv(include_legacy=False)
excitation_runs
# Out:
# Wrote 171 excitation evolution rows:
# /exp/e961/data/MDsims-data/pnichols/Master_CSVs_v3/excitation_evolved_master.csv
# /home/pnichols/MDsims/excitation_evolved_master.csv
#      n_fcc_cells  temp  density  radius  energy_deposition  \
# 0           10.0   0.8     0.72     3.0              600.0
# 1           10.0   0.8     0.72     3.0              600.0
# 2           10.0   0.8     0.72     3.0              650.0
# 3           10.0   0.8     0.72     3.0              700.0
# 4           10.0   0.8     0.72     3.0              750.0
# ..           ...   ...      ...     ...                ...
# 166          NaN   NaN      NaN     NaN                NaN
# 167          NaN   NaN      NaN     NaN                NaN
# 168          NaN   NaN      NaN     NaN                NaN
# 169          NaN   NaN      NaN     NaN                NaN
# 170          NaN   NaN      NaN     NaN                NaN
#
#              voxel_phase outcome outcome_source  terminal  stopped_segment  \
# ...
