# %%
from importlib import reload
from md_Helpers import master_csv

reload(master_csv)

excitation_runs = master_csv.build_excitation_evolved_master_csv()
excitation_runs
# Out:
# Wrote 211 excitation evolution rows:
# /exp/e961/data/MDsims-data/pnichols/Master_CSVs_v3/excitation_evolved_master.csv
# /home/pnichols/MDsims/excitation_evolved_master.csv
#      n_fcc_cells  temp  density  radius  energy_deposition  \
# 0           10.0   0.8     0.72     3.0              600.0
# 1           10.0   0.8     0.72     3.0              600.0
# 2           10.0   0.8     0.72     3.0              650.0
# 3           10.0   0.8     0.72     3.0              700.0
# 4           10.0   0.8     0.72     3.0              750.0
# ..           ...   ...      ...     ...                ...
# 206          NaN   NaN      NaN     NaN                NaN
# 207          NaN   NaN      NaN     NaN                NaN
# 208          NaN   NaN      NaN     NaN                NaN
# 209          NaN   NaN      NaN     NaN                NaN
# 210          NaN   NaN      NaN     NaN                NaN
#
#              voxel_phase  actual_energy_deposition     excitation_method  \
# 0    not_phase_separated                     600.0  velocity_rescale_com
# 1    not_phase_separated                     600.0  velocity_rescale_com
# 2    not_phase_separated                     650.0  velocity_rescale_com
# 3    not_phase_separated                     700.0  velocity_rescale_com
# 4    not_phase_separated                     750.0  velocity_rescale_com
# ..                   ...                       ...                   ...
# 206       not_classified                       NaN
# 207       not_classified                       NaN
# 208       not_classified                       NaN
# 209       not_classified                       NaN
# 210       not_classified                       NaN
#
#       evolution_format ensemble  ...  source_nsteps  source_seed  evolve_seed  \
# 0    two_segment_dt_v1      NPH  ...      1000000.0          1.0          1.0
# 1    two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 2    two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 3    two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# 4    two_segment_dt_v1      NVE  ...      1000000.0          1.0          1.0
# ..                 ...      ...  ...            ...          ...          ...
# 206  two_segment_dt_v1      NPH  ...            NaN          NaN          1.0
# 207  two_segment_dt_v1      NPH  ...            NaN          NaN          1.0
# 208  two_segment_dt_v1      NPH  ...            NaN          NaN          1.0
# 209  two_segment_dt_v1      NPH  ...            NaN          NaN          1.0
# 210   legacy_single_dt      NVE  ...            NaN          NaN          NaN
#
#      voxel_low_density_fraction      status  files_complete  \
# 0                           0.0    complete            True
# 1                           0.0    complete            True
# 2                           0.0    complete            True
# 3                           0.0    complete            True
# 4                           0.0    complete            True
# ..                          ...         ...             ...
# 206                         NaN     running           False
# 207                         NaN     running           False
# 208                         NaN     running           False
# 209                         NaN     running           False
# 210                         NaN  incomplete           False
#
#                    last_updated  \
# 0    2026-08-17T18:32:40.596349
# 1    2026-08-05T21:00:03.274759
# 2    2026-08-07T15:08:42.670624
# 3    2026-08-05T21:01:29.476579
# 4    2026-08-07T15:31:11.202919
# ..                          ...
# 206  2026-08-05T20:04:32.855325
# 207  2026-08-05T18:22:38.430752
# 208  2026-08-17T18:36:38.472019
# 209  2026-08-05T17:44:24.896670
# 210  2026-07-28T17:30:02.440778
#
#                                               run_path  checked  notes
# 0    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 1    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 2    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 3    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 4    /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# ..                                                 ...      ...    ...
# 206  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 207  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 208  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 209  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
# 210  /exp/e961/data/MDsims-data/pnichols/Excitation...      NaN    NaN
#
# [211 rows x 27 columns]
