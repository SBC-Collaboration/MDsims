# %%
import numpy
import itertools
import math
import gsd.hoomd
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display


#Grabbing helper scripts
import md_Helpers.Create_Lattices as cl
import md_Helpers.Simulation_Helpers as sh
import md_Helpers.Logging_Helpers as lh
import md_Helpers.viz_helpers as vh
from md_Helpers.Project_Paths import THERMALIZED_STATES_V2_ROOT

import importlib
importlib.reload(cl)
importlib.reload(sh)
importlib.reload(lh)
importlib.reload(vh)
# Out:
# <module 'md_Helpers.viz_helpers' from '/home/pnichols/MDsims/md_Helpers/viz_helpers.py'>

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    n_fcc_cells=25,
    target_rho=0.40,
    kT=0.40,
    nsteps=1_000_000,
    overwrite=False,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Created new FCC lattice
# ----------------------------
# n_fcc_cells = 25
# N = 62500
# Target rho = 0.4
# Actual rho = 0.4000000000000003
# Density error = 2.7755575615628914e-16
# BoxLength = 53.86086725079708
# FCC cell size = 2.154434690031883
# Saved lattice to:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices_v2/FCC/n_cells_25/rho_0.400/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7ff67a3bcd70>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_25/rho_0.400/kT_0.400/nsteps_1000000/seed_1/randomization_log.hdf5
# Log period: 1000
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_25/rho_0.400/kT_0.400/nsteps_1000000/seed_1/randomization_log.hdf5
# Metadata group: metadata
# Saved final state
# ...

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    n_fcc_cells=25,
    target_rho=0.40,
    kT=0.40,
    nsteps=1_000_000,
    overwrite=False,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing thermalized state:
# /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_25/rho_0.400/kT_0.400/nsteps_1000000/seed_1/randomization.gsd
#
# ...
# Simulation timing
# ...
# Total time: 0.05 seconds
# Total time: 0.00 minutes
# Total time: 0.00 hours
# Speed: 21,712,239.8 steps/second

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    n_fcc_cells=20,
    target_rho=0.80,
    kT=0.80,
    nsteps=1_000_000,
    overwrite=False,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing FCC lattice:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices_v2/FCC/n_cells_20/rho_0.800/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7ff67d44bc50>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_20/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Log period: 1000
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_20/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Metadata group: metadata
# Saved final state
# GSD file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_20/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization.gsd
#
# ...
# Simulation timing
# ...
# Total time: 238.06 seconds
# Total time: 3.97 minutes
# Total time: 0.07 hours
# Speed: 4,200.6 steps/second

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    n_fcc_cells=30,
    target_rho=0.80,
    kT=0.80,
    nsteps=1_000_000,
    overwrite=False,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Loaded existing FCC lattice:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices_v2/FCC/n_cells_30/rho_0.800/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7ff67ae674d0>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_30/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Log period: 1000
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_30/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Metadata group: metadata
# Saved final state
# GSD file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_30/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization.gsd
#
# ...
# Simulation timing
# ...
# Total time: 553.66 seconds
# Total time: 9.23 minutes
# Total time: 0.15 hours
# Speed: 1,806.2 steps/second

# %%
# ============================================================
# Time get_or_make_thermalized_state
# ============================================================

import time

start_time = time.perf_counter()

result = sh.get_or_make_thermalized_state(
    n_fcc_cells=15,
    target_rho=0.80,
    kT=0.80,
    nsteps=1_000_000,
    overwrite=False,
)

end_time = time.perf_counter()

elapsed = end_time - start_time

print("\n" + "=" * 80)
print("Simulation timing")
print("=" * 80)
print(f"Total time: {elapsed:.2f} seconds")
print(f"Total time: {elapsed/60:.2f} minutes")
print(f"Total time: {elapsed/3600:.2f} hours")
print(f"Speed: {1_000_000/elapsed:,.1f} steps/second")
# Out:
# Created new FCC lattice
# ----------------------------
# n_fcc_cells = 15
# N = 13500
# Target rho = 0.8
# Actual rho = 0.8000000000000005
# Density error = 4.440892098500626e-16
# BoxLength = 25.64963920015045
# FCC cell size = 1.7099759466766966
# Saved lattice to:
# /exp/e961/data/MDsims-data/pnichols/Simple_Lattices_v2/FCC/n_cells_15/rho_0.800/lattice.gsd
# Using GPU device
# Final device: <hoomd.device.GPU object at 0x7f2c391ccd70>
# Started HDF5 logger
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_15/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Log period: 1000
# Stopped HDF5 logger
# Wrote HDF5 metadata
# Log file: /exp/e961/data/MDsims-data/pnichols/Thermalized_States_v2/FCC/n_cells_15/rho_0.800/kT_0.800/nsteps_1000000/seed_1/randomization_log.hdf5
# Metadata group: metadata
# Saved final state
# ...
