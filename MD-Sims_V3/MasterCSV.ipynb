# %%
from md_Helpers import master_csv

df30 = master_csv.build_thermalization_master_csv(
    n_fcc_cells=30,
    output_path="/exp/e961/data/MDsims-data/pnichols/Master_CSVs_v3/thermalization_master_ncells_30.csv",
)
