# %% [markdown]
# # V4 Thermalization Starter
# This notebook uses the local SQLite backend and the output root configured in `md_Helpers/paths.py`.

# %%
from md_Helpers import (
    ProjectPaths,
    SQLiteRunDatabase,
    ThermalizationConfig,
    display_thermalization_table,
    run_thermalization,
)

paths = ProjectPaths()
print("Output root:", paths.top_directory)
print("Local database:", paths.database)
# Out:
# Output root: /home/pnichols/MDsims/MDSims
# Local database: /home/pnichols/MDsims/MDSims/mdsims.sqlite3

# %%
config = ThermalizationConfig(
    n_fcc_cells=30,
    target_rho=0.7,
    nsteps=200_000,
    kT=1.0,
    log_period=100,
    seed=1,
    dt=0.005,
    epsilon_LJ=1.0,
    sigma_LJ=1.0,
    r_cut_LJ=2.5,
    buffer_LJ=0.4,
    lj_mode="xplor",
    r_on_LJ=2.0,
)

print("Run signature:", config.run_signature)
# Out:
# Run signature: c3990170f0cf5c1685de07735d1c8f4c72ebdf7b446f35b050bf318f8b909da4

# %%
result = run_thermalization(config, project_paths=paths)
result
# Out:
# {'skipped': False,
#  'created_new': True,
#  'run_id': '20260903204405',
#  'run_signature': 'c3990170f0cf5c1685de07735d1c8f4c72ebdf7b446f35b050bf318f8b909da4',
#  'status': 'Complete',
#  'directory': PosixPath('/home/pnichols/MDsims/MDSims/Thermalization/20260903204405'),
#  'trajectory_path': PosixPath('/home/pnichols/MDsims/MDSims/Thermalization/20260903204405/trajectory.gsd'),
#  'hdf5_path': PosixPath('/home/pnichols/MDsims/MDSims/Thermalization/20260903204405/run.hdf5'),
#  'phase_separation': {'phase_separated': False,
#   'status': 'Not_Separated',
#   'method': 'voxel_histogram',
#   'method_version': 'voxel_low_density_fraction_v1'},
#  'phase_fit': {'status': 'Skipped_Homogeneous',
#   'method': None,
#   'method_version': None,
#   'message': 'Voxel classification did not identify phase separation.',
#   'rho_liquid': None,
#   'rho_liquid_unc': None,
#   'rho_gas': None,
#   'rho_gas_unc': None,
#   'V_liquid': None,
#   'V_liquid_unc': None,
#   'V_gas': None,
#   'V_gas_unc': None},
#  'thermodynamic_summary': {'Summary_Start_Step': 190100,
#   'Summary_End_Step': 200000,
#   'Summary_Num_Samples': 100,
#   'Pressure_Mean': None,
#   'Pressure_Std': None,
#   'Pressure_SEM': None,
#   'PE_Per_Particle_Mean': -4.377507478133916,
#   'PE_Per_Particle_Std': 0.00241567893085031,
#   'PE_Per_Particle_SEM': 0.00024156789308503102}}

# %%
database = SQLiteRunDatabase(paths.database)
database.query_runs(Sim_Type="Thermalization")
# Out:
# [{'Run_ID': '20260903044809',
#   'Run_Signature': '6dceda56c4bee48333fd5a50e9901915d9be6f718b234aac28912b71ee7a4d4c',
#   'N_Cells': 45,
#   'Nsteps': 1000000,
#   'Current_Nstep': 1000000,
#   'ElapsedTime': 1465.0412391158752,
#   'StartTime': '2026-09-03 04:48:12.680925',
#   'EndTime': '2026-09-03 05:15:26.214064',
#   'Last_Update_Time': '2026-09-03 05:15:26.214064',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903051350',
#   'Run_Signature': 'c7cdcf0dba811becc000d4f5116f101036445f5d1542434084616e7da0eb5774',
#   'N_Cells': 30,
#   'Nsteps': 1000000,
#   'Current_Nstep': 1000000,
#   'ElapsedTime': 869.6405410429579,
#   'StartTime': '2026-09-03 05:13:52.238211',
#   'EndTime': '2026-09-03 05:29:22.927381',
#   'Last_Update_Time': '2026-09-03 05:29:22.927381',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903182125',
#   'Run_Signature': 'f47a06128da165c5b633443355088cbc77711d707f24695ab6d075d09bea95cc',
#   'N_Cells': 30,
#   'Nsteps': 10000,
#   'Current_Nstep': 10000,
#   'ElapsedTime': 4.943641804624349,
#   'StartTime': '2026-09-03 18:21:28.401184',
#   'EndTime': '2026-09-03 18:21:38.067508',
#   'Last_Update_Time': '2026-09-03 18:21:38.067508',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903182141',
#   'Run_Signature': '7a3070af6e4868d89525a38826af5a765294d62d6920a40523fbc6ccd323270a',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 230.85725369886495,
#   'StartTime': '2026-09-03 18:21:41.244037',
#   'EndTime': '2026-09-03 18:26:04.640248',
#   'Last_Update_Time': '2026-09-03 18:26:04.640248',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903184758',
#   'Run_Signature': '21e9f75930ced944b3ee1d14a45540fb9bb7e0482143c909ca356c5a162441f3',
#   'N_Cells': 30,
#   'Nsteps': 500000,
#   'Current_Nstep': 500000,
#   'ElapsedTime': 232.27146689011715,
#   'StartTime': '2026-09-03 18:47:58.674230',
#   'EndTime': '2026-09-03 18:52:23.205803',
#   'Last_Update_Time': '2026-09-03 18:52:23.205803',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903194250',
#   'Run_Signature': '04bf75abe357e0c29ab63afb74599c39801a45673d53f6bbedadfd4fa9085d01',
#   'N_Cells': 30,
#   'Nsteps': 100000,
#   'Current_Nstep': 100000,
#   'ElapsedTime': 177.86421099613653,
#   'StartTime': '2026-09-03 19:42:52.064354',
#   'EndTime': '2026-09-03 19:45:57.626881',
#   'Last_Update_Time': '2026-09-03 19:45:57.626881',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903194254',
#   'Run_Signature': '3ecb3c851079c90ebf5c603549f50566ed09be6f201e6495e72b75f853784ef5',
#   'N_Cells': 30,
#   'Nsteps': 100000,
#   'Current_Nstep': 100000,
#   'ElapsedTime': 46.85960826976225,
#   'StartTime': '2026-09-03 19:42:54.701068',
#   'EndTime': '2026-09-03 19:43:49.331384',
#   'Last_Update_Time': '2026-09-03 19:43:49.331384',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903194402',
#   'Run_Signature': 'c7315908d06559362ba3c5e496848866ddbfc338736ccaa788273cb88d937fa4',
#   'N_Cells': 30,
#   'Nsteps': 100000,
#   'Current_Nstep': 100000,
#   'ElapsedTime': 49.27216264093295,
#   'StartTime': '2026-09-03 19:44:02.731208',
#   'EndTime': '2026-09-03 19:44:59.921464',
#   'Last_Update_Time': '2026-09-03 19:44:59.921464',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903202814',
#   'Run_Signature': '5059e3bc8da08e6fa338ae61c628e8de9d44bd588c7566fe1fe7835ea65b5d77',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 97.08675846992992,
#   'StartTime': '2026-09-03 20:28:14.373284',
#   'EndTime': '2026-09-03 20:30:06.387490',
#   'Last_Update_Time': '2026-09-03 20:30:06.387490',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903203452',
#   'Run_Signature': 'eb73e0628a21f7725c46ff636edea12781e0807a0b065ef5ac900e4da9c3ab05',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 96.9629849884659,
#   'StartTime': '2026-09-03 20:34:52.124717',
#   'EndTime': '2026-09-03 20:36:58.353199',
#   'Last_Update_Time': '2026-09-03 20:36:58.353199',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None},
#  {'Run_ID': '20260903204405',
#   'Run_Signature': 'c3990170f0cf5c1685de07735d1c8f4c72ebdf7b446f35b050bf318f8b909da4',
#   'N_Cells': 30,
#   'Nsteps': 200000,
#   'Current_Nstep': 200000,
#   'ElapsedTime': 96.792999134399,
#   'StartTime': '2026-09-03 20:44:05.833806',
#   'EndTime': '2026-09-03 20:48:06.356281',
#   'Last_Update_Time': '2026-09-03 20:48:06.356281',
#   'Sim_Type': 'Thermalization',
#   'Status': 'Complete',
#   'Stop_Reason': None,
#   'Status_Message': None,
#   'Notes': None}]

# %%
# No filters displays the entire Thermalization table.
display_thermalization_table(database)
# Out:
# <style type="text/css">
# #T_bbd87 th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_bbd87_row0_col0, #T_bbd87_row0_col1, #T_bbd87_row0_col2, #T_bbd87_row0_col14, #T_bbd87_row0_col19, #T_bbd87_row0_col20, #T_bbd87_row0_col21, #T_bbd87_row0_col22, #T_bbd87_row0_col31, #T_bbd87_row0_col32, #T_bbd87_row0_col33, #T_bbd87_row1_col0, #T_bbd87_row1_col1, #T_bbd87_row1_col2, #T_bbd87_row1_col14, #T_bbd87_row1_col19, #T_bbd87_row1_col20, #T_bbd87_row1_col21, #T_bbd87_row1_col22, #T_bbd87_row1_col31, #T_bbd87_row1_col32, #T_bbd87_row1_col33, #T_bbd87_row2_col0, #T_bbd87_row2_col1, #T_bbd87_row2_col2, #T_bbd87_row2_col14, #T_bbd87_row2_col19, #T_bbd87_row2_col20, #T_bbd87_row2_col21, #T_bbd87_row2_col22, #T_bbd87_row2_col31, #T_bbd87_row2_col32, #T_bbd87_row2_col33, #T_bbd87_row3_col0, #T_bbd87_row3_col1, #T_bbd87_row3_col2, #T_bbd87_row3_col14, #T_bbd87_row3_col19, #T_bbd87_row3_col20, #T_bbd87_row3_col21, #T_bbd87_row3_col22, #T_bbd87_row3_col31, #T_bbd87_row3_col32, #T_bbd87_row3_col33, #T_bbd87_row4_col0, #T_bbd87_row4_col1, #T_bbd87_row4_col2, #T_bbd87_row4_col14, #T_bbd87_row4_col19, #T_bbd87_row4_col20, #T_bbd87_row4_col21, #T_bbd87_row4_col22, #T_bbd87_row4_col31, #T_bbd87_row4_col32, #T_bbd87_row4_col33, #T_bbd87_row5_col0, #T_bbd87_row5_col1, #T_bbd87_row5_col2, #T_bbd87_row5_col14, #T_bbd87_row5_col19, #T_bbd87_row5_col20, #T_bbd87_row5_col21, #T_bbd87_row5_col22, #T_bbd87_row5_col
_col5, #T_bbd87_row5_col6, #T_bbd87_row5_col7, #T_bbd87_row5_col8, #T_bbd87_row5_col9, #T_bbd87_row5_col10, #T_bbd87_row5_col11, #T_bbd87_row5_col12, #T_bbd87_row5_col13, #T_bbd87_row5_col15, #T_bbd87_row5_col16, #T_bbd87_row5_col17, #T_bbd87_row5_col18, #T_bbd87_row5_col23, #T_bbd87_row5_col24, #T_bbd87_row5_col25, #T_bbd87_row5_col26, #T_bbd87_row5_col27, #T_bbd87_row5_col28, #T_bbd87_row5_col29, #T_bbd87_row5_col30, #T_bbd87_row5_col34, #T_bbd87_row5_col35, #T_bbd87_row5_col36, #T_bbd87_row5_col37, #T_bbd87_r ...
#            Run_ID                  File_Location Clone_Run_ID Clone_Frame_ID  \
# 0  20260903044809  Thermalization/20260903044809         None           None
# 1  20260903051350  Thermalization/20260903051350         None           None
# 2  20260903182125  Thermalization/20260903182125         None           None
# 3  20260903182141  Thermalization/20260903182141         None           None
# 4  20260903184758  Thermalization/20260903184758         None           None
# 5  20260903194250  Thermalization/20260903194250         None           None
# 6  20260903194254  Thermalization/20260903194254         None           None
# 7  20260903194402  Thermalization/20260903194402         None           None
# 8  20260903202814  Thermalization/20260903202814         None           None
# 9  20260903203452  Thermalization/20260903203452         None           None
#
#    Therm_kT  Therm_Seed  Density_Start  Density_End  BoxLength_Start  \
# 0       0.9           1            0.5          0.5             90.0
# 1       0.9           1            0.5          0.5             60.0
# 2       0.9           1            0.5          0.5             60.0
# 3       0.9           1            0.5          0.5             60.0
# 4       0.9           1            0.6          0.6        56.462162
# 5       0.9           1            0.7          0.7        53.634212
# 6       0.9           1           0.65         0.65         54.97562
# 7       0.9           1           0.75         0.75        52.414828
# 8       1.0           1            0.7          0.7        53.634212
# 9       1.0           1            0.7          0.7        53.634212
#
#    BoxLength_End  ...  Summary_Start_Step  Summary_End_Step  \
# 0           90.0  ...              901000           1000000
# 1           60.0  ...              901000           1000000
# 2           60.0  ...                   0             10000
# 3           60.0  ...              401000            500000
# 4      56.462162  ...              401000            500000
# 5      53.634212  ...                1000            100000
# 6       54.97562  ...                1000            100000
# 7      52.414828  ...                1000            100000
# 8      53.634212  ...              101000            200000
# 9      53.634212  ...              150500            200000
#
#    Summary_Num_Samples  Pressure_Mean Pressure_Std  Pressure_SEM  \
# 0                  100           None         None          None
# 1                  100           None         None          None
# 2                   11           None         None          None
# 3                  100           None         None          None
# 4                  100           None         None          None
# 5                  100           None         None          None
# 6                  100           None         None          None
# 7                  100           None         None          None
# 8                  100           None         None          None
# 9                  100           None         None          None
#
#   PE_Per_Particle_Mean  PE_Per_Particle_Std  PE_Per_Particle_SEM Num_Frames
# 0            -4.256506             0.003409             0.000341       1001
# 1            -4.230416             0.005652             0.000565       1001
# 2            -3.685286             0.351868             0.106092         11
# 3              -4.2314             0.005632             0.000563        501
# 4            -4.297407             0.006246             0.000625        501
# 5            -4.448007             0.002213             0.000221        101
# 6            -4.145777             0.002311             0.000231        101
# 7            -4.754569             0.002176             0.000218        101
# 8            -4.377949              0.00261             0.000261        201
# 9             -4.37794             0.002266             0.000227        401
#
# [10 rows x 44 columns]

# %%
# Scalars are exact matches, tuples are inclusive ranges, and lists
# contain any acceptable value. Set limit=None to return every match.
matches = display_thermalization_table(
    database,
    limit=100,
    Therm_kT=(0.85, 0.95),
    Density_End=(0.5, 0.65),
    Nsteps=[10_000, 100_000, 500_000, 1_000_000],
    Phase_Separation_Status="Separated",
)
matches
# Out:
# <style type="text/css">
# #T_0d2fc th {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_0d2fc_row0_col0, #T_0d2fc_row0_col1, #T_0d2fc_row0_col2, #T_0d2fc_row0_col14, #T_0d2fc_row0_col19, #T_0d2fc_row0_col20, #T_0d2fc_row0_col21, #T_0d2fc_row0_col22, #T_0d2fc_row0_col31, #T_0d2fc_row0_col32, #T_0d2fc_row0_col33, #T_0d2fc_row1_col0, #T_0d2fc_row1_col1, #T_0d2fc_row1_col2, #T_0d2fc_row1_col14, #T_0d2fc_row1_col19, #T_0d2fc_row1_col20, #T_0d2fc_row1_col21, #T_0d2fc_row1_col22, #T_0d2fc_row1_col31, #T_0d2fc_row1_col32, #T_0d2fc_row1_col33, #T_0d2fc_row2_col0, #T_0d2fc_row2_col1, #T_0d2fc_row2_col2, #T_0d2fc_row2_col14, #T_0d2fc_row2_col19, #T_0d2fc_row2_col20, #T_0d2fc_row2_col21, #T_0d2fc_row2_col22, #T_0d2fc_row2_col31, #T_0d2fc_row2_col32, #T_0d2fc_row2_col33, #T_0d2fc_row3_col0, #T_0d2fc_row3_col1, #T_0d2fc_row3_col2, #T_0d2fc_row3_col14, #T_0d2fc_row3_col19, #T_0d2fc_row3_col20, #T_0d2fc_row3_col21, #T_0d2fc_row3_col22, #T_0d2fc_row3_col31, #T_0d2fc_row3_col32, #T_0d2fc_row3_col33, #T_0d2fc_row4_col0, #T_0d2fc_row4_col1, #T_0d2fc_row4_col2, #T_0d2fc_row4_col14, #T_0d2fc_row4_col19, #T_0d2fc_row4_col20, #T_0d2fc_row4_col21, #T_0d2fc_row4_col22, #T_0d2fc_row4_col31, #T_0d2fc_row4_col32, #T_0d2fc_row4_col33 {
#   text-align: left;
#   white-space: nowrap;
# }
# #T_0d2fc_row0_col3, #T_0d2fc_row0_col4, #T_0d2fc_row0_col5, #T_0d2fc_row0_col6, #T_0d2fc_row0_col7, #T_0d2fc_row0_col8, #T_0d2fc_row0_col9, #T_0d2fc_row0_col10, #T_0d2fc_row0_col11, #T_0d2fc_row0_col12, #T_0d2fc_row0_col13, #T_0d2fc_row0_col15, #T_0d2fc_row0_col16, #T_0d2fc_row0_col17, #T_0d2fc_row0_col18, #T_0d2fc_row0_col23, #T_0d2fc_row0_col24, #T_0d2fc_row0_col25, #T_0d2fc_row0_col26, #T_0d2fc_row0_col27, #T_0d2fc_row0_col28, #T_0d2fc_row0_col29, #T_0d2fc_row0_col30, #T_0d2fc_row0_col34, #T_0d2fc_row0_col35, #T_0d2fc_row0_col36, #
37, #T_0d2fc_row3_col38, #T_0d2fc_row3_col39, #T_0d2fc_row3_col40, #T_0d2fc_row3_col41, #T_0d2fc_row3_col42, #T_0d2fc_row3_col43, #T_0d2fc_row4_col3, #T_0d2fc_row4_col4, #T_0d2fc_row4_col5, #T_0d2fc_row4_col6, #T_0d2fc_row4_col7, #T_0d2fc_row4_col8, #T_0d2fc_row4_col9, #T_0d2fc_row4_col10, #T_0d2fc_row4_col11, #T_0d2fc_row4_col12, #T_0d2fc_row4_col13, #T_0d2fc_row4_col15, #T_0d2fc_row4_col16, #T_0d2fc_row4_col17, #T_0d2fc_row4_col18, #T_0d2fc_row4_col23, #T_0d2fc_row4_col24, #T_0d2fc_row4_col25, #T_0d2fc_row4_col26, #T_0d2fc_row4_col27, #T_0d2fc_row4_col28, #T_0d2fc_row4_col29, #T_0d2fc_row4_col30, #T_0d2fc_row4_col34, #T_0d2fc_row4_col35, #T_0d2fc_row4_col36, #T_0d2fc_row4_col37, #T_0d2fc_row4_col38, #T_0d2fc_row4_col39, #T_0d2fc_row4_col40, #T_0d2fc_row4_col41, #T_0d2fc_row4_col42, #T_0d2fc_row4_col43 {
#   text-align: right;
#   white-space: nowrap;
# }
# </style>
# <table id="T_0d2fc">
#   <thead>
#     <tr>
#       <th id="T_0d2fc_level0_col0" class="col_heading level0 col0" >Run_ID</th>
#       <th id="T_0d2fc_level0_col1" class="col_heading level0 col1" >File_Location</th>
#       <th id="T_0d2fc_level0_col2" class="col_heading level0 col2" >Clone_Run_ID</th>
#       <th id="T_0d2fc_level0_col3" class="col_heading level0 col3" >Clone_Frame_ID</th>
#       <th id="T_0d2fc_level0_col4" class="col_heading level0 col4" >Therm_kT</th>
#       <th id="T_0d2fc_level0_col5" class="col_heading level0 col5" >Therm_Seed</th>
#       <th id="T_0d2fc_level0_col6" class="col_heading level0 col6" >Density_Start</th>
#       <th id="T_0d2fc_level0_col7" class="col_heading level0 col7" >Density_End</th>
#       <th id="T_0d2fc_level0_col8" class="col_heading level0 col8" >BoxLength_Start</th>
#       <th id="T_0d2fc_level0_col9" class="col_heading level0 col9" >BoxLength_End</th>
#       <th id="T_0d2fc_level0_col10" class="col_heading level0 col10" >dt</th>
#       <th id="T_0d2fc_level0_col11" class="col_heading level0 col11" >Nsteps</th>
#       <th id="T_0d2fc_level0_col12" class="col_heading level0 col12" >This_LJ_Time</th>
#       <th id="T_0d2fc_level0_col13" class="col_heading level0 col13" >Cumulative_LJ_Time</th>
#       <th id="T_0d2fc_level0_col14" class="col_heading level0 col14" >Ensemble</th>
#       <th id="T_0d2fc_level0_col15" class="col_heading level0 col15" >T_Set</th>
#       <th id="T_0d2fc_level0_col16" class="col_heading level0 col16" >P_Set</th>
#       <th id="T_0d2fc_level0_col17" class="col_heading level0 col17" >LJ_r_cut</th>
#       <th id="T_0d2fc_level0_col18" class="col_heading level0 col18" >LJ_r_on</th>
#       <th id="T_0d2fc_level0_col19" class="col_heading level0 col19" >LJ_Mode</th>
#       <th id="T_0d2fc_level0_col20" class="col_heading level0 col20" >Phase_Separation_Status</th>
#       <th id="T_0d2fc_level0_col21" class="col_heading level0 col21" >Phase_Separation_Method</th>
#       <th id="T_0d2fc_level0_col22" class="col_heading level0 col22" >Phase_Separation_Method_Version</th>
#       <th id="T_0d2fc_level0_col23" class="col_heading level0 col23" >rho_liquid</th>
#       <th id="T_0d2fc_level0_col24" class="col_heading level0 col24" >rho_liquid_unc</th>
#       <th id="T_0d2fc_level0_col25" class="col_heading level0 col25" >rho_gas</th>
#       <th id="T_0d2fc_level0_col26" class="col_heading level0 col26" >rho_gas_unc</th>
#       <th id="T_0d2fc_level0_col27" class="col_heading level0 col27" >V_liquid</th>
#       <th id="T_0d2fc_level0_col28" class="col_heading level0 col28" >V_liquid_unc</th>
#       <th id="T_0d2fc_level0_col29" class="col_heading level0 col29" >V_gas</th>
#       <th id="T_0d2fc_level0_col30" class="col_heading level0 col30" >V_gas_unc</th>
#       <th id="T_0d2fc_level0_col31" class="col_heading level0 col31" >Phase_Fit_Status</th>
#       <th id="T_0d2fc_level0_col32" class="col_heading level0 col32" >Phase_Fit_Method</th>
#       <th id="T_0d2fc_level0_col33" class="col_heading level0 col33" >Phase_Fit_Method_Version</th>
#       <th id="T_0d2fc_level0_col34" class="col_heading level0 col34" >Summary_Start_Step</th>
#       <th id="T_0d2fc_level0_col35" class="col_heading level0 col35" >Summary_End_Step</th>
#       <th id="T_0d2fc_level0_col36" class="col_headin
#            Run_ID                  File_Location Clone_Run_ID Clone_Frame_ID  \
# 0  20260903044809  Thermalization/20260903044809         None           None
# 1  20260903051350  Thermalization/20260903051350         None           None
# 2  20260903182125  Thermalization/20260903182125         None           None
# 3  20260903182141  Thermalization/20260903182141         None           None
# 4  20260903184758  Thermalization/20260903184758         None           None
#
#    Therm_kT  Therm_Seed  Density_Start  Density_End  BoxLength_Start  \
# 0       0.9           1            0.5          0.5             90.0
# 1       0.9           1            0.5          0.5             60.0
# 2       0.9           1            0.5          0.5             60.0
# 3       0.9           1            0.5          0.5             60.0
# 4       0.9           1            0.6          0.6        56.462162
#
#    BoxLength_End  ...  Summary_Start_Step  Summary_End_Step  \
# 0           90.0  ...              901000           1000000
# 1           60.0  ...              901000           1000000
# 2           60.0  ...                   0             10000
# 3           60.0  ...              401000            500000
# 4      56.462162  ...              401000            500000
#
#    Summary_Num_Samples  Pressure_Mean Pressure_Std  Pressure_SEM  \
# 0                  100           None         None          None
# 1                  100           None         None          None
# 2                   11           None         None          None
# 3                  100           None         None          None
# 4                  100           None         None          None
#
#   PE_Per_Particle_Mean  PE_Per_Particle_Std  PE_Per_Particle_SEM Num_Frames
# 0            -4.256506             0.003409             0.000341       1001
# 1            -4.230416             0.005652             0.000565       1001
# 2            -3.685286             0.351868             0.106092         11
# 3              -4.2314             0.005632             0.000563        501
# 4            -4.297407             0.006246             0.000625        501
#
# [5 rows x 44 columns]
