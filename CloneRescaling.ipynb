# %%
# Thermostat-free box resizing (NVE particle dynamics)
from md_Helpers import run_clone_rescale_ensemble

nve_result = run_clone_rescale_ensemble(
    source_run_id="20260909155510",
    final_density=0.64,  # Above source rho = compression; below = expansion
    nsteps=200_000,
    ensemble="NVE",
    notes="",
)

nve_result['existing_run']['Nsteps']
# Out:
# 200000
