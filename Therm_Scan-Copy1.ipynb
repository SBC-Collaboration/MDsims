# %%
import numpy as np
import pandas as pd

from md_Helpers import (
    ThermalizationConfig,
    run_thermalization,
)


# ============================================================
# Scan ranges — endpoints are included
# ============================================================

kT_values = np.round(
    np.arange(0.7, 1.0 + 0.01, 0.02),
    decimals=10,
)

rho_values = np.round(
    np.arange(0.5, 0.6 + 0.01, 0.02),
    decimals=10,
)


# ============================================================
# Core thermalization settings
# ============================================================

n_cells = 40
nsteps = 100_000
dt = 0.002

# HDF5 log interval in simulation steps.
nlog = 1_000

seed = 1



# ============================================================
# Execution controls
# ============================================================

base_notes = (
    "Thermalization grid scan over temperature and density"
)

# If True, immediately stop when any grid point fails.
# If False, record the failure and continue through the grid.
stop_on_error = False


# ============================================================
# Validate the requested grid before starting
# ============================================================

if len(kT_values) == 0:
    raise ValueError("kT_values cannot be empty.")

if len(rho_values) == 0:
    raise ValueError("rho_values cannot be empty.")

if np.any(kT_values <= 0):
    raise ValueError("Every kT value must be positive.")

if np.any(rho_values <= 0):
    raise ValueError("Every density must be positive.")

if n_cells <= 0:
    raise ValueError("n_cells must be positive.")

if nsteps <= 0:
    raise ValueError("nsteps must be positive.")

if nlog <= 0:
    raise ValueError("nlog must be positive.")

if dt <= 0:
    raise ValueError("dt must be positive.")

# The workflow requires at least 41 evolved log points for
# its five terminal phase-analysis frames.
number_of_evolved_logs = int(np.ceil(nsteps / nlog))

if number_of_evolved_logs < 41:
    raise ValueError(
        "This workflow requires at least 41 evolved log points. "
        f"The current settings provide only "
        f"{number_of_evolved_logs}. Increase nsteps or reduce nlog."
    )

number_of_runs = len(kT_values) * len(rho_values)
number_of_particles = 4 * n_cells**3

print("Thermalization scan")
print(f"  kT values:       {kT_values.tolist()}")
print(f"  density values:  {rho_values.tolist()}")
print(f"  grid size:       {number_of_runs} runs")
print(f"  particles/run:   {number_of_particles:,}")
print(f"  steps/run:       {nsteps:,}")
print(f"  dt:              {dt:g}")
print(f"  log period:      {nlog:,}")
print()


# ============================================================
# Run every kT-density combination
# ============================================================

results = []
scan_index = 0

for kT in kT_values:
    for rho in rho_values:
        scan_index += 1

        kT = float(kT)
        rho = float(rho)

        print(
            f"[{scan_index:>2}/{number_of_runs}] "
            f"Starting kT={kT:.3f}, rho={rho:.3f}"
        )

        config = ThermalizationConfig(
            n_fcc_cells=n_cells,
            target_rho=rho,
            nsteps=nsteps,
            kT=kT,
            dt=dt,
            log_period=nlog,
            seed=seed,
        )

        try:
            result = run_thermalization(config)

            created_new = bool(
                result.get("created_new", False)
            )
            skipped = bool(result.get("skipped", False))

            if created_new:
                action = "created"
            elif skipped:
                action = "reused"
            else:
                action = "returned"

            print(
                f"    {action}: "
                f"Run_ID={result['run_id']}, "
                f"status={result.get('status', 'unknown')}"
            )

            results.append({
                "scan_index": scan_index,
                "kT": kT,
                "rho": rho,
                "run_id": result["run_id"],
                "action": action,
                "status": result.get("status"),
                "created_new": created_new,
                "skipped_existing": skipped,
                "run_signature": result.get(
                    "run_signature"
                ),
                "error": None,
            })

        except Exception as error:
            print(
                f"    FAILED: "
                f"{type(error).__name__}: {error}"
            )

            results.append({
                "scan_index": scan_index,
                "kT": kT,
                "rho": rho,
                "run_id": None,
                "action": "failed",
                "status": "Failed",
                "created_new": False,
                "skipped_existing": False,
                "run_signature": config.run_signature,
                "error": (
                    f"{type(error).__name__}: {error}"
                ),
            })

            if stop_on_error:
                raise


# ============================================================
# Display the completed scan
# ============================================================

thermalization_scan = (
    pd.DataFrame(results)
    .sort_values(["kT", "rho"])
    .reset_index(drop=True)
)

print()
print("Thermalization scan results:")
display(thermalization_scan)

print()
print("Run-ID grid:")

run_id_grid = thermalization_scan.pivot(
    index="kT",
    columns="rho",
    values="run_id",
)

display(run_id_grid)

failed_runs = thermalization_scan.loc[
    thermalization_scan["action"] == "failed"
]

if failed_runs.empty:
    print(
        f"All {number_of_runs} grid points completed "
        "or reused an existing matching run."
    )
else:
    print(
        f"{len(failed_runs)} of {number_of_runs} "
        "grid points failed:"
    )
    display(
        failed_runs[
            ["kT", "rho", "error"]
        ]
    )
# Out:
# Thermalization scan
#   kT values:       [0.7, 0.72, 0.74, 0.76, 0.78, 0.8, 0.82, 0.84, 0.86, 0.88, 0.9, 0.92, 0.94, 0.96, 0.98, 1.0]
#   density values:  [0.5, 0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.68, 0.7, 0.72, 0.74, 0.76, 0.78, 0.8]
#   grid size:       256 runs
#   particles/run:   108,000
#   steps/run:       100,000
#   dt:              0.002
#   log period:      1,000
#
# [ 1/256] Starting kT=0.700, rho=0.500
#     created: Run_ID=20260914191900, status=Complete
# [ 2/256] Starting kT=0.700, rho=0.520
#     reused: Run_ID=20260914191909, status=Running
# [ 3/256] Starting kT=0.700, rho=0.540
#     created: Run_ID=20260914191959, status=Complete
# [ 4/256] Starting kT=0.700, rho=0.560
#     reused: Run_ID=20260914192054, status=Running
# [ 5/256] Starting kT=0.700, rho=0.580
#     created: Run_ID=20260914192101, status=Complete
# [ 6/256] Starting kT=0.700, rho=0.600
#     created: Run_ID=20260914192200, status=Complete
# [ 7/256] Starting kT=0.700, rho=0.620
#     reused: Run_ID=20260914192238, status=Running
# [ 8/256] Starting kT=0.700, rho=0.640
#     created: Run_ID=20260914192259, status=Complete
# [ 9/256] Starting kT=0.700, rho=0.660
#     created: Run_ID=20260914192359, status=Complete
# [10/256] Starting kT=0.700, rho=0.680
#     reused: Run_ID=20260914192421, status=Running
# [11/256] Starting kT=0.700, rho=0.700
#     created: Run_ID=20260914192501, status=Complete
# [12/256] Starting kT=0.700, rho=0.720
#     created: Run_ID=20260914192602, status=Complete
# [13/256] Starting kT=0.700, rho=0.740
#     reused: Run_ID=20260914192607, status=Running
# [14/256] Starting kT=0.700, rho=0.760
#     created: Run_ID=20260914192705, status=Complete
# [15/256] Starting kT=0.700, rho=0.780
#     reused: Run_ID=20260914192752, status=Running
# [16/256] Starting kT=0.700, rho=0.800
#     created: Run_ID=20260914192802, status=Complete
# [17/256] Starting kT=0.720, rho=0.500
#     created: Run_ID=20260914192905, status=Complete
# [18/256] Starting kT=0.720, rho=0.520
#     reused: Run_ID=20260914192937, status=Running
# [19/256] Starting kT=0.720, rho=0.540
#     created: Run_ID=20260914193003, status=Complete
# [20/256] Starting kT=0.720, rho=0.560
#     created: Run_ID=20260914193105, status=Complete
# [21/256] Starting kT=0.720, rho=0.580
#     reused: Run_ID=20260914193118, status=Running
# [22/256] Starting kT=0.720, rho=0.600
#     created: Run_ID=20260914193204, status=Complete
# [23/256] Starting kT=0.720, rho=0.620
#     reused: Run_ID=20260914193301, status=Running
# [24/256] Starting kT=0.720, rho=0.640
#     created: Run_ID=20260914193302, status=Complete
# [25/256] Starting kT=0.720, rho=0.660
#     created: Run_ID=20260914193401, status=Complete
# [26/256] Starting kT=0.720, rho=0.680
#     reused: Run_ID=20260914193444, status=Running
# [27/256] Starting kT=0.720, rho=0.700
#     created: Run_ID=20260914193501, status=Complete
# [28/256] Starting kT=0.720, rho=0.720
#     created: Run_ID=20260914193600, status=Complete
# [29/256] Starting kT=0.720, rho=0.740
#     reused: Run_ID=20260914193630, status=Running
# [30/256] Starting kT=0.720, rho=0.760
#     created: Run_ID=20260914193700, status=Complete
# [31/256] Starting kT=0.720, rho=0.780
#     created: Run_ID=20260914193756, status=Complete
# [32/256] Starting kT=0.720, rho=0.800
#     reused: Run_ID=20260914193809, status=Running
# [33/256] Starting kT=0.740, rho=0.500
#     created: Run_ID=20260914193854, status=Complete
# [34/256] Starting kT=0.740, rho=0.520
#     created: Run_ID=20260914193954, status=Complete
# [35/256] Starting kT=0.740, rho=0.540
#     reused: Run_ID=20260914193956, status=Running
# [36/256] Starting kT=0.740, rho=0.560
#     created: Run_ID=20260914194055, status=Complete
# [37/256] Starting kT=0.740, rho=0.580
#     reused: Run_ID=20260914194136, status=Running
# [38/256] Starting kT=0.740, rho=0.600
#     created: Run_ID=20260914194154, status=Complete
# [39/256] Starting kT=0.740, rho=0.620
#     created: Run_ID=20260914194253, status=Complete
# [40/256] Starting kT=0.740, rho=0.640
#     reused: Run_ID=20260914194320, status=Running
# [41/256] Starting kT=0.740, rho=0.660
#     created: Run_ID=20260914194350, status=Complete
# [42/256] Starting kT=0.740, rho=0.680
#     created: Run_ID=20260914194448, status=Complete
# [43/256] Starting kT=0.740, rho=0.700
#     reused: Run_ID=20260914194501, status=Running
# [44/256] Starting kT=0.740, rho=0.720
#     created: Run_ID=20260914194548, status=Complete
# [45/256] Starting kT=0.740, rho=0.740
#     reused: Run_ID=20260914194647, status=Running
# [46/256] Starting kT=0.740, rho=0.760
#     created: Run_ID=20260914194648, status=Complete
# [47/256] Starting kT=0.740, rho=0.780
#     created: Run_ID=20260914194745, status=Complete
# [48/256] Starting kT=0.740, rho=0.800
#     reused: Run_ID=20260914194826, status=Running
# [49/256] Starting kT=0.760, rho=0.500
#     created: Run_ID=20260914194843, status=Complete
# [50/256] Starting kT=0.760, rho=0.520
#     created: Run_ID=20260914194942, status=Complete
# [51/256] Starting kT=0.760, rho=0.540
#     reused: Run_ID=20260914195010, status=Running
# [52/256] Starting kT=0.760, rho=0.560
#     created: Run_ID=20260914195042, status=Complete
# [53/256] Starting kT=0.760, rho=0.580
#     created: Run_ID=20260914195138, status=Complete
# [54/256] Starting kT=0.760, rho=0.600
#     reused: Run_ID=20260914195150, status=Running
# [55/256] Starting kT=0.760, rho=0.620
#     created: Run_ID=20260914195236, status=Complete
# [56/256] Starting kT=0.760, rho=0.640
#     created: Run_ID=20260914195333, status=Complete
# [57/256] Starting kT=0.760, rho=0.660
#     reused: Run_ID=20260914195334, status=Running
# [58/256] Starting kT=0.760, rho=0.680
#     created: Run_ID=20260914195432, status=Complete
# [59/256] Starting kT=0.760, rho=0.700
#     reused: Run_ID=20260914195521, status=Running
# [60/256] Starting kT=0.760, rho=0.720
#     created: Run_ID=20260914195530, status=Complete
# [61/256] Starting kT=0.760, rho=0.740
#     created: Run_ID=20260914195625, status=Complete
# [62/256] Starting kT=0.760, rho=0.760
#     reused: Run_ID=20260914195703, status=Running
# [63/256] Starting kT=0.760, rho=0.780
#     created: Run_ID=20260914195719, status=Complete
# [64/256] Starting kT=0.760, rho=0.800
#     created: Run_ID=20260914195817, status=Complete
# [65/256] Starting kT=0.780, rho=0.500
#     reused: Run_ID=20260914195845, status=Running
# [66/256] Starting kT=0.780, rho=0.520
#     created: Run_ID=20260914195916, status=Complete
# [67/256] Starting kT=0.780, rho=0.540
#     created: Run_ID=20260914200011, status=Complete
# [68/256] Starting kT=0.780, rho=0.560
#     reused: Run_ID=20260914200030, status=Running
# [69/256] Starting kT=0.780, rho=0.580
#     created: Run_ID=20260914200109, status=Complete
# [70/256] Starting kT=0.780, rho=0.600
#     created: Run_ID=20260914200205, status=Complete
# [71/256] Starting kT=0.780, rho=0.620
#     reused: Run_ID=20260914200210, status=Running
# [72/256] Starting kT=0.780, rho=0.640
#     created: Run_ID=20260914200303, status=Complete
# [73/256] Starting kT=0.780, rho=0.660
#     reused: Run_ID=20260914200351, status=Running
# [74/256] Starting kT=0.780, rho=0.680
#     created: Run_ID=20260914200359, status=Complete
# [75/256] Starting kT=0.780, rho=0.700
#     created: Run_ID=20260914200456, status=Complete
# [76/256] Starting kT=0.780, rho=0.720
#     reused: Run_ID=20260914200533, status=Running
# [77/256] Starting kT=0.780, rho=0.740
#     created: Run_ID=20260914200554, status=Complete
# [78/256] Starting kT=0.780, rho=0.760
#     created: Run_ID=20260914200650, status=Complete
# [79/256] Starting kT=0.780, rho=0.780
#     reused: Run_ID=20260914200713, status=Running
# [80/256] Starting kT=0.780, rho=0.800
#     created: Run_ID=20260914200749, status=Complete
# [81/256] Starting kT=0.800, rho=0.500
#     created: Run_ID=20260914200847, status=Complete
# [82/256] Starting kT=0.800, rho=0.520
#     reused: Run_ID=20260914200858, status=Running
# [83/256] Starting kT=0.800, rho=0.540
#     created: Run_ID=20260914200946, status=Complete
# [84/256] Starting kT=0.800, rho=0.560
#     reused: Run_ID=20260914201038, status=Running
# [85/256] Starting kT=0.800, rho=0.580
#     created: Run_ID=20260914201043, status=Complete
# [86/256] Starting kT=0.800, rho=0.600
#     created: Run_ID=20260914201141, status=Complete
# [87/256] Starting kT=0.800, rho=0.620
#     reused: Run_ID=20260914201219, status=Running
# [88/256] Starting kT=0.800, rho=0.640
#     created: Run_ID=20260914201237, status=Complete
# [89/256] Starting kT=0.800, rho=0.660
#     created: Run_ID=20260914201335, status=Complete
# [90/256] Starting kT=0.800, rho=0.680
#     reused: Run_ID=20260914201401, status=Running
# [91/256] Starting kT=0.800, rho=0.700
#     created: Run_ID=20260914201433, status=Complete
# [92/256] Starting kT=0.800, rho=0.720
#     created: Run_ID=20260914201527, status=Complete
# [93/256] Starting kT=0.800, rho=0.740
#     reused: Run_ID=20260914201543, status=Running
# [94/256] Starting kT=0.800, rho=0.760
#     created: Run_ID=20260914201621, status=Complete
# [95/256] Starting kT=0.800, rho=0.780
#     created: Run_ID=20260914201718, status=Complete
# [96/256] Starting kT=0.800, rho=0.800
#     reused: Run_ID=20260914201725, status=Running
# [97/256] Starting kT=0.820, rho=0.500
#     created: Run_ID=20260914201815, status=Complete
# [98/256] Starting kT=0.820, rho=0.520
#     reused: Run_ID=20260914201910, status=Running
# [99/256] Starting kT=0.820, rho=0.540
#     created: Run_ID=20260914201912, status=Complete
# [100/256] Starting kT=0.820, rho=0.560
#     created: Run_ID=20260914202008, status=Complete
# [101/256] Starting kT=0.820, rho=0.580
#     reused: Run_ID=20260914202049, status=Running
# [102/256] Starting kT=0.820, rho=0.600
#     created: Run_ID=20260914202106, status=Complete
# [103/256] Starting kT=0.820, rho=0.620
#     created: Run_ID=20260914202202, status=Complete
# [104/256] Starting kT=0.820, rho=0.640
#     reused: Run_ID=20260914202229, status=Running
# [105/256] Starting kT=0.820, rho=0.660
#     created: Run_ID=20260914202259, status=Complete
# [106/256] Starting kT=0.820, rho=0.680
#     created: Run_ID=20260914202357, status=Complete
# [107/256] Starting kT=0.820, rho=0.700
#     reused: Run_ID=20260914202409, status=Running
# [108/256] Starting kT=0.820, rho=0.720
#     created: Run_ID=20260914202457, status=Complete
# [109/256] Starting kT=0.820, rho=0.740
#     reused: Run_ID=20260914202546, status=Running
# [110/256] Starting kT=0.820, rho=0.760
#     created: Run_ID=20260914202552, status=Complete
# [111/256] Starting kT=0.820, rho=0.780
#     created: Run_ID=20260914202649, status=Complete
# [112/256] Starting kT=0.820, rho=0.800
#     reused: Run_ID=20260914202727, status=Running
# [113/256] Starting kT=0.840, rho=0.500
#     created: Run_ID=20260914202747, status=Complete
# [114/256] Starting kT=0.840, rho=0.520
#     created: Run_ID=20260914202844, status=Complete
# [115/256] Starting kT=0.840, rho=0.540
#     reused: Run_ID=20260914202914, status=Running
# [116/256] Starting kT=0.840, rho=0.560
#     created: Run_ID=20260914202941, status=Complete
# [117/256] Starting kT=0.840, rho=0.580
#     created: Run_ID=20260914203039, status=Complete
# [118/256] Starting kT=0.840, rho=0.600
#     reused: Run_ID=20260914203052, status=Running
# [119/256] Starting kT=0.840, rho=0.620
#     created: Run_ID=20260914203137, status=Complete
# [120/256] Starting kT=0.840, rho=0.640
#     reused: Run_ID=20260914203231, status=Running
# [121/256] Starting kT=0.840, rho=0.660
#     created: Run_ID=20260914203233, status=Complete
# [122/256] Starting kT=0.840, rho=0.680
#     created: Run_ID=20260914203330, status=Complete
# [123/256] Starting kT=0.840, rho=0.700
#     reused: Run_ID=20260914203412, status=Running
# [124/256] Starting kT=0.840, rho=0.720
#     created: Run_ID=20260914203428, status=Complete
# [125/256] Starting kT=0.840, rho=0.740
#     created: Run_ID=20260914203524, status=Complete
# [126/256] Starting kT=0.840, rho=0.760
#     reused: Run_ID=20260914203553, status=Running
# [127/256] Starting kT=0.840, rho=0.780
#     created: Run_ID=20260914203623, status=Complete
# [128/256] Starting kT=0.840, rho=0.800
#     created: Run_ID=20260914203721, status=Complete
# [129/256] Starting kT=0.860, rho=0.500
#     reused: Run_ID=20260914203738, status=Running
# [130/256] Starting kT=0.860, rho=0.520
#     created: Run_ID=20260914203821, status=Complete
# [131/256] Starting kT=0.860, rho=0.540
#     created: Run_ID=20260914203917, status=Complete
# [132/256] Starting kT=0.860, rho=0.560
#     reused: Run_ID=20260914203920, status=Running
# [133/256] Starting kT=0.860, rho=0.580
#     created: Run_ID=20260914204018, status=Complete
# [134/256] Starting kT=0.860, rho=0.600
#     reused: Run_ID=20260914204100, status=Running
# [135/256] Starting kT=0.860, rho=0.620
#     created: Run_ID=20260914204116, status=Complete
# [136/256] Starting kT=0.860, rho=0.640
#     created: Run_ID=20260914204215, status=Complete
# [137/256] Starting kT=0.860, rho=0.660
#     reused: Run_ID=20260914204242, status=Running
# [138/256] Starting kT=0.860, rho=0.680
#     created: Run_ID=20260914204315, status=Complete
# [139/256] Starting kT=0.860, rho=0.700
#     created: Run_ID=20260914204410, status=Complete
# [140/256] Starting kT=0.860, rho=0.720
#     reused: Run_ID=20260914204424, status=Running
# [141/256] Starting kT=0.860, rho=0.740
#     created: Run_ID=20260914204508, status=Complete
# [142/256] Starting kT=0.860, rho=0.760
#     reused: Run_ID=20260914204605, status=Running
# [143/256] Starting kT=0.860, rho=0.780
#     created: Run_ID=20260914204608, status=Complete
# [144/256] Starting kT=0.860, rho=0.800
#     created: Run_ID=20260914204712, status=Complete
# [145/256] Starting kT=0.880, rho=0.500
#     reused: Run_ID=20260914204751, status=Running
# [146/256] Starting kT=0.880, rho=0.520
#     created: Run_ID=20260914204814, status=Complete
# [147/256] Starting kT=0.880, rho=0.540
#     created: Run_ID=20260914204910, status=Complete
# [148/256] Starting kT=0.880, rho=0.560
#     reused: Run_ID=20260914204932, status=Running
# [149/256] Starting kT=0.880, rho=0.580
#     created: Run_ID=20260914205005, status=Complete
# [150/256] Starting kT=0.880, rho=0.600
#     created: Run_ID=20260914205105, status=Complete
# [151/256] Starting kT=0.880, rho=0.620
#     reused: Run_ID=20260914205112, status=Running
# [152/256] Starting kT=0.880, rho=0.640
#     created: Run_ID=20260914205202, status=Complete
# [153/256] Starting kT=0.880, rho=0.660
#     reused: Run_ID=20260914205251, status=Running
# [154/256] Starting kT=0.880, rho=0.680
#     created: Run_ID=20260914205301, status=Complete
# [155/256] Starting kT=0.880, rho=0.700
#     created: Run_ID=20260914205357, status=Complete
# [156/256] Starting kT=0.880, rho=0.720
#     reused: Run_ID=20260914205428, status=Running
# [157/256] Starting kT=0.880, rho=0.740
#     created: Run_ID=20260914205455, status=Complete
# [158/256] Starting kT=0.880, rho=0.760
#     created: Run_ID=20260914205553, status=Complete
# [159/256] Starting kT=0.880, rho=0.780
#     reused: Run_ID=20260914205610, status=Running
# [160/256] Starting kT=0.880, rho=0.800
#     created: Run_ID=20260914205652, status=Complete
# [161/256] Starting kT=0.900, rho=0.500
#     created: Run_ID=20260914205752, status=Complete
# [162/256] Starting kT=0.900, rho=0.520
#     reused: Run_ID=20260914205757, status=Running
# [163/256] Starting kT=0.900, rho=0.540
#     created: Run_ID=20260914205848, status=Complete
# [164/256] Starting kT=0.900, rho=0.560
#     reused: Run_ID=20260914205933, status=Running
# [165/256] Starting kT=0.900, rho=0.580
#     created: Run_ID=20260914205943, status=Complete
# [166/256] Starting kT=0.900, rho=0.600
#     created: Run_ID=20260914210039, status=Complete
# [167/256] Starting kT=0.900, rho=0.620
#     reused: Run_ID=20260914210111, status=Running
# [168/256] Starting kT=0.900, rho=0.640
#     created: Run_ID=20260914210136, status=Complete
# [169/256] Starting kT=0.900, rho=0.660
#     created: Run_ID=20260914210233, status=Complete
# [170/256] Starting kT=0.900, rho=0.680
#     reused: Run_ID=20260914210249, status=Running
# [171/256] Starting kT=0.900, rho=0.700
#     created: Run_ID=20260914210326, status=Complete
# [172/256] Starting kT=0.900, rho=0.720
#     created: Run_ID=20260914210421, status=Complete
# [173/256] Starting kT=0.900, rho=0.740
#     reused: Run_ID=20260914210427, status=Running
# [174/256] Starting kT=0.900, rho=0.760
#     created: Run_ID=20260914210518, status=Complete
# [175/256] Starting kT=0.900, rho=0.780
#     reused: Run_ID=20260914210608, status=Running
# [176/256] Starting kT=0.900, rho=0.800
#     created: Run_ID=20260914210618, status=Complete
# [177/256] Starting kT=0.920, rho=0.500
#     created: Run_ID=20260914210719, status=Complete
# [178/256] Starting kT=0.920, rho=0.520
#     reused: Run_ID=20260914210753, status=Running
# [179/256] Starting kT=0.920, rho=0.540
#     created: Run_ID=20260914210814, status=Complete
# [180/256] Starting kT=0.920, rho=0.560
#     created: Run_ID=20260914210909, status=Complete
# [181/256] Starting kT=0.920, rho=0.580
#     reused: Run_ID=20260914210928, status=Running
# [182/256] Starting kT=0.920, rho=0.600
#     created: Run_ID=20260914211004, status=Complete
# [183/256] Starting kT=0.920, rho=0.620
#     created: Run_ID=20260914211059, status=Complete
# [184/256] Starting kT=0.920, rho=0.640
#     reused: Run_ID=20260914211105, status=Running
# [185/256] Starting kT=0.920, rho=0.660
#     created: Run_ID=20260914211153, status=Complete
# [186/256] Starting kT=0.920, rho=0.680
#     reused: Run_ID=20260914211238, status=Running
# [187/256] Starting kT=0.920, rho=0.700
#     created: Run_ID=20260914211247, status=Complete
# [188/256] Starting kT=0.920, rho=0.720
#     created: Run_ID=20260914211344, status=Complete
# [189/256] Starting kT=0.920, rho=0.740
#     reused: Run_ID=20260914211415, status=Running
# [190/256] Starting kT=0.920, rho=0.760
#     created: Run_ID=20260914211439, status=Complete
# [191/256] Starting kT=0.920, rho=0.780
#     created: Run_ID=20260914211537, status=Complete
# [192/256] Starting kT=0.920, rho=0.800
#     reused: Run_ID=20260914211559, status=Running
# [193/256] Starting kT=0.940, rho=0.500
#     created: Run_ID=20260914211638, status=Complete
# [194/256] Starting kT=0.940, rho=0.520
#     created: Run_ID=20260914211731, status=Complete
# [195/256] Starting kT=0.940, rho=0.540
#     reused: Run_ID=20260914211748, status=Running
# [196/256] Starting kT=0.940, rho=0.560
#     created: Run_ID=20260914211823, status=Complete
# [197/256] Starting kT=0.940, rho=0.580
#     created: Run_ID=20260914211918, status=Complete
# [198/256] Starting kT=0.940, rho=0.600
#     reused: Run_ID=20260914211922, status=Running
# [199/256] Starting kT=0.940, rho=0.620
#     created: Run_ID=20260914212013, status=Complete
# [200/256] Starting kT=0.940, rho=0.640
#     reused: Run_ID=20260914212058, status=Running
# [201/256] Starting kT=0.940, rho=0.660
#     created: Run_ID=20260914212109, status=Complete
# [202/256] Starting kT=0.940, rho=0.680
#     created: Run_ID=20260914212203, status=Complete
# [203/256] Starting kT=0.940, rho=0.700
#     reused: Run_ID=20260914212231, status=Running
# [204/256] Starting kT=0.940, rho=0.720
#     created: Run_ID=20260914212302, status=Complete
# [205/256] Starting kT=0.940, rho=0.740
#     created: Run_ID=20260914212358, status=Complete
# [206/256] Starting kT=0.940, rho=0.760
#     reused: Run_ID=20260914212410, status=Running
# [207/256] Starting kT=0.940, rho=0.780
#     created: Run_ID=20260914212454, status=Complete
# [208/256] Starting kT=0.940, rho=0.800
#     created: Run_ID=20260914212554, status=Complete
# [209/256] Starting kT=0.960, rho=0.500
#     reused: Run_ID=20260914212555, status=Running
# [210/256] Starting kT=0.960, rho=0.520
#     created: Run_ID=20260914212653, status=Complete
# [211/256] Starting kT=0.960, rho=0.540
#     reused: Run_ID=20260914212729, status=Running
# [212/256] Starting kT=0.960, rho=0.560
#     created: Run_ID=20260914212746, status=Complete
# [213/256] Starting kT=0.960, rho=0.580
#     created: Run_ID=20260914212842, status=Complete
# [214/256] Starting kT=0.960, rho=0.600
#     reused: Run_ID=20260914212902, status=Running
# [215/256] Starting kT=0.960, rho=0.620
#     created: Run_ID=20260914212937, status=Complete
# [216/256] Starting kT=0.960, rho=0.640
#     created: Run_ID=20260914213029, status=Complete
# [217/256] Starting kT=0.960, rho=0.660
#     reused: Run_ID=20260914213036, status=Running
# [218/256] Starting kT=0.960, rho=0.680
#     created: Run_ID=20260914213122, status=Complete
# [219/256] Starting kT=0.960, rho=0.700
#     reused: Run_ID=20260914213212, status=Running
# [220/256] Starting kT=0.960, rho=0.720
#     created: Run_ID=20260914213218, status=Complete
# [221/256] Starting kT=0.960, rho=0.740
#     created: Run_ID=20260914213313, status=Complete
# [222/256] Starting kT=0.960, rho=0.760
#     reused: Run_ID=20260914213352, status=Running
# [223/256] Starting kT=0.960, rho=0.780
#     created: Run_ID=20260914213408, status=Complete
# [224/256] Starting kT=0.960, rho=0.800
#     created: Run_ID=20260914213507, status=Complete
# [225/256] Starting kT=0.980, rho=0.500
#     reused: Run_ID=20260914213536, status=Running
# [226/256] Starting kT=0.980, rho=0.520
#     created: Run_ID=20260914213607, status=Complete
# [227/256] Starting kT=0.980, rho=0.540
#     created: Run_ID=20260914213700, status=Complete
# [228/256] Starting kT=0.980, rho=0.560
#     reused: Run_ID=20260914213709, status=Running
# [229/256] Starting kT=0.980, rho=0.580
#     created: Run_ID=20260914213754, status=Complete
# [230/256] Starting kT=0.980, rho=0.600
#     reused: Run_ID=20260914213841, status=Running
# [231/256] Starting kT=0.980, rho=0.620
#     created: Run_ID=20260914213847, status=Complete
# [232/256] Starting kT=0.980, rho=0.640
#     created: Run_ID=20260914213938, status=Complete
# [233/256] Starting kT=0.980, rho=0.660
#     reused: Run_ID=20260914214013, status=Running
# [234/256] Starting kT=0.980, rho=0.680
#     created: Run_ID=20260914214030, status=Complete
# [235/256] Starting kT=0.980, rho=0.700
#     created: Run_ID=20260914214125, status=Complete
# [236/256] Starting kT=0.980, rho=0.720
#     reused: Run_ID=20260914214148, status=Running
# [237/256] Starting kT=0.980, rho=0.740
#     created: Run_ID=20260914214220, status=Complete
# [238/256] Starting kT=0.980, rho=0.760
#     created: Run_ID=20260914214317, status=Complete
# [239/256] Starting kT=0.980, rho=0.780
#     reused: Run_ID=20260914214328, status=Running
# [240/256] Starting kT=0.980, rho=0.800
#     created: Run_ID=20260914214416, status=Complete
# [241/256] Starting kT=1.000, rho=0.500
#     reused: Run_ID=20260914214514, status=Running
# [242/256] Starting kT=1.000, rho=0.520
#     created: Run_ID=20260914214517, status=Complete
# [243/256] Starting kT=1.000, rho=0.540
#     created: Run_ID=20260914214609, status=Complete
# [244/256] Starting kT=1.000, rho=0.560
#     reused: Run_ID=20260914214645, status=Running
# [245/256] Starting kT=1.000, rho=0.580
#     created: Run_ID=20260914214701, status=Complete
# [246/256] Starting kT=1.000, rho=0.600
#     created: Run_ID=20260914214754, status=Complete
# [247/256] Starting kT=1.000, rho=0.620
#     reused: Run_ID=20260914214817, status=Running
# [248/256] Starting kT=1.000, rho=0.640
#     created: Run_ID=20260914214845, status=Complete
# [249/256] Starting kT=1.000, rho=0.660
#     created: Run_ID=20260914214938, status=Complete
# [250/256] Starting kT=1.000, rho=0.680
#     reused: Run_ID=20260914214949, status=Running
# [251/256] Starting kT=1.000, rho=0.700
#     created: Run_ID=20260914215032, status=Complete
# [252/256] Starting kT=1.000, rho=0.720
#     reused: Run_ID=20260914215127, status=Running
# [253/256] Starting kT=1.000, rho=0.740
#     created: Run_ID=20260914215129, status=Complete
# [254/256] Starting kT=1.000, rho=0.760
#     created: Run_ID=20260914215224, status=Complete
# [255/256] Starting kT=1.000, rho=0.780
#     reused: Run_ID=20260914215307, status=Running
# [256/256] Starting kT=1.000, rho=0.800
#     created: Run_ID=20260914215322, status=Complete
#
# Thermalization scan results:
#      scan_index   kT   rho          run_id   action    status  created_new  \
# 0             1  0.7  0.50  20260914191900  created  Complete         True
# 1             2  0.7  0.52  20260914191909   reused   Running        False
# 2             3  0.7  0.54  20260914191959  created  Complete         True
# 3             4  0.7  0.56  20260914192054   reused   Running        False
# 4             5  0.7  0.58  20260914192101  created  Complete         True
# ..          ...  ...   ...             ...      ...       ...          ...
# 251         252  1.0  0.72  20260914215127   reused   Running        False
# 252         253  1.0  0.74  20260914215129  created  Complete         True
# 253         254  1.0  0.76  20260914215224  created  Complete         True
# 254         255  1.0  0.78  20260914215307   reused   Running        False
# 255         256  1.0  0.80  20260914215322  created  Complete         True
#
#      skipped_existing                                      run_signature error
# 0               False  4766e87bda389dcacc37915af7d42c3f62808a3c525b18...  None
# 1                True  32a26c58d9b2c9e6e968972e1511933a09f5df64a7eaf1...  None
# 2               False  265b7240e7b4612a957f4fdd0e3c5aefb8366a91f13044...  None
# 3                True  a960b8dce9a09e8c0e40a7cfaf13ad537efed3090e5d11...  None
# 4               False  542fb4a0a0f7555f6218da8e5a15a1532e3d9b2f71bc08...  None
# ..                ...                                                ...   ...
# 251              True  167d7f498cd818b5802b96c933e76abceaa96c4ce6f087...  None
# 252             False  d206e7c6ac0a1f661cb9809657154a5a02fd3a856cbcb0...  None
# 253             False  86e62e186d270accfceacb369630b1af920d901fc1c326...  None
# 254              True  f28678eba10bcf364ada689aa1930548a643d16b561088...  None
# 255             False  3632681ef9013d870f5d5c87919bc0a37db6a0600ae836...  None
#
# [256 rows x 10 columns]
# Run-ID grid:
# rho             0.50            0.52            0.54            0.56  \
# kT
# 0.70  20260914191900  20260914191909  20260914191959  20260914192054
# 0.72  20260914192905  20260914192937  20260914193003  20260914193105
# 0.74  20260914193854  20260914193954  20260914193956  20260914194055
# 0.76  20260914194843  20260914194942  20260914195010  20260914195042
# 0.78  20260914195845  20260914195916  20260914200011  20260914200030
# 0.80  20260914200847  20260914200858  20260914200946  20260914201038
# 0.82  20260914201815  20260914201910  20260914201912  20260914202008
# 0.84  20260914202747  20260914202844  20260914202914  20260914202941
# 0.86  20260914203738  20260914203821  20260914203917  20260914203920
# 0.88  20260914204751  20260914204814  20260914204910  20260914204932
# 0.90  20260914205752  20260914205757  20260914205848  20260914205933
# 0.92  20260914210719  20260914210753  20260914210814  20260914210909
# 0.94  20260914211638  20260914211731  20260914211748  20260914211823
# 0.96  20260914212555  20260914212653  20260914212729  20260914212746
# 0.98  20260914213536  20260914213607  20260914213700  20260914213709
# 1.00  20260914214514  20260914214517  20260914214609  20260914214645
#
# rho             0.58            0.60            0.62            0.64  \
# kT
# 0.70  20260914192101  20260914192200  20260914192238  20260914192259
# 0.72  20260914193118  20260914193204  20260914193301  20260914193302
# 0.74  20260914194136  20260914194154  20260914194253  20260914194320
# 0.76  20260914195138  20260914195150  20260914195236  20260914195333
# 0.78  20260914200109  20260914200205  20260914200210  20260914200303
# 0.80  20260914201043  20260914201141  20260914201219  20260914201237
# 0.82  20260914202049  20260914202106  20260914202202  20260914202229
# 0.84  20260914203039  20260914203052  20260914203137  20260914203231
# 0.86  20260914204018  20260914204100  20260914204116  20260914204215
# 0.88  20260914205005  20260914205105  20260914205112  20260914205202
# 0.90  20260914205943  20260914210039  20260914210111  20260914210136
# 0.92  20260914210928  20260914211004  20260914211059  20260914211105
# 0.94  20260914211918  20260914211922  20260914212013  20260914212058
# 0.96  20260914212842  20260914212902  20260914212937  20260914213029
# 0.98  20260914213754  20260914213841  20260914213847  20260914213938
# 1.00  20260914214701  20260914214754  20260914214817  20260914214845
#
# rho             0.66            0.68            0.70            0.72  \
# kT
# 0.70  20260914192359  20260914192421  20260914192501  20260914192602
# 0.72  20260914193401  20260914193444  20260914193501  20260914193600
# 0.74  20260914194350  20260914194448  20260914194501  20260914194548
# 0.76  20260914195334  20260914195432  20260914195521  20260914195530
# 0.78  20260914200351  20260914200359  20260914200456  20260914200533
# 0.80  20260914201335  20260914201401  20260914201433  20260914201527
# 0.82  20260914202259  20260914202357  20260914202409  20260914202457
# 0.84  20260914203233  20260914203330  20260914203412  20260914203428
# 0.86  20260914204242  20260914204315  20260914204410  20260914204424
# 0.88  20260914205251  20260914205301  20260914205357  20260914205428
# 0.90  20260914210233  20260914210249  20260914210326  20260914210421
# 0.92  20260914211153  20260914211238  20260914211247  20260914211344
# 0.94  20260914212109  20260914212203  20260914212231  20260914212302
# 0.96  20260914213036  20260914213122  20260914213212  20260914213218
# 0.98  20260914214013  20260914214030  20260914214125  20260914214148
# 1.00  20260914214938  20260914214949  20260914215032  20260914215127
#
# rho             0.74            0.76            0.78            0.80
# kT
# 0.70  20260914192607  20260914192705  20260914192752  20260914192802
# 0.72  20260914193630  20260914193700  20260914193756  20260914193809
# 0.74  20260914194647  20260914194648  20260914194745  20260914194826
# 0.76  20260914195625  20260914195703  20260914195719  20260914195817
# 0.78  20260914200554  20260914200650  20260914200713  20260914200749
# 0.80  20260914201543  20260914201621  20260914201718  20260914201725
# 0.82  20260914202546  20260914202552  20260914202649  20260914202727
# 0.84  20260914203524  20260914203553  20260914203623  20260914203721
# 0.86  20260914204508  20260914204605  20260914204608  20260914204712
# 0.88  20260914205455  20260914205553  20260914205610  20260914205652
# 0.90  20260914210427  20260914210518  20260914210608  20260914210618
# 0.92  20260914211415  20260914211439  20260914211537  20260914211559
# 0.94  20260914212358  20260914212410  20260914212454  20260914212554
# 0.96  20260914213313  20260914213352  20260914213408  20260914213507
# 0.98  20260914214220  20260914214317  20260914214328  20260914214416
# 1.00  20260914215129  20260914215224  20260914215307  20260914215322
# All 256 grid points completed or reused an existing matching run.
